# %% [markdown]
# # Importing Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %matplotlib inline

# %%
# Setting path to test and training data
raw_data_path = os.path.join(os.path.pardir, 'Data', 'Raw_Data')
train_file_path = os.path.join(raw_data_path, 'train.csv')
test_file_path = os.path.join(raw_data_path, 'test.csv')

# %%
# Loading test and training data
train_df = pd.read_csv(train_file_path, index_col = 'Id')
test_df = pd.read_csv(test_file_path, index_col = 'Id')

# %% [markdown]
# # Basic Structure

# %%
train_df
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# 1            Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 2            Lvl    AllPub       FR2  ...        0    NaN    NaN         NaN
# 3            Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 4            Lvl    AllPub    Corner  ...        0    NaN    NaN         NaN
# 5            Lvl    AllPub       FR2  ...        0    NaN    NaN         NaN
# ...          ...       ...       ...  ...      ...    ...    ...         ...
# 1456         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1457         Lvl    AllPub    Inside  ...        0    NaN  MnPrv         NaN
# 1458         Lvl    AllPub    Inside  ...        0    NaN  GdPrv        Shed
# 1459         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1460         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1          0      2    2008        WD         Normal     208500
# 2          0      5    2007        WD         Normal     181500
# 3          0      9    2008        WD         Normal     223500
# 4          0      2    2006        WD        Abnorml     140000
# 5          0     12    2008        WD         Normal     250000
# ...      ...    ...     ...       ...            ...        ...
# 1456       0      8    2007        WD         Normal     175000
# 1457       0      2    2010        WD         Normal     210000
# 1458    2500      5    2010        WD         Normal     266500
# 1459       0      4    2010        WD         Normal     142125
# 1460       0      6    2008        WD         Normal     147500
#
# [1460 rows x 80 columns]

# %%
test_df
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1462          20       RL         81.0    14267   Pave   NaN      IR1
# 1463          60       RL         74.0    13830   Pave   NaN      IR1
# 1464          60       RL         78.0     9978   Pave   NaN      IR1
# 1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 2915         160       RM         21.0     1936   Pave   NaN      Reg
# 2916         160       RM         21.0     1894   Pave   NaN      Reg
# 2917          20       RL        160.0    20000   Pave   NaN      Reg
# 2918          85       RL         62.0    10441   Pave   NaN      Reg
# 2919          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC  Fence  \
# Id                                    ...
# 1461         Lvl    AllPub    Inside  ...         120        0    NaN  MnPrv
# 1462         Lvl    AllPub    Corner  ...           0        0    NaN    NaN
# 1463         Lvl    AllPub    Inside  ...           0        0    NaN  MnPrv
# 1464         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 1465         HLS    AllPub    Inside  ...         144        0    NaN    NaN
# ...          ...       ...       ...  ...         ...      ...    ...    ...
# 2915         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 2916         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 2917         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 2918         Lvl    AllPub    Inside  ...           0        0    NaN  MnPrv
# 2919         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
#
#      MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# Id
# 1461         NaN       0       6    2010        WD         Normal
# 1462        Gar2   12500       6    2010        WD         Normal
# 1463         NaN       0       3    2010        WD         Normal
# 1464         NaN       0       6    2010        WD         Normal
# 1465         NaN       0       1    2010        WD         Normal
# ...          ...     ...     ...     ...       ...            ...
# 2915         NaN       0       6    2006        WD         Normal
# 2916         NaN       0       4    2006        WD        Abnorml
# 2917         NaN       0       9    2006        WD        Abnorml
# 2918        Shed     700       7    2006        WD         Normal
# 2919         NaN       0      11    2006        WD         Normal
#
# [1459 rows x 79 columns]

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 1 to 1460
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
#  17  OverallCond    1460 non-null   int64
#  18  YearBuilt      1460 non-null   int64
#  19  YearRemodAdd   1460 non-null   int64
#  20  RoofStyle      1460 non-null   object
#  21  RoofMatl       1460 non-null   object
#  22  Exterior1st    1460 non-null   object
#  23  Exterior2nd    1460 non-null   object
#  24  MasVnrType     1452 non-null   object
#  25  MasVnrArea     1452 non-null   float64
#  26  ExterQual      1460 non-null   object
#  27  ExterCond      1460 non-null   object
#  28  Foundation     1460 non-null   object
#  29  BsmtQual       1423 non-null   object
#  30  BsmtCond       1423 non-null   object
#  31  BsmtExposure   1422 non-null   object
#  32  BsmtFinType1   1423 non-null   object
#  33  BsmtFinSF1     1460 non-null   int64
#  34  BsmtFinType2   1422 non-null   object
#  35  BsmtFinSF2     1460 non-null   int64
#  36  BsmtUnfSF      1460 non-null   int64
#  37  TotalBsmtSF    1460 non-null   int64
#  38  Heating        1460 non-null   object
#  39  HeatingQC      1460 non-null   object
#  40  CentralAir     1460 non-null   object
#  41  Electrical     1459 non-null   object
#  42  1stFlrSF       1460 non-null   int64
#  43  2ndFlrSF       1460 non-null   int64
#  44  LowQualFinSF   1460 non-null   int64
#  45  GrLivArea      1460 non-null   int64
#  46  BsmtFullBath   1460 non-null   int64
#  47  BsmtHalfBath   1460 non-null   int64
#  48  FullBath       1460 non-null   int64
#  49  HalfBath       1460 non-null   int64
#  50  BedroomAbvGr   1460 non-null   int64
#  51  KitchenAbvGr   1460 non-null   int64
#  52  KitchenQual    1460 non-null   object
#  53  TotRmsAbvGrd   1460 non-null   int64
#  54  Functional     1460 non-null   object
#  55  Fireplaces     1460 non-null   int64
#  56  FireplaceQu    770 non-null    object
#  57  GarageType     1379 non-null   object
#  58  GarageYrBlt    1379 non-null   float64
#  59  GarageFinish   1379 non-null   object
#  60  GarageCars     1460 non-null   int64
#  61  GarageArea     1460 non-null   int64
#  62  GarageQual     1379 non-null   object
#  63  GarageCond     1379 non-null   object
#  64  PavedDrive     1460 non-null   object
#  65  WoodDeckSF     1460 non-null   int64
#  66  OpenPorchSF    1460 non-null   int64
#  67  EnclosedPorch  1460 non-null   int64
#  68  3SsnPorch      1460 non-null   int64
#  69  ScreenPorch    1460 non-null   int64
#  70  PoolArea       1460 non-null   int64
#  71  PoolQC         7 non-null      object
#  72  Fence          281 non-null    object
#  73  MiscFeature    54 non-null     object
#  74  MiscVal        1460 non-null   int64
#  75  MoSold         1460 non-null   int64
#  76  YrSold         1460 non-null   int64
#  77  SaleType       1460 non-null   object
#  78  SaleCondition  1460 non-null   object
#  79  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(34), object(43)
# memory usage: 923.9+ KB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1459 entries, 1461 to 2919
# Data columns (total 79 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1459 non-null   int64
#  1   MSZoning       1455 non-null   object
#  2   LotFrontage    1232 non-null   float64
#  3   LotArea        1459 non-null   int64
#  4   Street         1459 non-null   object
#  5   Alley          107 non-null    object
#  6   LotShape       1459 non-null   object
#  7   LandContour    1459 non-null   object
#  8   Utilities      1457 non-null   object
#  9   LotConfig      1459 non-null   object
#  10  LandSlope      1459 non-null   object
#  11  Neighborhood   1459 non-null   object
#  12  Condition1     1459 non-null   object
#  13  Condition2     1459 non-null   object
#  14  BldgType       1459 non-null   object
#  15  HouseStyle     1459 non-null   object
#  16  OverallQual    1459 non-null   int64
#  17  OverallCond    1459 non-null   int64
#  18  YearBuilt      1459 non-null   int64
#  19  YearRemodAdd   1459 non-null   int64
#  20  RoofStyle      1459 non-null   object
#  21  RoofMatl       1459 non-null   object
#  22  Exterior1st    1458 non-null   object
#  23  Exterior2nd    1458 non-null   object
#  24  MasVnrType     1443 non-null   object
#  25  MasVnrArea     1444 non-null   float64
#  26  ExterQual      1459 non-null   object
#  27  ExterCond      1459 non-null   object
#  28  Foundation     1459 non-null   object
#  29  BsmtQual       1415 non-null   object
#  30  BsmtCond       1414 non-null   object
#  31  BsmtExposure   1415 non-null   object
#  32  BsmtFinType1   1417 non-null   object
#  33  BsmtFinSF1     1458 non-null   float64
#  34  BsmtFinType2   1417 non-null   object
#  35  BsmtFinSF2     1458 non-null   float64
#  36  BsmtUnfSF      1458 non-null   float64
#  37  TotalBsmtSF    1458 non-null   float64
#  38  Heating        1459 non-null   object
#  39  HeatingQC      1459 non-null   object
#  40  CentralAir     1459 non-null   object
#  41  Electrical     1459 non-null   object
#  42  1stFlrSF       1459 non-null   int64
#  43  2ndFlrSF       1459 non-null   int64
#  44  LowQualFinSF   1459 non-null   int64
#  45  GrLivArea      1459 non-null   int64
#  46  BsmtFullBath   1457 non-null   float64
#  47  BsmtHalfBath   1457 non-null   float64
#  48  FullBath       1459 non-null   int64
#  49  HalfBath       1459 non-null   int64
#  50  BedroomAbvGr   1459 non-null   int64
#  51  KitchenAbvGr   1459 non-null   int64
#  52  KitchenQual    1458 non-null   object
#  53  TotRmsAbvGrd   1459 non-null   int64
#  54  Functional     1457 non-null   object
#  55  Fireplaces     1459 non-null   int64
#  56  FireplaceQu    729 non-null    object
#  57  GarageType     1383 non-null   object
#  58  GarageYrBlt    1381 non-null   float64
#  59  GarageFinish   1381 non-null   object
#  60  GarageCars     1458 non-null   float64
#  61  GarageArea     1458 non-null   float64
#  62  GarageQual     1381 non-null   object
#  63  GarageCond     1381 non-null   object
#  64  PavedDrive     1459 non-null   object
#  65  WoodDeckSF     1459 non-null   int64
#  66  OpenPorchSF    1459 non-null   int64
#  67  EnclosedPorch  1459 non-null   int64
#  68  3SsnPorch      1459 non-null   int64
#  69  ScreenPorch    1459 non-null   int64
#  70  PoolArea       1459 non-null   int64
#  71  PoolQC         3 non-null      object
#  72  Fence          290 non-null    object
#  73  MiscFeature    51 non-null     object
#  74  MiscVal        1459 non-null   int64
#  75  MoSold         1459 non-null   int64
#  76  YrSold         1459 non-null   int64
#  77  SaleType       1458 non-null   object
#  78  SaleCondition  1459 non-null   object
# dtypes: float64(11), int64(25), object(43)
# memory usage: 911.9+ KB

# %%
# Adding Sale Price Feature to test_df with default value -1
test_df['SalePrice'] = -1
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1459 entries, 1461 to 2919
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1459 non-null   int64
#  1   MSZoning       1455 non-null   object
#  2   LotFrontage    1232 non-null   float64
#  3   LotArea        1459 non-null   int64
#  4   Street         1459 non-null   object
#  5   Alley          107 non-null    object
#  6   LotShape       1459 non-null   object
#  7   LandContour    1459 non-null   object
#  8   Utilities      1457 non-null   object
#  9   LotConfig      1459 non-null   object
#  10  LandSlope      1459 non-null   object
#  11  Neighborhood   1459 non-null   object
#  12  Condition1     1459 non-null   object
#  13  Condition2     1459 non-null   object
#  14  BldgType       1459 non-null   object
#  15  HouseStyle     1459 non-null   object
#  16  OverallQual    1459 non-null   int64
#  17  OverallCond    1459 non-null   int64
#  18  YearBuilt      1459 non-null   int64
#  19  YearRemodAdd   1459 non-null   int64
#  20  RoofStyle      1459 non-null   object
#  21  RoofMatl       1459 non-null   object
#  22  Exterior1st    1458 non-null   object
#  23  Exterior2nd    1458 non-null   object
#  24  MasVnrType     1443 non-null   object
#  25  MasVnrArea     1444 non-null   float64
#  26  ExterQual      1459 non-null   object
#  27  ExterCond      1459 non-null   object
#  28  Foundation     1459 non-null   object
#  29  BsmtQual       1415 non-null   object
#  30  BsmtCond       1414 non-null   object
#  31  BsmtExposure   1415 non-null   object
#  32  BsmtFinType1   1417 non-null   object
#  33  BsmtFinSF1     1458 non-null   float64
#  34  BsmtFinType2   1417 non-null   object
#  35  BsmtFinSF2     1458 non-null   float64
#  36  BsmtUnfSF      1458 non-null   float64
#  37  TotalBsmtSF    1458 non-null   float64
#  38  Heating        1459 non-null   object
#  39  HeatingQC      1459 non-null   object
#  40  CentralAir     1459 non-null   object
#  41  Electrical     1459 non-null   object
#  42  1stFlrSF       1459 non-null   int64
#  43  2ndFlrSF       1459 non-null   int64
#  44  LowQualFinSF   1459 non-null   int64
#  45  GrLivArea      1459 non-null   int64
#  46  BsmtFullBath   1457 non-null   float64
#  47  BsmtHalfBath   1457 non-null   float64
#  48  FullBath       1459 non-null   int64
#  49  HalfBath       1459 non-null   int64
#  50  BedroomAbvGr   1459 non-null   int64
#  51  KitchenAbvGr   1459 non-null   int64
#  52  KitchenQual    1458 non-null   object
#  53  TotRmsAbvGrd   1459 non-null   int64
#  54  Functional     1457 non-null   object
#  55  Fireplaces     1459 non-null   int64
#  56  FireplaceQu    729 non-null    object
#  57  GarageType     1383 non-null   object
#  58  GarageYrBlt    1381 non-null   float64
#  59  GarageFinish   1381 non-null   object
#  60  GarageCars     1458 non-null   float64
#  61  GarageArea     1458 non-null   float64
#  62  GarageQual     1381 non-null   object
#  63  GarageCond     1381 non-null   object
#  64  PavedDrive     1459 non-null   object
#  65  WoodDeckSF     1459 non-null   int64
#  66  OpenPorchSF    1459 non-null   int64
#  67  EnclosedPorch  1459 non-null   int64
#  68  3SsnPorch      1459 non-null   int64
#  69  ScreenPorch    1459 non-null   int64
#  70  PoolArea       1459 non-null   int64
#  71  PoolQC         3 non-null      object
#  72  Fence          290 non-null    object
#  73  MiscFeature    51 non-null     object
#  74  MiscVal        1459 non-null   int64
#  75  MoSold         1459 non-null   int64
#  76  YrSold         1459 non-null   int64
#  77  SaleType       1458 non-null   object
#  78  SaleCondition  1459 non-null   object
#  79  SalePrice      1459 non-null   int64
# dtypes: float64(11), int64(26), object(43)
# memory usage: 923.3+ KB

# %%
# Concatinating train_f and test_df to process them simultaneously
df = pd.concat((train_df, test_df), axis = 0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 1 to 2919
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     2919 non-null   int64
#  1   MSZoning       2915 non-null   object
#  2   LotFrontage    2433 non-null   float64
#  3   LotArea        2919 non-null   int64
#  4   Street         2919 non-null   object
#  5   Alley          198 non-null    object
#  6   LotShape       2919 non-null   object
#  7   LandContour    2919 non-null   object
#  8   Utilities      2917 non-null   object
#  9   LotConfig      2919 non-null   object
#  10  LandSlope      2919 non-null   object
#  11  Neighborhood   2919 non-null   object
#  12  Condition1     2919 non-null   object
#  13  Condition2     2919 non-null   object
#  14  BldgType       2919 non-null   object
#  15  HouseStyle     2919 non-null   object
#  16  OverallQual    2919 non-null   int64
#  17  OverallCond    2919 non-null   int64
#  18  YearBuilt      2919 non-null   int64
#  19  YearRemodAdd   2919 non-null   int64
#  20  RoofStyle      2919 non-null   object
#  21  RoofMatl       2919 non-null   object
#  22  Exterior1st    2918 non-null   object
#  23  Exterior2nd    2918 non-null   object
#  24  MasVnrType     2895 non-null   object
#  25  MasVnrArea     2896 non-null   float64
#  26  ExterQual      2919 non-null   object
#  27  ExterCond      2919 non-null   object
#  28  Foundation     2919 non-null   object
#  29  BsmtQual       2838 non-null   object
#  30  BsmtCond       2837 non-null   object
#  31  BsmtExposure   2837 non-null   object
#  32  BsmtFinType1   2840 non-null   object
#  33  BsmtFinSF1     2918 non-null   float64
#  34  BsmtFinType2   2839 non-null   object
#  35  BsmtFinSF2     2918 non-null   float64
#  36  BsmtUnfSF      2918 non-null   float64
#  37  TotalBsmtSF    2918 non-null   float64
#  38  Heating        2919 non-null   object
#  39  HeatingQC      2919 non-null   object
#  40  CentralAir     2919 non-null   object
#  41  Electrical     2918 non-null   object
#  42  1stFlrSF       2919 non-null   int64
#  43  2ndFlrSF       2919 non-null   int64
#  44  LowQualFinSF   2919 non-null   int64
#  45  GrLivArea      2919 non-null   int64
#  46  BsmtFullBath   2917 non-null   float64
#  47  BsmtHalfBath   2917 non-null   float64
#  48  FullBath       2919 non-null   int64
#  49  HalfBath       2919 non-null   int64
#  50  BedroomAbvGr   2919 non-null   int64
#  51  KitchenAbvGr   2919 non-null   int64
#  52  KitchenQual    2918 non-null   object
#  53  TotRmsAbvGrd   2919 non-null   int64
#  54  Functional     2917 non-null   object
#  55  Fireplaces     2919 non-null   int64
#  56  FireplaceQu    1499 non-null   object
#  57  GarageType     2762 non-null   object
#  58  GarageYrBlt    2760 non-null   float64
#  59  GarageFinish   2760 non-null   object
#  60  GarageCars     2918 non-null   float64
#  61  GarageArea     2918 non-null   float64
#  62  GarageQual     2760 non-null   object
#  63  GarageCond     2760 non-null   object
#  64  PavedDrive     2919 non-null   object
#  65  WoodDeckSF     2919 non-null   int64
#  66  OpenPorchSF    2919 non-null   int64
#  67  EnclosedPorch  2919 non-null   int64
#  68  3SsnPorch      2919 non-null   int64
#  69  ScreenPorch    2919 non-null   int64
#  70  PoolArea       2919 non-null   int64
#  71  PoolQC         10 non-null     object
#  72  Fence          571 non-null    object
#  73  MiscFeature    105 non-null    object
#  74  MiscVal        2919 non-null   int64
#  75  MoSold         2919 non-null   int64
#  76  YrSold         2919 non-null   int64
#  77  SaleType       2918 non-null   object
#  78  SaleCondition  2919 non-null   object
#  79  SalePrice      2919 non-null   int64
# dtypes: float64(11), int64(26), object(43)
# memory usage: 1.8+ MB

# %% [markdown]
# # Processing and Cleaning Data

# %% [markdown]
# ## Feature: MS Zoning

# %%
# Houses with invalid entries in 'MSZoning' feature
df[pd.isnull(df['MSZoning'])]

# We observe that all the houses with missing 'MSZoning' values are from the test dataset
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1916          30      NaN        109.0    21780   Grvl   NaN      Reg
# 2217          20      NaN         80.0    14584   Pave   NaN      Reg
# 2251          70      NaN          NaN    56600   Pave   NaN      IR1
# 2905          20      NaN        125.0    31250   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                    ...
# 1916         Lvl       NaN    Inside  ...        0    NaN   NaN         NaN
# 2217         Low    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2251         Low    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2905         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1916       0      3    2009     ConLD         Normal         -1
# 2217       0      2    2008        WD        Abnorml         -1
# 2251       0      1    2008        WD         Normal         -1
# 2905       0      5    2006        WD         Normal         -1
#
# [4 rows x 80 columns]

# %%
# Frequency of different MSZoning Categories
df['MSZoning'].value_counts()
# Out:
# RL         2265
# RM          460
# FV          139
# RH           26
# C (all)      25
# Name: MSZoning, dtype: int64

# %%
# Crosstab between 'MSSubClass' and 'MSZoning'
pd.crosstab(df['MSSubClass'], df['MSZoning'])
# Out:
# MSZoning    C (all)  FV  RH    RL   RM
# MSSubClass
# 20                3  34   4  1016   20
# 30                8   0   2    61   67
# 40                0   0   0     4    2
# 45                0   0   1     6   11
# 50                7   0   2   159  119
# 60                0  43   0   529    3
# 70                4   0   3    57   63
# 75                0   0   0     9   14
# 80                0   0   0   115    3
# 85                0   0   0    47    1
# 90                0   0   4    92   13
# 120               0  19   6   117   40
# 150               0   0   0     1    0
# 160               0  43   0    21   64
# 180               0   0   0     0   17
# 190               3   0   4    31   23

# %% [markdown]
# From the above crosstab we see that among houses belonging to MSSubClass 20 (1-STORY 1946 & NEWER ALL STYLES),
# 1000+ of them have MSZONING label RL (Residential Low Density). Thus we will set MSZoning feature of houses with
# MSSubClass 20 having invalid entries to RL. Also houses with MSSubClass 30 (1-STORY 1945 & OLDER) and
# 70 (2-STORY 1945 & OLDER) to RM (Residential Medium Density) as that label is most common.

# %%
# Filling in missing MSZoning values

df.loc[pd.isnull(df['MSZoning']) & (df['MSSubClass'] == 20), 'MSZoning'] = 'RL'
df.MSZoning.fillna('RM', inplace = True)

#The above replacement is carried out because MSSubClass and MSZoning most probably are interrelated.

# %%
# MSZoning feature is now complete
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 1 to 2919
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     2919 non-null   int64
#  1   MSZoning       2919 non-null   object
#  2   LotFrontage    2433 non-null   float64
#  3   LotArea        2919 non-null   int64
#  4   Street         2919 non-null   object
#  5   Alley          198 non-null    object
#  6   LotShape       2919 non-null   object
#  7   LandContour    2919 non-null   object
#  8   Utilities      2917 non-null   object
#  9   LotConfig      2919 non-null   object
#  10  LandSlope      2919 non-null   object
#  11  Neighborhood   2919 non-null   object
#  12  Condition1     2919 non-null   object
#  13  Condition2     2919 non-null   object
#  14  BldgType       2919 non-null   object
#  15  HouseStyle     2919 non-null   object
#  16  OverallQual    2919 non-null   int64
#  17  OverallCond    2919 non-null   int64
#  18  YearBuilt      2919 non-null   int64
#  19  YearRemodAdd   2919 non-null   int64
#  20  RoofStyle      2919 non-null   object
#  21  RoofMatl       2919 non-null   object
#  22  Exterior1st    2918 non-null   object
#  23  Exterior2nd    2918 non-null   object
#  24  MasVnrType     2895 non-null   object
#  25  MasVnrArea     2896 non-null   float64
#  26  ExterQual      2919 non-null   object
#  27  ExterCond      2919 non-null   object
#  28  Foundation     2919 non-null   object
#  29  BsmtQual       2838 non-null   object
#  30  BsmtCond       2837 non-null   object
#  31  BsmtExposure   2837 non-null   object
#  32  BsmtFinType1   2840 non-null   object
#  33  BsmtFinSF1     2918 non-null   float64
#  34  BsmtFinType2   2839 non-null   object
#  35  BsmtFinSF2     2918 non-null   float64
#  36  BsmtUnfSF      2918 non-null   float64
#  37  TotalBsmtSF    2918 non-null   float64
#  38  Heating        2919 non-null   object
#  39  HeatingQC      2919 non-null   object
#  40  CentralAir     2919 non-null   object
#  41  Electrical     2918 non-null   object
#  42  1stFlrSF       2919 non-null   int64
#  43  2ndFlrSF       2919 non-null   int64
#  44  LowQualFinSF   2919 non-null   int64
#  45  GrLivArea      2919 non-null   int64
#  46  BsmtFullBath   2917 non-null   float64
#  47  BsmtHalfBath   2917 non-null   float64
#  48  FullBath       2919 non-null   int64
#  49  HalfBath       2919 non-null   int64
#  50  BedroomAbvGr   2919 non-null   int64
#  51  KitchenAbvGr   2919 non-null   int64
#  52  KitchenQual    2918 non-null   object
#  53  TotRmsAbvGrd   2919 non-null   int64
#  54  Functional     2917 non-null   object
#  55  Fireplaces     2919 non-null   int64
#  56  FireplaceQu    1499 non-null   object
#  57  GarageType     2762 non-null   object
#  58  GarageYrBlt    2760 non-null   float64
#  59  GarageFinish   2760 non-null   object
#  60  GarageCars     2918 non-null   float64
#  61  GarageArea     2918 non-null   float64
#  62  GarageQual     2760 non-null   object
#  63  GarageCond     2760 non-null   object
#  64  PavedDrive     2919 non-null   object
#  65  WoodDeckSF     2919 non-null   int64
#  66  OpenPorchSF    2919 non-null   int64
#  67  EnclosedPorch  2919 non-null   int64
#  68  3SsnPorch      2919 non-null   int64
#  69  ScreenPorch    2919 non-null   int64
#  70  PoolArea       2919 non-null   int64
#  71  PoolQC         10 non-null     object
#  72  Fence          571 non-null    object
#  73  MiscFeature    105 non-null    object
#  74  MiscVal        2919 non-null   int64
#  75  MoSold         2919 non-null   int64
#  76  YrSold         2919 non-null   int64
#  77  SaleType       2918 non-null   object
#  78  SaleCondition  2919 non-null   object
#  79  SalePrice      2919 non-null   int64
# dtypes: float64(11), int64(26), object(43)
# memory usage: 1.8+ MB

# %% [markdown]
# ## Feature: Lot Frontage

# %%
# Houses with invalid LotFrontage entries
df[pd.isnull(df['LotFrontage'])]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 8             60       RL          NaN    10382   Pave   NaN      IR1
# 13            20       RL          NaN    12968   Pave   NaN      IR2
# 15            20       RL          NaN    10920   Pave   NaN      IR1
# 17            20       RL          NaN    11241   Pave   NaN      IR1
# 25            20       RL          NaN     8246   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 2848          20       RL          NaN    11088   Pave   NaN      Reg
# 2851          60       RL          NaN    21533   Pave   NaN      IR2
# 2901          20       RL          NaN    50102   Pave   NaN      IR1
# 2902          20       RL          NaN     8098   Pave   NaN      IR1
# 2909          90       RL          NaN    11836   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# 8            Lvl    AllPub    Corner  ...        0    NaN    NaN        Shed
# 13           Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 15           Lvl    AllPub    Corner  ...        0    NaN   GdWo         NaN
# 17           Lvl    AllPub   CulDSac  ...        0    NaN    NaN        Shed
# 25           Lvl    AllPub    Inside  ...        0    NaN  MnPrv         NaN
# ...          ...       ...       ...  ...      ...    ...    ...         ...
# 2848         Lvl    AllPub    Corner  ...        0    NaN    NaN         NaN
# 2851         Lvl    AllPub       FR2  ...        0    NaN    NaN         NaN
# 2901         Low    AllPub    Inside  ...        0    NaN    NaN         NaN
# 2902         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 2909         Lvl    AllPub    Corner  ...        0    NaN    NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 8        350     11    2009        WD         Normal     200000
# 13         0      9    2008        WD         Normal     144000
# 15         0      5    2008        WD         Normal     157000
# 17       700      3    2010        WD         Normal     149000
# 25         0      5    2010        WD         Normal     154000
# ...      ...    ...     ...       ...            ...        ...
# 2848       0      6    2006        WD         Normal         -1
# 2851       0      8    2006        WD         Normal         -1
# 2901       0      3    2006        WD         Alloca         -1
# 2902       0     10    2006        WD         Normal         -1
# 2909       0      3    2006        WD         Normal         -1
#
# [486 rows x 80 columns]

# %%
# Crosstab between MSSubClass and LotFrontage
pd.crosstab(df['MSSubClass'], df['LotFrontage'])
# Out:
# LotFrontage  21.0   22.0   24.0   25.0   26.0   28.0   30.0   31.0   32.0   \
# MSSubClass
# 20               0      0      0      0      0      0      0      0      0
# 30               0      0      0      0      0      0      1      0      0
# 40               0      0      0      0      0      0      0      0      0
# 45               0      0      0      0      0      0      0      0      0
# 50               0      0      0      0      0      0      0      0      0
# 60               0      0      0      0      0      0      0      0      0
# 70               0      0      0      0      0      0      0      0      0
# 75               0      0      0      0      0      0      0      0      0
# 80               0      0      0      0      0      0      0      0      0
# 85               0      0      0      0      0      0      0      0      0
# 90               0      0      0      0      0      0      0      0      0
# 120              0      1      6      1      3      1      3      1      6
# 160             40      0     43      0      0      0      7      0      2
# 180             10      0      0      0      0      0      0      0      0
# 190              0      0      0      0      0      0      0      0      0
#
# LotFrontage  33.0   ...  152.0  153.0  155.0  160.0  168.0  174.0  182.0  \
# MSSubClass          ...
# 20               0  ...      0      0      1      2      0      0      1
# 30               0  ...      0      1      0      0      0      0      0
# 40               0  ...      0      0      0      0      0      0      0
# 45               0  ...      0      0      0      0      0      0      0
# 50               0  ...      1      0      0      0      0      0      0
# 60               0  ...      0      0      0      1      1      1      0
# 70               0  ...      0      0      0      0      0      0      0
# 75               0  ...      0      0      0      0      0      1      0
# 80               0  ...      0      0      0      0      0      0      0
# 85               0  ...      0      0      0      0      0      0      0
# 90               1  ...      0      0      0      0      0      0      0
# 120              1  ...      0      0      0      0      0      0      0
# 160              0  ...      0      0      0      0      0      0      0
# 180              0  ...      0      0      0      0      0      0      0
# 190              1  ...      0      0      0      0      0      0      0
#
# LotFrontage  195.0  200.0  313.0
# MSSubClass
# 20               0      1      1
# 30               0      0      0
# 40               0      0      0
# 45               0      0      0
# 50               0      0      0
# 60               0      0      1
# 70               0      0      0
# 75               0      0      0
# 80               0      0      0
# 85               0      0      0
# 90               0      0      0
# 120              0      0      0
# 160              0      0      0
# 180              0      0      0
# 190              1      0      0
#
# [15 rows x 128 columns]

# %%
# Scatter Plot between MSSubClass and LotFrontage
plt.scatter(df['MSSubClass'], df['LotFrontage'], color = 'c', alpha = 0.2);

plt.title('Lot Frontage Vs MS SubClass')
plt.xlabel('MS SubClass')
plt.ylabel('Lot Frontage')

plt.show()

# %% [markdown]
# There doesn't seem to be any relationship between these 2 features.

# %%
# Checking the Frequency of different Lot Frontage Values
df['LotFrontage'].value_counts().sort_index()
# Out:
# 21.0     50
# 22.0      1
# 24.0     49
# 25.0      1
# 26.0      3
#          ..
# 174.0     2
# 182.0     1
# 195.0     1
# 200.0     1
# 313.0     2
# Name: LotFrontage, Length: 128, dtype: int64

# %%
# Plot of frequency of LotFrontage values
plt.hist(df.loc[pd.notnull(df['LotFrontage'])]['LotFrontage'], bins = 80 ,color = 'c')

plt.title('LotFrontage Frequency Plot')
plt.xlabel('LotFrontage')
plt.ylabel('Frequency')

plt.show()

# %%
df.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  2919.000000  2433.000000    2919.000000  2919.000000  2919.000000
# mean     57.137718    69.305795   10168.114080     6.089072     5.564577
# std      42.517628    23.344905    7886.996359     1.409947     1.113131
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7478.000000     5.000000     5.000000
# 50%      50.000000    68.000000    9453.000000     6.000000     5.000000
# 75%      70.000000    80.000000   11570.000000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  2919.000000   2919.000000  2896.000000  2918.000000  2918.000000  ...
# mean   1971.312778   1984.264474   102.201312   441.423235    49.582248  ...
# std      30.291442     20.894344   179.334253   455.610826   169.205611  ...
# min    1872.000000   1950.000000     0.000000     0.000000     0.000000  ...
# 25%    1953.500000   1965.000000     0.000000     0.000000     0.000000  ...
# 50%    1973.000000   1993.000000     0.000000   368.500000     0.000000  ...
# 75%    2001.000000   2004.000000   164.000000   733.000000     0.000000  ...
# max    2010.000000   2010.000000  1600.000000  5644.000000  1526.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  2919.000000  2919.000000    2919.000000  2919.000000  2919.000000
# mean     93.709832    47.486811      23.098321     2.602261    16.062350
# std     126.526589    67.575493      64.244246    25.188169    56.184365
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    26.000000       0.000000     0.000000     0.000000
# 75%     168.000000    70.000000       0.000000     0.000000     0.000000
# max    1424.000000   742.000000    1012.000000   508.000000   576.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  2919.000000   2919.000000  2919.000000  2919.000000    2919.000000
# mean      2.251799     50.825968     6.213087  2007.792737   90491.088386
# std      35.663946    567.402211     2.714762     1.314964  106496.804191
# min       0.000000      0.000000     1.000000  2006.000000      -1.000000
# 25%       0.000000      0.000000     4.000000  2007.000000      -1.000000
# 50%       0.000000      0.000000     6.000000  2008.000000   34900.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  163000.000000
# max     800.000000  17000.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 37 columns]

# %%
# Statistics of known LotFrontage Values
lot_frontage_mean = df.loc[pd.notnull(df['LotFrontage']), 'LotFrontage'].mean()
lot_frontage_median = df.loc[pd.notnull(df['LotFrontage']), 'LotFrontage'].median()
lot_frontage_std = df.loc[pd.notnull(df['LotFrontage']), 'LotFrontage'].std()

print(f"Lot Frontage mean : {lot_frontage_mean}") # Mean
print(f"Lot Frontage median : {lot_frontage_median}") # Median
print(f"Lot Frontage Standard Deviation : {lot_frontage_std}") # Standard Deviation
# Out:
# Lot Frontage mean : 69.30579531442663
# Lot Frontage median : 68.0
# Lot Frontage Standard Deviation : 23.34490470692737

# %%
# Crosstab between MSZoning and LotFrontage
pd.crosstab(df['MSZoning'], df['LotFrontage'])
# Out:
# LotFrontage  21.0   22.0   24.0   25.0   26.0   28.0   30.0   31.0   32.0   \
# MSZoning
# C (all)          0      0      0      0      0      0      0      0      0
# FV               0      0     15      1      0      0      8      0      2
# RH               0      0      0      0      3      0      0      0      0
# RL               0      1     18      0      0      1      2      0      1
# RM              50      0     16      0      0      0      1      1      5
#
# LotFrontage  33.0   ...  152.0  153.0  155.0  160.0  168.0  174.0  182.0  \
# MSZoning            ...
# C (all)          0  ...      0      0      0      0      0      0      0
# FV               0  ...      0      0      0      0      0      0      0
# RH               1  ...      0      0      0      0      0      0      0
# RL               0  ...      1      0      1      3      1      2      1
# RM               2  ...      0      1      0      0      0      0      0
#
# LotFrontage  195.0  200.0  313.0
# MSZoning
# C (all)          0      0      0
# FV               0      0      0
# RH               0      0      0
# RL               1      1      2
# RM               0      0      0
#
# [5 rows x 128 columns]

# %%
# Scatter Plot between MSZoning and LotFrontage
plt.scatter(df['MSZoning'], df['LotFrontage'], color = 'c', alpha = 0.2);

plt.title('Lot Frontage Vs MS Zoning')
plt.xlabel('MS Zoning')
plt.ylabel('Lot Frontage')

plt.show()

# %% [markdown]
# After observing the above graphs, it seems clear that there is no clear relationship between Lot Frontage and the type of house.

# %%
# Scatter Plot between LotArea and Lot Frontage
plt.scatter(df['LotArea'], df['LotFrontage'], color = 'c', alpha = 0.1);

plt.title('Lot Frontage vs Lot Area')
plt.xlabel('Lot Area')
plt.ylabel('Lot Frontage')

plt.show()

# %%
# Scatter Plot between LotArea and Lot Frontage Excluding Few Outlier from Lot Area
plt.scatter(df.loc[df['LotArea'] <= 50000, 'LotArea'], df.loc[df['LotArea'] <= 50000, 'LotFrontage'], color = 'c', alpha = 0.1);

plt.title('Lot Frontage vs Lot Area (Excluding outliers)')
plt.xlabel('Lot Area')
plt.ylabel('Lot Frontage')

plt.show()

# %% [markdown]
# It is very clear the there is a linear relationship between Lot Area and Lot Frontage. I will try to use a Linear Regression Model to fit an accurate line to this graph which will help predict the missing Lot Frontage values.

# %% [markdown]
# ### Linear Regression on Lot Frontage

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# Setting features matrix X with only one feature ie LotArea
X = df.loc[pd.notnull(df['LotFrontage']), 'LotArea'].to_numpy().astype('int64').reshape(-1, 1)

# Setting prediction matrix y with LotFrontage feature
y = df.loc[pd.notnull(df['LotFrontage']), 'LotFrontage'].ravel().astype('int64').reshape(-1, 1)

# Greating Linear Regression model
lr_1 = LinearRegression()

# Train model (with all valid training examples)
lr_1.fit(X, y)

# Checking the performance of the trained model
for i in range(10):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
    print('Score for linear regression model - version 1 - Trial {0} : {1:.2f}'.format(i + 1, lr_1.score(X_test, y_test)))

# Getting Predictions
prediction_y = lr_1.predict(X)

# Plot the Predictions
plt.scatter(df['LotArea'], df['LotFrontage'], color = 'c', alpha = 0.1);
plt.plot(X, prediction_y, color = 'k')

plt.title('Lot Frontage vs Lot Area')
plt.xlabel('Lot Area')
plt.ylabel('Lot Frontage')

plt.show()
# Out:
# Score for linear regression model - version 1 - Trial 1 : 0.31
# Score for linear regression model - version 1 - Trial 2 : -0.01
# Score for linear regression model - version 1 - Trial 3 : 0.22
# Score for linear regression model - version 1 - Trial 4 : -0.12
# Score for linear regression model - version 1 - Trial 5 : 0.31
# Score for linear regression model - version 1 - Trial 6 : -0.04
# Score for linear regression model - version 1 - Trial 7 : 0.29
# Score for linear regression model - version 1 - Trial 8 : 0.38
# Score for linear regression model - version 1 - Trial 9 : 0.18
# Score for linear regression model - version 1 - Trial 10 : 0.17

# %% [markdown]
# It seems that few outliers in the data set are causing the model to underfit. Excluding them may help improve the model performance.

# %%
# Setting features matrix X with only one feature ie LotArea without outliers
X = df.loc[pd.notnull(df['LotFrontage']) & (df['LotArea'] <= 25000), 'LotArea'].to_numpy().astype('int64').reshape(-1, 1)

# Setting prediction matrix y with LotFrontage feature without outliers
y = df.loc[pd.notnull(df['LotFrontage']) & (df['LotArea'] <= 25000), 'LotFrontage'].ravel().astype('int64').reshape(-1, 1)

# Greating Linear Regression model
lr_2 = LinearRegression()

# Train model (with all valid training examples and without outliers)
lr_2.fit(X, y)

# Checking the performance of the trained model
for i in range(10):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
    print('Score for linear regression model - version 2 - Trail {0} : {1:.2f}'.format(i + 1, lr_2.score(X_test, y_test)))

# Getting Predictions
prediction_y = lr_2.predict(X)
# Out:
# Score for linear regression model - version 2 - Trail 1 : 0.47
# Score for linear regression model - version 2 - Trail 2 : 0.50
# Score for linear regression model - version 2 - Trail 3 : 0.43
# Score for linear regression model - version 2 - Trail 4 : 0.53
# Score for linear regression model - version 2 - Trail 5 : 0.47
# Score for linear regression model - version 2 - Trail 6 : 0.45
# Score for linear regression model - version 2 - Trail 7 : 0.38
# Score for linear regression model - version 2 - Trail 8 : 0.46
# Score for linear regression model - version 2 - Trail 9 : 0.38
# Score for linear regression model - version 2 - Trail 10 : 0.45

# %%
# Plot predictions
# Plot without outiers
plt.scatter(df.loc[df['LotArea'] <= 25000, 'LotArea'], df.loc[df['LotArea'] <= 25000, 'LotFrontage'], color = 'c', alpha = 0.1);
plt.plot(X, prediction_y, color = 'k');
plt.title('Lot Frontage vs Lot Area (Excluding outliers)')
plt.xlabel('Lot Area')
plt.ylabel('Lot Frontage')
plt.show()

# %%
# Plot with outliers (Model is still without outliers)
plt.scatter(df['LotArea'], df['LotFrontage'], color = 'c', alpha = 0.1);
plt.plot(X, prediction_y, color = 'k');
plt.title('Lot Frontage vs Lot Area')
plt.xlabel('Lot Area')
plt.ylabel('Lot Frontage')
plt.show()

# %% [markdown]
# This seems to be a much better fit to the training data. However I will deal with outliers separately to avoid impractical entries. Our model is trainded only for houses with lot area less than 25000. For houses with  lot area more that 25000 we will use median as it seems to best represent the data.

# %%
# Checking out the number of outlying houses (wrt LotArea) having  missing Lot Frontage
df[pd.isnull(df['LotFrontage']) & (df['LotArea'] > 25000)]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 250           50       RL          NaN   159000   Pave   NaN      IR2
# 336          190       RL          NaN   164660   Grvl   NaN      IR1
# 385           60       RL          NaN    53107   Pave   NaN      IR2
# 458           20       RL          NaN    53227   Pave   NaN      IR1
# 530           20       RL          NaN    32668   Pave   NaN      IR1
# 707           20       RL          NaN   115149   Pave   NaN      IR2
# 829           60       RL          NaN    28698   Pave   NaN      IR2
# 1058          60       RL          NaN    29959   Pave   NaN      IR2
# 1191         190       RL          NaN    32463   Pave   NaN      Reg
# 1288          20       RL          NaN    36500   Pave   NaN      IR1
# 1384          30       RL          NaN    25339   Pave   NaN      Reg
# 1397          20       RL          NaN    57200   Pave   NaN      IR1
# 1447          20       RL          NaN    26142   Pave   NaN      IR1
# 1946          20       RL          NaN    31220   Pave   NaN      IR1
# 1948          20       RL          NaN    47280   Pave   NaN      IR1
# 2251          70       RM          NaN    56600   Pave   NaN      IR1
# 2568          20       RL          NaN    25485   Pave   NaN      IR1
# 2618          20       RL          NaN    39384   Pave   NaN      IR1
# 2901          20       RL          NaN    50102   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                    ...
# 250          Low    AllPub   CulDSac  ...        0    NaN   NaN        Shed
# 336          HLS    AllPub    Corner  ...        0    NaN   NaN        Shed
# 385          Low    AllPub    Corner  ...        0    NaN   NaN         NaN
# 458          Low    AllPub   CulDSac  ...        0    NaN   NaN         NaN
# 530          Lvl    AllPub   CulDSac  ...        0    NaN   NaN         NaN
# 707          Low    AllPub   CulDSac  ...        0    NaN   NaN         NaN
# 829          Low    AllPub   CulDSac  ...        0    NaN   NaN         NaN
# 1058         Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 1191         Low    AllPub    Inside  ...        0    NaN   NaN         NaN
# 1288         Low    AllPub    Inside  ...        0    NaN   NaN         NaN
# 1384         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 1397         Bnk    AllPub    Inside  ...        0    NaN   NaN         NaN
# 1447         Lvl    AllPub   CulDSac  ...        0    NaN   NaN         NaN
# 1946         Bnk       NaN       FR2  ...        0    NaN   NaN        Shed
# 1948         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2251         Low    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2568         Lvl    AllPub   CulDSac  ...        0    NaN   NaN         NaN
# 2618         Low    AllPub   CulDSac  ...        0    NaN   NaN         NaN
# 2901         Low    AllPub    Inside  ...        0    NaN   NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 250      500      6    2007        WD         Normal     277000
# 336      700      8    2008        WD         Normal     228950
# 385        0      6    2007        WD         Normal     240000
# 458        0      3    2008        WD         Normal     256000
# 530        0      3    2007        WD         Alloca     200624
# 707        0      6    2007        WD         Normal     302000
# 829        0      6    2009        WD        Abnorml     185000
# 1058       0      1    2009        WD         Normal     248000
# 1191       0      3    2007        WD         Normal     168000
# 1288       0      6    2006        WD         Normal     190000
# 1384       0      8    2007        WD         Normal     112000
# 1397       0      6    2010        WD         Normal     160000
# 1447       0      4    2010        WD         Normal     157900
# 1946     750      5    2008        WD         Normal         -1
# 1948       0      7    2008        WD         Family         -1
# 2251       0      1    2008        WD         Normal         -1
# 2568       0      5    2007        WD         Normal         -1
# 2618       0     10    2006        WD        Abnorml         -1
# 2901       0      3    2006        WD         Alloca         -1
#
# [19 rows x 80 columns]

# %% [markdown]
# There are only 19 house belonging to this category, hence it would be most suitable to fill in these values using median.

# %%
# Setting these values to the median
outlier_median = df.loc[pd.notnull(df['LotFrontage']) & (df['LotArea'] > 25000), 'LotFrontage'].median()
df.loc[pd.isnull(df['LotFrontage']) & (df['LotArea'] > 25000), 'LotFrontage'] = outlier_median
print(f"Outlier Median : {outlier_median}")
# Out:
# Outlier Median : 100.0

# %%
# Outlier values have been filled in
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 1 to 2919
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     2919 non-null   int64
#  1   MSZoning       2919 non-null   object
#  2   LotFrontage    2452 non-null   float64
#  3   LotArea        2919 non-null   int64
#  4   Street         2919 non-null   object
#  5   Alley          198 non-null    object
#  6   LotShape       2919 non-null   object
#  7   LandContour    2919 non-null   object
#  8   Utilities      2917 non-null   object
#  9   LotConfig      2919 non-null   object
#  10  LandSlope      2919 non-null   object
#  11  Neighborhood   2919 non-null   object
#  12  Condition1     2919 non-null   object
#  13  Condition2     2919 non-null   object
#  14  BldgType       2919 non-null   object
#  15  HouseStyle     2919 non-null   object
#  16  OverallQual    2919 non-null   int64
#  17  OverallCond    2919 non-null   int64
#  18  YearBuilt      2919 non-null   int64
#  19  YearRemodAdd   2919 non-null   int64
#  20  RoofStyle      2919 non-null   object
#  21  RoofMatl       2919 non-null   object
#  22  Exterior1st    2918 non-null   object
#  23  Exterior2nd    2918 non-null   object
#  24  MasVnrType     2895 non-null   object
#  25  MasVnrArea     2896 non-null   float64
#  26  ExterQual      2919 non-null   object
#  27  ExterCond      2919 non-null   object
#  28  Foundation     2919 non-null   object
#  29  BsmtQual       2838 non-null   object
#  30  BsmtCond       2837 non-null   object
#  31  BsmtExposure   2837 non-null   object
#  32  BsmtFinType1   2840 non-null   object
#  33  BsmtFinSF1     2918 non-null   float64
#  34  BsmtFinType2   2839 non-null   object
#  35  BsmtFinSF2     2918 non-null   float64
#  36  BsmtUnfSF      2918 non-null   float64
#  37  TotalBsmtSF    2918 non-null   float64
#  38  Heating        2919 non-null   object
#  39  HeatingQC      2919 non-null   object
#  40  CentralAir     2919 non-null   object
#  41  Electrical     2918 non-null   object
#  42  1stFlrSF       2919 non-null   int64
#  43  2ndFlrSF       2919 non-null   int64
#  44  LowQualFinSF   2919 non-null   int64
#  45  GrLivArea      2919 non-null   int64
#  46  BsmtFullBath   2917 non-null   float64
#  47  BsmtHalfBath   2917 non-null   float64
#  48  FullBath       2919 non-null   int64
#  49  HalfBath       2919 non-null   int64
#  50  BedroomAbvGr   2919 non-null   int64
#  51  KitchenAbvGr   2919 non-null   int64
#  52  KitchenQual    2918 non-null   object
#  53  TotRmsAbvGrd   2919 non-null   int64
#  54  Functional     2917 non-null   object
#  55  Fireplaces     2919 non-null   int64
#  56  FireplaceQu    1499 non-null   object
#  57  GarageType     2762 non-null   object
#  58  GarageYrBlt    2760 non-null   float64
#  59  GarageFinish   2760 non-null   object
#  60  GarageCars     2918 non-null   float64
#  61  GarageArea     2918 non-null   float64
#  62  GarageQual     2760 non-null   object
#  63  GarageCond     2760 non-null   object
#  64  PavedDrive     2919 non-null   object
#  65  WoodDeckSF     2919 non-null   int64
#  66  OpenPorchSF    2919 non-null   int64
#  67  EnclosedPorch  2919 non-null   int64
#  68  3SsnPorch      2919 non-null   int64
#  69  ScreenPorch    2919 non-null   int64
#  70  PoolArea       2919 non-null   int64
#  71  PoolQC         10 non-null     object
#  72  Fence          571 non-null    object
#  73  MiscFeature    105 non-null    object
#  74  MiscVal        2919 non-null   int64
#  75  MoSold         2919 non-null   int64
#  76  YrSold         2919 non-null   int64
#  77  SaleType       2918 non-null   object
#  78  SaleCondition  2919 non-null   object
#  79  SalePrice      2919 non-null   int64
# dtypes: float64(11), int64(26), object(43)
# memory usage: 1.8+ MB

# %%
# Calculating predictions
X = df.loc[pd.isnull(df['LotFrontage']), 'LotArea'].to_numpy().astype('int64').reshape(-1, 1)
prediction_LotFrontage = lr_2.predict(X)

# Setting lot frontage values for houses with lot area <= 25000
df.loc[pd.isnull(df['LotFrontage']) & (df['LotArea'] <= 25000), 'LotFrontage'] = prediction_LotFrontage

# %%
# Checking to see the precitions fit the graph
# Scatter Plot between LotArea and Lot Frontage
plt.scatter(df['LotArea'], df['LotFrontage'], color = 'c', alpha = 0.1);

plt.title('Lot Frontage vs Lot Area (After filling in missing values)')
plt.xlabel('Lot Area')
plt.ylabel('Lot Frontage')

plt.show()

# %% [markdown]
# The predicted values seem to fit the original graph well. Hence the regression model is working properly (with outliers set to median).

# %%
# Lot Frontage value is now complete
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 1 to 2919
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     2919 non-null   int64
#  1   MSZoning       2919 non-null   object
#  2   LotFrontage    2919 non-null   float64
#  3   LotArea        2919 non-null   int64
#  4   Street         2919 non-null   object
#  5   Alley          198 non-null    object
#  6   LotShape       2919 non-null   object
#  7   LandContour    2919 non-null   object
#  8   Utilities      2917 non-null   object
#  9   LotConfig      2919 non-null   object
#  10  LandSlope      2919 non-null   object
#  11  Neighborhood   2919 non-null   object
#  12  Condition1     2919 non-null   object
#  13  Condition2     2919 non-null   object
#  14  BldgType       2919 non-null   object
#  15  HouseStyle     2919 non-null   object
#  16  OverallQual    2919 non-null   int64
#  17  OverallCond    2919 non-null   int64
#  18  YearBuilt      2919 non-null   int64
#  19  YearRemodAdd   2919 non-null   int64
#  20  RoofStyle      2919 non-null   object
#  21  RoofMatl       2919 non-null   object
#  22  Exterior1st    2918 non-null   object
#  23  Exterior2nd    2918 non-null   object
#  24  MasVnrType     2895 non-null   object
#  25  MasVnrArea     2896 non-null   float64
#  26  ExterQual      2919 non-null   object
#  27  ExterCond      2919 non-null   object
#  28  Foundation     2919 non-null   object
#  29  BsmtQual       2838 non-null   object
#  30  BsmtCond       2837 non-null   object
#  31  BsmtExposure   2837 non-null   object
#  32  BsmtFinType1   2840 non-null   object
#  33  BsmtFinSF1     2918 non-null   float64
#  34  BsmtFinType2   2839 non-null   object
#  35  BsmtFinSF2     2918 non-null   float64
#  36  BsmtUnfSF      2918 non-null   float64
#  37  TotalBsmtSF    2918 non-null   float64
#  38  Heating        2919 non-null   object
#  39  HeatingQC      2919 non-null   object
#  40  CentralAir     2919 non-null   object
#  41  Electrical     2918 non-null   object
#  42  1stFlrSF       2919 non-null   int64
#  43  2ndFlrSF       2919 non-null   int64
#  44  LowQualFinSF   2919 non-null   int64
#  45  GrLivArea      2919 non-null   int64
#  46  BsmtFullBath   2917 non-null   float64
#  47  BsmtHalfBath   2917 non-null   float64
#  48  FullBath       2919 non-null   int64
#  49  HalfBath       2919 non-null   int64
#  50  BedroomAbvGr   2919 non-null   int64
#  51  KitchenAbvGr   2919 non-null   int64
#  52  KitchenQual    2918 non-null   object
#  53  TotRmsAbvGrd   2919 non-null   int64
#  54  Functional     2917 non-null   object
#  55  Fireplaces     2919 non-null   int64
#  56  FireplaceQu    1499 non-null   object
#  57  GarageType     2762 non-null   object
#  58  GarageYrBlt    2760 non-null   float64
#  59  GarageFinish   2760 non-null   object
#  60  GarageCars     2918 non-null   float64
#  61  GarageArea     2918 non-null   float64
#  62  GarageQual     2760 non-null   object
#  63  GarageCond     2760 non-null   object
#  64  PavedDrive     2919 non-null   object
#  65  WoodDeckSF     2919 non-null   int64
#  66  OpenPorchSF    2919 non-null   int64
#  67  EnclosedPorch  2919 non-null   int64
#  68  3SsnPorch      2919 non-null   int64
#  69  ScreenPorch    2919 non-null   int64
#  70  PoolArea       2919 non-null   int64
#  71  PoolQC         10 non-null     object
#  72  Fence          571 non-null    object
#  73  MiscFeature    105 non-null    object
#  74  MiscVal        2919 non-null   int64
#  75  MoSold         2919 non-null   int64
#  76  YrSold         2919 non-null   int64
#  77  SaleType       2918 non-null   object
#  78  SaleCondition  2919 non-null   object
#  79  SalePrice      2919 non-null   int64
# dtypes: float64(11), int64(26), object(43)
# memory usage: 1.8+ MB

# %% [markdown]
# ## Feature : Alley

# %%
# Houses with missing values in this feature
df[pd.isnull(df['Alley'])]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 2915         160       RM         21.0     1936   Pave   NaN      Reg
# 2916         160       RM         21.0     1894   Pave   NaN      Reg
# 2917          20       RL        160.0    20000   Pave   NaN      Reg
# 2918          85       RL         62.0    10441   Pave   NaN      Reg
# 2919          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# 1            Lvl    AllPub    Inside  ...        0     NA     NA          NA
# 2            Lvl    AllPub       FR2  ...        0     NA     NA          NA
# 3            Lvl    AllPub    Inside  ...        0     NA     NA          NA
# 4            Lvl    AllPub    Corner  ...        0     NA     NA          NA
# 5            Lvl    AllPub       FR2  ...        0     NA     NA          NA
# ...          ...       ...       ...  ...      ...    ...    ...         ...
# 2915         Lvl    AllPub    Inside  ...        0     NA     NA          NA
# 2916         Lvl    AllPub    Inside  ...        0     NA     NA          NA
# 2917         Lvl    AllPub    Inside  ...        0     NA     NA          NA
# 2918         Lvl    AllPub    Inside  ...        0     NA  MnPrv        Shed
# 2919         Lvl    AllPub    Inside  ...        0     NA     NA          NA
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1          0      2    2008        WD         Normal     208500
# 2          0      5    2007        WD         Normal     181500
# 3          0      9    2008        WD         Normal     223500
# 4          0      2    2006        WD        Abnorml     140000
# 5          0     12    2008        WD         Normal     250000
# ...      ...    ...     ...       ...            ...        ...
# 2915       0      6    2006        WD         Normal         -1
# 2916       0      4    2006        WD        Abnorml         -1
# 2917       0      9    2006        WD        Abnorml         -1
# 2918     700      7    2006        WD         Normal         -1
# 2919       0     11    2006        WD         Normal         -1
#
# [2721 rows x 80 columns]

# %%
df[pd.notnull(df['Alley'])]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 22            45       RM         57.0     7449   Pave  Grvl      Reg
# 31            70  C (all)         50.0     8500   Pave  Pave      Reg
# 57           160       FV         24.0     2645   Pave  Pave      Reg
# 80            50       RM         60.0    10440   Pave  Grvl      Reg
# 88           160       FV         40.0     3951   Pave  Pave      Reg
# ...          ...      ...          ...      ...    ...   ...      ...
# 2791          20       RM         65.0     9750   Pave  Grvl      Reg
# 2796          30       RL         50.0    11672   Pave  Pave      IR2
# 2798          50       RM         60.0    10320   Pave  Grvl      Reg
# 2871          50       RL         45.0     8248   Pave  Grvl      Reg
# 2872          30       RL         60.0     8088   Pave  Grvl      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# 22           Bnk    AllPub    Inside  ...        0     NA  GdPrv          NA
# 31           Lvl    AllPub    Inside  ...        0     NA  MnPrv          NA
# 57           Lvl    AllPub    Inside  ...        0     NA     NA          NA
# 80           Lvl    AllPub    Corner  ...        0     NA  MnPrv          NA
# 88           Lvl    AllPub    Corner  ...        0     NA     NA          NA
# ...          ...       ...       ...  ...      ...    ...    ...         ...
# 2791         Lvl    AllPub    Inside  ...        0     NA     NA        Gar2
# 2796         Lvl    AllPub    Inside  ...        0     NA     NA          NA
# 2798         Lvl    AllPub    Inside  ...        0     NA     NA          NA
# 2871         Lvl    AllPub    Inside  ...        0     NA     NA          NA
# 2872         Lvl    AllPub    Inside  ...        0     NA     NA          NA
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 22         0      6    2007        WD         Normal     139400
# 31         0      7    2008        WD         Normal      40000
# 57         0      8    2009        WD        Abnorml     172500
# 80         0      5    2009        WD         Normal     110000
# 88         0      6    2009       New        Partial     164500
# ...      ...    ...     ...       ...            ...        ...
# 2791    4500      7    2006        WD         Normal         -1
# 2796       0      7    2006        WD         Normal         -1
# 2798       0     10    2006        WD        Abnorml         -1
# 2871       0      9    2006       COD        Abnorml         -1
# 2872       0      2    2006     ConLD         Normal         -1
#
# [198 rows x 80 columns]

# %%
# Crosstab between Street and Alley
pd.crosstab(df['Street'], df['Alley'])
# Out:
# Alley   Grvl  Pave
# Street
# Pave     120    78

# %% [markdown]
# I will set the default entry as no alley access (NA).

# %%
# Setting missing values to NA
df.loc[pd.isnull(df['Alley']), 'Alley'] = 'NA'

# %%
# Checking if update done as expected
df['Alley'].value_counts()
# Out:
# NA      2721
# Grvl     120
# Pave      78
# Name: Alley, dtype: int64

# %%
# Alley feature is now complete
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 1 to 2919
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     2919 non-null   int64
#  1   MSZoning       2919 non-null   object
#  2   LotFrontage    2919 non-null   float64
#  3   LotArea        2919 non-null   int64
#  4   Street         2919 non-null   object
#  5   Alley          2919 non-null   object
#  6   LotShape       2919 non-null   object
#  7   LandContour    2919 non-null   object
#  8   Utilities      2919 non-null   object
#  9   LotConfig      2919 non-null   object
#  10  LandSlope      2919 non-null   object
#  11  Neighborhood   2919 non-null   object
#  12  Condition1     2919 non-null   object
#  13  Condition2     2919 non-null   object
#  14  BldgType       2919 non-null   object
#  15  HouseStyle     2919 non-null   object
#  16  OverallQual    2919 non-null   int64
#  17  OverallCond    2919 non-null   int64
#  18  YearBuilt      2919 non-null   int64
#  19  YearRemodAdd   2919 non-null   int64
#  20  RoofStyle      2919 non-null   object
#  21  RoofMatl       2919 non-null   object
#  22  Exterior1st    2919 non-null   object
#  23  Exterior2nd    2919 non-null   object
#  24  MasVnrType     2919 non-null   object
#  25  MasVnrArea     2919 non-null   float64
#  26  ExterQual      2919 non-null   object
#  27  ExterCond      2919 non-null   object
#  28  Foundation     2919 non-null   object
#  29  BsmtQual       2919 non-null   object
#  30  BsmtCond       2919 non-null   object
#  31  BsmtExposure   2919 non-null   object
#  32  BsmtFinType1   2919 non-null   object
#  33  BsmtFinSF1     2919 non-null   float64
#  34  BsmtFinType2   2919 non-null   object
#  35  BsmtFinSF2     2919 non-null   float64
#  36  BsmtUnfSF      2919 non-null   float64
#  37  TotalBsmtSF    2919 non-null   float64
#  38  Heating        2919 non-null   object
#  39  HeatingQC      2919 non-null   object
#  40  CentralAir     2919 non-null   object
#  41  Electrical     2919 non-null   object
#  42  1stFlrSF       2919 non-null   int64
#  43  2ndFlrSF       2919 non-null   int64
#  44  LowQualFinSF   2919 non-null   int64
#  45  GrLivArea      2919 non-null   int64
#  46  BsmtFullBath   2919 non-null   float64
#  47  BsmtHalfBath   2919 non-null   float64
#  48  FullBath       2919 non-null   int64
#  49  HalfBath       2919 non-null   int64
#  50  BedroomAbvGr   2919 non-null   int64
#  51  KitchenAbvGr   2919 non-null   int64
#  52  KitchenQual    2919 non-null   object
#  53  TotRmsAbvGrd   2919 non-null   int64
#  54  Functional     2919 non-null   object
#  55  Fireplaces     2919 non-null   int64
#  56  FireplaceQu    2919 non-null   object
#  57  GarageType     2919 non-null   object
#  58  GarageYrBlt    2919 non-null   float64
#  59  GarageFinish   2919 non-null   object
#  60  GarageCars     2919 non-null   float64
#  61  GarageArea     2919 non-null   float64
#  62  GarageQual     2919 non-null   object
#  63  GarageCond     2919 non-null   object
#  64  PavedDrive     2919 non-null   object
#  65  WoodDeckSF     2919 non-null   int64
#  66  OpenPorchSF    2919 non-null   int64
#  67  EnclosedPorch  2919 non-null   int64
#  68  3SsnPorch      2919 non-null   int64
#  69  ScreenPorch    2919 non-null   int64
#  70  PoolArea       2919 non-null   int64
#  71  PoolQC         2919 non-null   object
#  72  Fence          2919 non-null   object
#  73  MiscFeature    2919 non-null   object
#  74  MiscVal        2919 non-null   int64
#  75  MoSold         2919 non-null   int64
#  76  YrSold         2919 non-null   int64
#  77  SaleType       2919 non-null   object
#  78  SaleCondition  2919 non-null   object
#  79  SalePrice      2919 non-null   int64
# dtypes: float64(11), int64(26), object(43)
# memory usage: 1.8+ MB

# %% [markdown]
# ## Feature : Utilities

# %%
# Checking out houses with missing Utilities
df[pd.isnull(df['Utilities'])]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1916          30       RM        109.0    21780   Grvl   NaN      Reg
# 1946          20       RL        100.0    31220   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                    ...
# 1916         Lvl       NaN    Inside  ...        0    NaN   NaN         NaN
# 1946         Bnk       NaN       FR2  ...        0    NaN   NaN        Shed
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1916       0      3    2009     ConLD         Normal         -1
# 1946     750      5    2008        WD         Normal         -1
#
# [2 rows x 80 columns]

# %%
# Observing frequency of different Utilities entries
df['Utilities'].value_counts()
# Out:
# AllPub    2916
# NoSeWa       1
# Name: Utilities, dtype: int64

# %%
# Observing frequency of different Utilities entries (normalized)
df['Utilities'].value_counts(normalize = True) * 100
# Out:
# AllPub    99.965718
# NoSeWa     0.034282
# Name: Utilities, dtype: float64

# %% [markdown]
# Since more than 99.9% of the data has access to all public utitlities. We will set the missing values to all public. Since the feature is so biased towards this option and there are only two missing values, this should be a good choice.

# %%
# Setting missing values to 'AllPub'
df.loc[pd.isnull(df['Utilities']), 'Utilities'] = 'AllPub'

# Checking to see update done properly
df['Utilities'].value_counts()
# Out:
# AllPub    2918
# NoSeWa       1
# Name: Utilities, dtype: int64

# %%
# Utilities feature is now ready
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 1 to 2919
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     2919 non-null   int64
#  1   MSZoning       2919 non-null   object
#  2   LotFrontage    2919 non-null   float64
#  3   LotArea        2919 non-null   int64
#  4   Street         2919 non-null   object
#  5   Alley          198 non-null    object
#  6   LotShape       2919 non-null   object
#  7   LandContour    2919 non-null   object
#  8   Utilities      2919 non-null   object
#  9   LotConfig      2919 non-null   object
#  10  LandSlope      2919 non-null   object
#  11  Neighborhood   2919 non-null   object
#  12  Condition1     2919 non-null   object
#  13  Condition2     2919 non-null   object
#  14  BldgType       2919 non-null   object
#  15  HouseStyle     2919 non-null   object
#  16  OverallQual    2919 non-null   int64
#  17  OverallCond    2919 non-null   int64
#  18  YearBuilt      2919 non-null   int64
#  19  YearRemodAdd   2919 non-null   int64
#  20  RoofStyle      2919 non-null   object
#  21  RoofMatl       2919 non-null   object
#  22  Exterior1st    2918 non-null   object
#  23  Exterior2nd    2918 non-null   object
#  24  MasVnrType     2895 non-null   object
#  25  MasVnrArea     2896 non-null   float64
#  26  ExterQual      2919 non-null   object
#  27  ExterCond      2919 non-null   object
#  28  Foundation     2919 non-null   object
#  29  BsmtQual       2838 non-null   object
#  30  BsmtCond       2837 non-null   object
#  31  BsmtExposure   2837 non-null   object
#  32  BsmtFinType1   2840 non-null   object
#  33  BsmtFinSF1     2918 non-null   float64
#  34  BsmtFinType2   2839 non-null   object
#  35  BsmtFinSF2     2918 non-null   float64
#  36  BsmtUnfSF      2918 non-null   float64
#  37  TotalBsmtSF    2918 non-null   float64
#  38  Heating        2919 non-null   object
#  39  HeatingQC      2919 non-null   object
#  40  CentralAir     2919 non-null   object
#  41  Electrical     2918 non-null   object
#  42  1stFlrSF       2919 non-null   int64
#  43  2ndFlrSF       2919 non-null   int64
#  44  LowQualFinSF   2919 non-null   int64
#  45  GrLivArea      2919 non-null   int64
#  46  BsmtFullBath   2917 non-null   float64
#  47  BsmtHalfBath   2917 non-null   float64
#  48  FullBath       2919 non-null   int64
#  49  HalfBath       2919 non-null   int64
#  50  BedroomAbvGr   2919 non-null   int64
#  51  KitchenAbvGr   2919 non-null   int64
#  52  KitchenQual    2918 non-null   object
#  53  TotRmsAbvGrd   2919 non-null   int64
#  54  Functional     2917 non-null   object
#  55  Fireplaces     2919 non-null   int64
#  56  FireplaceQu    1499 non-null   object
#  57  GarageType     2762 non-null   object
#  58  GarageYrBlt    2760 non-null   float64
#  59  GarageFinish   2760 non-null   object
#  60  GarageCars     2918 non-null   float64
#  61  GarageArea     2918 non-null   float64
#  62  GarageQual     2760 non-null   object
#  63  GarageCond     2760 non-null   object
#  64  PavedDrive     2919 non-null   object
#  65  WoodDeckSF     2919 non-null   int64
#  66  OpenPorchSF    2919 non-null   int64
#  67  EnclosedPorch  2919 non-null   int64
#  68  3SsnPorch      2919 non-null   int64
#  69  ScreenPorch    2919 non-null   int64
#  70  PoolArea       2919 non-null   int64
#  71  PoolQC         10 non-null     object
#  72  Fence          571 non-null    object
#  73  MiscFeature    105 non-null    object
#  74  MiscVal        2919 non-null   int64
#  75  MoSold         2919 non-null   int64
#  76  YrSold         2919 non-null   int64
#  77  SaleType       2918 non-null   object
#  78  SaleCondition  2919 non-null   object
#  79  SalePrice      2919 non-null   int64
# dtypes: float64(11), int64(26), object(43)
# memory usage: 1.8+ MB

# %% [markdown]
# ## Feature : Exterior Covering

# %%
# Checking houses with missing Exterior Covering values
df.loc[pd.isnull(df['Exterior1st']) | pd.isnull(df['Exterior2nd'])]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 2152          30       RL         85.0    19550   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                    ...
# 2152         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 2152       0      1    2008        WD         Normal         -1
#
# [1 rows x 80 columns]

# %%
# Checking the frequecy of different housing exteriors
print(df['Exterior1st'].value_counts(), "\n")
print(df['Exterior2nd'].value_counts())
# Out:
# VinylSd    1025
# MetalSd     450
# HdBoard     442
# Wd Sdng     411
# Plywood     221
# CemntBd     126
# BrkFace      87
# WdShing      56
# AsbShng      44
# Stucco       43
# BrkComm       6
# Stone         2
# CBlock        2
# AsphShn       2
# ImStucc       1
# Name: Exterior1st, dtype: int64
#
# VinylSd    1014
# MetalSd     447
# HdBoard     406
# Wd Sdng     391
# Plywood     270
# CmentBd     126
# Wd Shng      81
# Stucco       47
# BrkFace      47
# AsbShng      38
# Brk Cmn      22
# ImStucc      15
# Stone         6
# AsphShn       4
# CBlock        3
# Other         1
# Name: Exterior2nd, dtype: int64

# %%
# Checking to see which year this house was built
df.loc[pd.isnull(df['Exterior1st']) | pd.isnull(df['Exterior2nd']), 'YearBuilt']
# Out:
# Id
# 2152    1940
# Name: YearBuilt, dtype: int64

# %%
# Checking to see if there is a relationship between these features
print(df.loc[df['YearBuilt'] == 1940, 'Exterior1st'].value_counts(), "\n")
print(df.loc[df['YearBuilt'] == 1940, 'Exterior2nd'].value_counts())
# Out:
# Wd Sdng    13
# MetalSd    11
# VinylSd     9
# WdShing     1
# Stucco      1
# Name: Exterior1st, dtype: int64
#
# MetalSd    12
# Wd Sdng    10
# VinylSd     9
# HdBoard     1
# Wd Shng     1
# Plywood     1
# Stucco      1
# Name: Exterior2nd, dtype: int64

# %%
# Checking to see the if there is any relationship between class of the house and the type of exteriors used
print(df.loc[df['MSSubClass'] == 30, 'Exterior1st'].value_counts(), "\n")
print(df.loc[df['MSSubClass'] == 30, 'Exterior2nd'].value_counts())
# Out:
# Wd Sdng    48
# MetalSd    41
# VinylSd    17
# Stucco     15
# WdShing     6
# AsbShng     6
# BrkFace     3
# HdBoard     1
# Plywood     1
# Name: Exterior1st, dtype: int64
#
# Wd Sdng    47
# MetalSd    37
# VinylSd    18
# Stucco     15
# Wd Shng     9
# AsbShng     6
# Plywood     3
# BrkFace     2
# HdBoard     1
# Name: Exterior2nd, dtype: int64

# %%
# Checking to see which year this house was remodeled 
df.loc[pd.isnull(df['Exterior1st']) | pd.isnull(df['Exterior2nd']), 'YearRemodAdd']
# Out:
# Id
# 2152    2007
# Name: YearRemodAdd, dtype: int64

# %%
# Checking to see if there is a relationship between these features
print(df.loc[df['YearRemodAdd'] >= 2005, 'Exterior1st'].value_counts(), "\n")
print(df.loc[df['YearRemodAdd'] >= 2005, 'Exterior2nd'].value_counts())
# Out:
# VinylSd    440
# CemntBd     61
# MetalSd     59
# Wd Sdng     35
# HdBoard     19
# WdShing      7
# Stucco       6
# Plywood      5
# BrkComm      1
# BrkFace      1
# Name: Exterior1st, dtype: int64
#
# VinylSd    437
# CmentBd     62
# MetalSd     59
# Wd Sdng     31
# HdBoard     16
# Plywood     10
# Wd Shng      8
# Stucco       6
# AsphShn      1
# Other        1
# BrkFace      1
# Brk Cmn      1
# ImStucc      1
# Name: Exterior2nd, dtype: int64

# %% [markdown]
# Initially I thought that since the house was built in 1940 it would have an exterior similar to the houses built around that time. However on further observation, the house seems to have been remodeled in 2007. Most housing built / Remodeled around this time have a VinylSd Exterior. Hence I will set the missing value to this.

# %%
# Checking to see if there is a relationship between these features (combining features)
print(df.loc[(df['YearRemodAdd'] >= 2005) & (df['MSSubClass'] == 30), 'Exterior1st'].value_counts(), "\n")
print(df.loc[(df['YearRemodAdd'] >= 2005) & (df['MSSubClass'] == 30), 'Exterior2nd'].value_counts())
# Out:
# Wd Sdng    7
# MetalSd    3
# VinylSd    3
# Stucco     1
# Name: Exterior1st, dtype: int64
#
# Wd Sdng    7
# VinylSd    3
# MetalSd    2
# Stucco     2
# Name: Exterior2nd, dtype: int64

# %% [markdown]
# On further analyis and combining more features (house class is very related to exterior used on the house), it appears the Wd Sdng would be a better choice.

# %%
# Setting housing exterior (both 1st and 2nd) to Ws Sdng
df.loc[pd.isnull(df['Exterior1st']), ['Exterior1st', 'Exterior2nd']] = 'Wd Sdng'

# %%
# Checking to see update done correctly
print(df['Exterior1st'].value_counts(), "\n")
print(df['Exterior2nd'].value_counts())
# Out:
# VinylSd    1025
# MetalSd     450
# HdBoard     442
# Wd Sdng     412
# Plywood     221
# CemntBd     126
# BrkFace      87
# WdShing      56
# AsbShng      44
# Stucco       43
# BrkComm       6
# Stone         2
# CBlock        2
# AsphShn       2
# ImStucc       1
# Name: Exterior1st, dtype: int64
#
# VinylSd    1014
# MetalSd     447
# HdBoard     406
# Wd Sdng     392
# Plywood     270
# CmentBd     126
# Wd Shng      81
# Stucco       47
# BrkFace      47
# AsbShng      38
# Brk Cmn      22
# ImStucc      15
# Stone         6
# AsphShn       4
# CBlock        3
# Other         1
# Name: Exterior2nd, dtype: int64

# %%
# Housing Exterior feature is now complete
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 1 to 2919
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     2919 non-null   int64
#  1   MSZoning       2919 non-null   object
#  2   LotFrontage    2919 non-null   float64
#  3   LotArea        2919 non-null   int64
#  4   Street         2919 non-null   object
#  5   Alley          198 non-null    object
#  6   LotShape       2919 non-null   object
#  7   LandContour    2919 non-null   object
#  8   Utilities      2919 non-null   object
#  9   LotConfig      2919 non-null   object
#  10  LandSlope      2919 non-null   object
#  11  Neighborhood   2919 non-null   object
#  12  Condition1     2919 non-null   object
#  13  Condition2     2919 non-null   object
#  14  BldgType       2919 non-null   object
#  15  HouseStyle     2919 non-null   object
#  16  OverallQual    2919 non-null   int64
#  17  OverallCond    2919 non-null   int64
#  18  YearBuilt      2919 non-null   int64
#  19  YearRemodAdd   2919 non-null   int64
#  20  RoofStyle      2919 non-null   object
#  21  RoofMatl       2919 non-null   object
#  22  Exterior1st    2919 non-null   object
#  23  Exterior2nd    2919 non-null   object
#  24  MasVnrType     2895 non-null   object
#  25  MasVnrArea     2896 non-null   float64
#  26  ExterQual      2919 non-null   object
#  27  ExterCond      2919 non-null   object
#  28  Foundation     2919 non-null   object
#  29  BsmtQual       2838 non-null   object
#  30  BsmtCond       2837 non-null   object
#  31  BsmtExposure   2837 non-null   object
#  32  BsmtFinType1   2840 non-null   object
#  33  BsmtFinSF1     2918 non-null   float64
#  34  BsmtFinType2   2839 non-null   object
#  35  BsmtFinSF2     2918 non-null   float64
#  36  BsmtUnfSF      2918 non-null   float64
#  37  TotalBsmtSF    2918 non-null   float64
#  38  Heating        2919 non-null   object
#  39  HeatingQC      2919 non-null   object
#  40  CentralAir     2919 non-null   object
#  41  Electrical     2918 non-null   object
#  42  1stFlrSF       2919 non-null   int64
#  43  2ndFlrSF       2919 non-null   int64
#  44  LowQualFinSF   2919 non-null   int64
#  45  GrLivArea      2919 non-null   int64
#  46  BsmtFullBath   2917 non-null   float64
#  47  BsmtHalfBath   2917 non-null   float64
#  48  FullBath       2919 non-null   int64
#  49  HalfBath       2919 non-null   int64
#  50  BedroomAbvGr   2919 non-null   int64
#  51  KitchenAbvGr   2919 non-null   int64
#  52  KitchenQual    2918 non-null   object
#  53  TotRmsAbvGrd   2919 non-null   int64
#  54  Functional     2917 non-null   object
#  55  Fireplaces     2919 non-null   int64
#  56  FireplaceQu    1499 non-null   object
#  57  GarageType     2762 non-null   object
#  58  GarageYrBlt    2760 non-null   float64
#  59  GarageFinish   2760 non-null   object
#  60  GarageCars     2918 non-null   float64
#  61  GarageArea     2918 non-null   float64
#  62  GarageQual     2760 non-null   object
#  63  GarageCond     2760 non-null   object
#  64  PavedDrive     2919 non-null   object
#  65  WoodDeckSF     2919 non-null   int64
#  66  OpenPorchSF    2919 non-null   int64
#  67  EnclosedPorch  2919 non-null   int64
#  68  3SsnPorch      2919 non-null   int64
#  69  ScreenPorch    2919 non-null   int64
#  70  PoolArea       2919 non-null   int64
#  71  PoolQC         10 non-null     object
#  72  Fence          571 non-null    object
#  73  MiscFeature    105 non-null    object
#  74  MiscVal        2919 non-null   int64
#  75  MoSold         2919 non-null   int64
#  76  YrSold         2919 non-null   int64
#  77  SaleType       2918 non-null   object
#  78  SaleCondition  2919 non-null   object
#  79  SalePrice      2919 non-null   int64
# dtypes: float64(11), int64(26), object(43)
# memory usage: 1.8+ MB

# %% [markdown]
# ## Feature : Masonary Veneer Type

# %%
# Housing with missing Masonary Veneer Type feature
df[pd.isnull(df['MasVnrType'])]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 235           60       RL    62.836335     7851   Pave   NaN      Reg
# 530           20       RL   100.000000    32668   Pave   NaN      IR1
# 651           60       FV    65.000000     8125   Pave   NaN      Reg
# 937           20       RL    67.000000    10083   Pave   NaN      Reg
# 974           20       FV    95.000000    11639   Pave   NaN      Reg
# 978          120       FV    35.000000     4274   Pave  Pave      IR1
# 1244          20       RL   107.000000    13891   Pave   NaN      Reg
# 1279          60       RL    75.000000     9473   Pave   NaN      Reg
# 1692          60       RL    83.337307    12891   Pave   NaN      IR1
# 1707          20       FV    90.000000     7993   Pave   NaN      IR1
# 1883          60       RL    70.000000     8749   Pave   NaN      Reg
# 1993          60       RL    62.425502     7750   Pave   NaN      Reg
# 2005          20       RL    87.000000    10037   Pave   NaN      Reg
# 2042          60       FV    61.408588     7500   Pave   NaN      Reg
# 2312          60       RL    59.000000    15810   Pave   NaN      IR1
# 2326          80       RL    79.509645    11950   Pave   NaN      IR1
# 2341          20       RL    85.000000     9965   Pave   NaN      Reg
# 2350          60       FV   112.000000    12217   Pave   NaN      IR1
# 2369         120       FV    30.000000     5330   Pave  Pave      IR2
# 2593          20       RL    68.000000     8298   Pave   NaN      IR1
# 2611          20       RL   124.000000    27697   Pave   NaN      Reg
# 2658          60       RL   103.000000    12867   Pave   NaN      IR1
# 2687          20       RL    49.000000    15218   Pave   NaN      IR1
# 2863          20       RL    75.000000     8050   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                    ...
# 235          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 530          Lvl    AllPub   CulDSac  ...        0    NaN   NaN         NaN
# 651          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 937          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 974          Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 978          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 1244         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 1279         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 1692         Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 1707         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 1883         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 1993         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2005         Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 2042         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2312         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2326         Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 2341         Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 2350         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2369         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2593         HLS    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2611         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2658         Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 2687         Lvl    AllPub   CulDSac  ...        0    NaN   NaN         NaN
# 2863         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 235        0      5    2010        WD         Normal     216500
# 530        0      3    2007        WD         Alloca     200624
# 651        0      5    2008        WD         Normal     205950
# 937        0      8    2009        WD         Normal     184900
# 974        0     12    2008       New        Partial     182000
# 978        0     11    2007       New        Partial     199900
# 1244       0      9    2006       New        Partial     465000
# 1279       0      3    2008        WD         Normal     237000
# 1692       0      7    2009        WD         Normal         -1
# 1707       0     10    2009       New        Partial         -1
# 1883       0     11    2009        WD         Normal         -1
# 1993       0      4    2008        WD         Normal         -1
# 2005       0      8    2008        WD         Normal         -1
# 2042       0      4    2008        WD         Normal         -1
# 2312       0      5    2007       New        Partial         -1
# 2326       0     10    2007        WD         Normal         -1
# 2341       0      9    2007       New        Partial         -1
# 2350       0     12    2007       New        Partial         -1
# 2369       0      7    2007       New        Partial         -1
# 2593       0      9    2007       New        Partial         -1
# 2611       0     11    2007       COD        Abnorml         -1
# 2658       0      7    2006       New        Partial         -1
# 2687       0      9    2006       New        Partial         -1
# 2863       0      4    2006        WD         Normal         -1
#
# [24 rows x 80 columns]

# %%
# Distribution of different entries
df['MasVnrType'].value_counts()
# Out:
# None       1742
# BrkFace     879
# Stone       249
# BrkCmn       25
# Name: MasVnrType, dtype: int64

# %%
# Crosstab between MSSubClass and MasVnrType
pd.crosstab(df['MSSubClass'], df['MasVnrType'])
# Out:
# MasVnrType  BrkCmn  BrkFace  None  Stone
# MSSubClass
# 20              15      359   566    128
# 30               1        3   132      3
# 40               0        0     6      0
# 45               0        0    18      0
# 50               2       21   260      4
# 60               4      251   262     48
# 70               0        0   126      2
# 75               0        1    22      0
# 80               0       61    52      4
# 85               1       15    30      2
# 90               2       35    68      4
# 120              0       72    70     38
# 150              0        0     1      0
# 160              0       52    64     12
# 180              0        5    11      1
# 190              0        4    54      3

# %% [markdown]
# It appeares that regardless of the class of the house, majority of the houses belonging to that class do not have any type of masonary veneer.

# %%
# Crosstab between Housing Exterior and MasVnrType
pd.crosstab(df['Exterior1st'], df['MasVnrType'])
# Out:
# MasVnrType   BrkCmn  BrkFace  None  Stone
# Exterior1st
# AsbShng           1        2    40      1
# AsphShn           0        0     2      0
# BrkComm           0        0     6      0
# BrkFace           0        0    84      3
# CBlock            0        0     2      0
# CemntBd           0       23    69     31
# HdBoard           7      215   207     13
# ImStucc           0        0     1      0
# MetalSd           2      117   314     17
# Plywood           3       78   130      9
# Stone             0        0     2      0
# Stucco            1        5    36      1
# VinylSd           3      352   486    166
# Wd Sdng           6       76   322      7
# WdShing           2       11    41      1

# %% [markdown]
# Again here it appears that majority of houses from all different categories have no Masonary. Hence I will set the missing values to be none (except for HdBoard).

# %%
pd.crosstab(df.loc[df['Exterior1st'] == 'HdBoard', 'MSSubClass'], df.loc[df['Exterior1st'] == 'HdBoard','MasVnrType'])
# Out:
# MasVnrType  BrkCmn  BrkFace  None  Stone
# MSSubClass
# 20               5       84   103     10
# 30               0        0     1      0
# 40               0        0     1      0
# 50               0        3     5      1
# 60               1       58    32      2
# 70               0        0     3      0
# 75               0        1     0      0
# 80               0       24    14      0
# 85               1       10    14      0
# 90               0        5    13      0
# 120              0        1    13      0
# 160              0       27     3      0
# 190              0        2     5      0

# %%
df[pd.isnull(df['MasVnrType']) & (df['Exterior1st'] == 'HdBoard')]
# Out:
# Empty DataFrame
# Columns: [MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []
#
# [0 rows x 80 columns]

# %% [markdown]
# There are no houses with Exterior of type Hdboard and missing Masonary entries. Hence I will directly update all the missing values to none.

# %%
# Filling in missing values
df['MasVnrType'].fillna('None', inplace = True)

# %%
# Checking to see if the update was done correctly
df['MasVnrType'].value_counts()
# Out:
# None       1766
# BrkFace     879
# Stone       249
# BrkCmn       25
# Name: MasVnrType, dtype: int64

# %%
# MasVnrType feature is now complete
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 1 to 2919
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     2919 non-null   int64
#  1   MSZoning       2919 non-null   object
#  2   LotFrontage    2919 non-null   float64
#  3   LotArea        2919 non-null   int64
#  4   Street         2919 non-null   object
#  5   Alley          198 non-null    object
#  6   LotShape       2919 non-null   object
#  7   LandContour    2919 non-null   object
#  8   Utilities      2919 non-null   object
#  9   LotConfig      2919 non-null   object
#  10  LandSlope      2919 non-null   object
#  11  Neighborhood   2919 non-null   object
#  12  Condition1     2919 non-null   object
#  13  Condition2     2919 non-null   object
#  14  BldgType       2919 non-null   object
#  15  HouseStyle     2919 non-null   object
#  16  OverallQual    2919 non-null   int64
#  17  OverallCond    2919 non-null   int64
#  18  YearBuilt      2919 non-null   int64
#  19  YearRemodAdd   2919 non-null   int64
#  20  RoofStyle      2919 non-null   object
#  21  RoofMatl       2919 non-null   object
#  22  Exterior1st    2919 non-null   object
#  23  Exterior2nd    2919 non-null   object
#  24  MasVnrType     2919 non-null   object
#  25  MasVnrArea     2896 non-null   float64
#  26  ExterQual      2919 non-null   object
#  27  ExterCond      2919 non-null   object
#  28  Foundation     2919 non-null   object
#  29  BsmtQual       2838 non-null   object
#  30  BsmtCond       2837 non-null   object
#  31  BsmtExposure   2837 non-null   object
#  32  BsmtFinType1   2840 non-null   object
#  33  BsmtFinSF1     2918 non-null   float64
#  34  BsmtFinType2   2839 non-null   object
#  35  BsmtFinSF2     2918 non-null   float64
#  36  BsmtUnfSF      2918 non-null   float64
#  37  TotalBsmtSF    2918 non-null   float64
#  38  Heating        2919 non-null   object
#  39  HeatingQC      2919 non-null   object
#  40  CentralAir     2919 non-null   object
#  41  Electrical     2918 non-null   object
#  42  1stFlrSF       2919 non-null   int64
#  43  2ndFlrSF       2919 non-null   int64
#  44  LowQualFinSF   2919 non-null   int64
#  45  GrLivArea      2919 non-null   int64
#  46  BsmtFullBath   2917 non-null   float64
#  47  BsmtHalfBath   2917 non-null   float64
#  48  FullBath       2919 non-null   int64
#  49  HalfBath       2919 non-null   int64
#  50  BedroomAbvGr   2919 non-null   int64
#  51  KitchenAbvGr   2919 non-null   int64
#  52  KitchenQual    2918 non-null   object
#  53  TotRmsAbvGrd   2919 non-null   int64
#  54  Functional     2917 non-null   object
#  55  Fireplaces     2919 non-null   int64
#  56  FireplaceQu    1499 non-null   object
#  57  GarageType     2762 non-null   object
#  58  GarageYrBlt    2760 non-null   float64
#  59  GarageFinish   2760 non-null   object
#  60  GarageCars     2918 non-null   float64
#  61  GarageArea     2918 non-null   float64
#  62  GarageQual     2760 non-null   object
#  63  GarageCond     2760 non-null   object
#  64  PavedDrive     2919 non-null   object
#  65  WoodDeckSF     2919 non-null   int64
#  66  OpenPorchSF    2919 non-null   int64
#  67  EnclosedPorch  2919 non-null   int64
#  68  3SsnPorch      2919 non-null   int64
#  69  ScreenPorch    2919 non-null   int64
#  70  PoolArea       2919 non-null   int64
#  71  PoolQC         10 non-null     object
#  72  Fence          571 non-null    object
#  73  MiscFeature    105 non-null    object
#  74  MiscVal        2919 non-null   int64
#  75  MoSold         2919 non-null   int64
#  76  YrSold         2919 non-null   int64
#  77  SaleType       2918 non-null   object
#  78  SaleCondition  2919 non-null   object
#  79  SalePrice      2919 non-null   int64
# dtypes: float64(11), int64(26), object(43)
# memory usage: 1.8+ MB

# %% [markdown]
# ## Feature : Masonary Veneer Area

# %%
df['MasVnrArea'].value_counts()
# Out:
# 0.0      1738
# 120.0      15
# 176.0      13
# 200.0      13
# 216.0      12
#          ...
# 664.0       1
# 247.0       1
# 550.0       1
# 137.0       1
# 572.0       1
# Name: MasVnrArea, Length: 444, dtype: int64

# %%
# Plot the frequency of the Masonary Veneer Area
plt.hist(df.loc[pd.notnull(df['MasVnrArea']), 'MasVnrArea'], bins = 35, color = 'c')

plt.title('Distrubution of Masonary Veneer Area')
plt.xlabel('Masonary Veneer Area')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# It is obvious that all houses not having any masonary will have 0 Masonary Area. Hence first I will set all these missing values to 0.

# %%
# Setting these missing values to be 0
df.loc[(df['MasVnrType'] == 'None') & (pd.isnull(df['MasVnrArea'])), 'MasVnrArea'] = 0

# %%
df.loc[(pd.isnull(df['MasVnrArea']))]
# Out:
# Empty DataFrame
# Columns: [MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []
#
# [0 rows x 80 columns]

# %% [markdown]
# Turns out only missing values were those having MasVnrType None. Hence we are done!

# %%
df['MasVnrArea']
# Out:
# Id
# 1       196.0
# 2         0.0
# 3       162.0
# 4         0.0
# 5       350.0
#         ...
# 2915      0.0
# 2916      0.0
# 2917      0.0
# 2918      0.0
# 2919     94.0
# Name: MasVnrArea, Length: 2919, dtype: float64

# %%
# MasVnrArea is now complete
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 1 to 2919
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     2919 non-null   int64
#  1   MSZoning       2919 non-null   object
#  2   LotFrontage    2919 non-null   float64
#  3   LotArea        2919 non-null   int64
#  4   Street         2919 non-null   object
#  5   Alley          198 non-null    object
#  6   LotShape       2919 non-null   object
#  7   LandContour    2919 non-null   object
#  8   Utilities      2919 non-null   object
#  9   LotConfig      2919 non-null   object
#  10  LandSlope      2919 non-null   object
#  11  Neighborhood   2919 non-null   object
#  12  Condition1     2919 non-null   object
#  13  Condition2     2919 non-null   object
#  14  BldgType       2919 non-null   object
#  15  HouseStyle     2919 non-null   object
#  16  OverallQual    2919 non-null   int64
#  17  OverallCond    2919 non-null   int64
#  18  YearBuilt      2919 non-null   int64
#  19  YearRemodAdd   2919 non-null   int64
#  20  RoofStyle      2919 non-null   object
#  21  RoofMatl       2919 non-null   object
#  22  Exterior1st    2919 non-null   object
#  23  Exterior2nd    2919 non-null   object
#  24  MasVnrType     2919 non-null   object
#  25  MasVnrArea     2919 non-null   float64
#  26  ExterQual      2919 non-null   object
#  27  ExterCond      2919 non-null   object
#  28  Foundation     2919 non-null   object
#  29  BsmtQual       2838 non-null   object
#  30  BsmtCond       2837 non-null   object
#  31  BsmtExposure   2837 non-null   object
#  32  BsmtFinType1   2840 non-null   object
#  33  BsmtFinSF1     2918 non-null   float64
#  34  BsmtFinType2   2839 non-null   object
#  35  BsmtFinSF2     2918 non-null   float64
#  36  BsmtUnfSF      2918 non-null   float64
#  37  TotalBsmtSF    2918 non-null   float64
#  38  Heating        2919 non-null   object
#  39  HeatingQC      2919 non-null   object
#  40  CentralAir     2919 non-null   object
#  41  Electrical     2918 non-null   object
#  42  1stFlrSF       2919 non-null   int64
#  43  2ndFlrSF       2919 non-null   int64
#  44  LowQualFinSF   2919 non-null   int64
#  45  GrLivArea      2919 non-null   int64
#  46  BsmtFullBath   2917 non-null   float64
#  47  BsmtHalfBath   2917 non-null   float64
#  48  FullBath       2919 non-null   int64
#  49  HalfBath       2919 non-null   int64
#  50  BedroomAbvGr   2919 non-null   int64
#  51  KitchenAbvGr   2919 non-null   int64
#  52  KitchenQual    2918 non-null   object
#  53  TotRmsAbvGrd   2919 non-null   int64
#  54  Functional     2917 non-null   object
#  55  Fireplaces     2919 non-null   int64
#  56  FireplaceQu    1499 non-null   object
#  57  GarageType     2762 non-null   object
#  58  GarageYrBlt    2760 non-null   float64
#  59  GarageFinish   2760 non-null   object
#  60  GarageCars     2918 non-null   float64
#  61  GarageArea     2918 non-null   float64
#  62  GarageQual     2760 non-null   object
#  63  GarageCond     2760 non-null   object
#  64  PavedDrive     2919 non-null   object
#  65  WoodDeckSF     2919 non-null   int64
#  66  OpenPorchSF    2919 non-null   int64
#  67  EnclosedPorch  2919 non-null   int64
#  68  3SsnPorch      2919 non-null   int64
#  69  ScreenPorch    2919 non-null   int64
#  70  PoolArea       2919 non-null   int64
#  71  PoolQC         10 non-null     object
#  72  Fence          571 non-null    object
#  73  MiscFeature    105 non-null    object
#  74  MiscVal        2919 non-null   int64
#  75  MoSold         2919 non-null   int64
#  76  YrSold         2919 non-null   int64
#  77  SaleType       2918 non-null   object
#  78  SaleCondition  2919 non-null   object
#  79  SalePrice      2919 non-null   int64
# dtypes: float64(11), int64(26), object(43)
# memory usage: 1.8+ MB

# %% [markdown]
# ## Feature : Basement

# %%
# Houses with missing values in features related to basement
df[pd.isnull(df['BsmtQual'])]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 18            90       RL         72.0    10791   Pave   NaN      Reg
# 40            90       RL         65.0     6040   Pave   NaN      Reg
# 91            20       RL         60.0     7200   Pave   NaN      Reg
# 103           90       RL         64.0     7018   Pave   NaN      Reg
# 157           20       RL         60.0     7200   Pave   NaN      Reg
# ...          ...      ...          ...      ...    ...   ...      ...
# 2804          20       RL        100.0    21370   Pave   NaN      Reg
# 2805          30       RL         55.0     8250   Pave   NaN      Reg
# 2825          20       RL         80.0    12048   Pave   NaN      Reg
# 2892          30  C (all)         69.0    12366   Pave   NaN      Reg
# 2905          20       RL        125.0    31250   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                    ...
# 18           Lvl    AllPub    Inside  ...        0    NaN   NaN        Shed
# 40           Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 91           Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 103          Bnk    AllPub    Inside  ...        0    NaN   NaN         NaN
# 157          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# ...          ...       ...       ...  ...      ...    ...   ...         ...
# 2804         Lvl    AllPub       FR2  ...        0    NaN   NaN        Shed
# 2805         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2825         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2892         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2905         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 18       500     10    2006        WD         Normal      90000
# 40         0      6    2008        WD        AdjLand      82000
# 91         0      7    2006        WD         Normal     109900
# 103        0      6    2009        WD         Alloca     118964
# 157        0      6    2006        WD         Normal     109500
# ...      ...    ...     ...       ...            ...        ...
# 2804     600      6    2006        WD         Normal         -1
# 2805       0      6    2006        WD         Normal         -1
# 2825       0      4    2006        WD         Normal         -1
# 2892       0     10    2006        WD        Abnorml         -1
# 2905       0      5    2006        WD         Normal         -1
#
# [81 rows x 80 columns]

# %%
df[pd.isnull(df['BsmtCond'])]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 18            90       RL         72.0    10791   Pave   NaN      Reg
# 40            90       RL         65.0     6040   Pave   NaN      Reg
# 91            20       RL         60.0     7200   Pave   NaN      Reg
# 103           90       RL         64.0     7018   Pave   NaN      Reg
# 157           20       RL         60.0     7200   Pave   NaN      Reg
# ...          ...      ...          ...      ...    ...   ...      ...
# 2804          20       RL        100.0    21370   Pave   NaN      Reg
# 2805          30       RL         55.0     8250   Pave   NaN      Reg
# 2825          20       RL         80.0    12048   Pave   NaN      Reg
# 2892          30  C (all)         69.0    12366   Pave   NaN      Reg
# 2905          20       RL        125.0    31250   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                    ...
# 18           Lvl    AllPub    Inside  ...        0    NaN   NaN        Shed
# 40           Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 91           Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 103          Bnk    AllPub    Inside  ...        0    NaN   NaN         NaN
# 157          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# ...          ...       ...       ...  ...      ...    ...   ...         ...
# 2804         Lvl    AllPub       FR2  ...        0    NaN   NaN        Shed
# 2805         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2825         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2892         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2905         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 18       500     10    2006        WD         Normal      90000
# 40         0      6    2008        WD        AdjLand      82000
# 91         0      7    2006        WD         Normal     109900
# 103        0      6    2009        WD         Alloca     118964
# 157        0      6    2006        WD         Normal     109500
# ...      ...    ...     ...       ...            ...        ...
# 2804     600      6    2006        WD         Normal         -1
# 2805       0      6    2006        WD         Normal         -1
# 2825       0      4    2006        WD         Normal         -1
# 2892       0     10    2006        WD        Abnorml         -1
# 2905       0      5    2006        WD         Normal         -1
#
# [82 rows x 80 columns]

# %%
df[pd.isnull(df['BsmtExposure'])]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 18            90       RL         72.0    10791   Pave   NaN      Reg
# 40            90       RL         65.0     6040   Pave   NaN      Reg
# 91            20       RL         60.0     7200   Pave   NaN      Reg
# 103           90       RL         64.0     7018   Pave   NaN      Reg
# 157           20       RL         60.0     7200   Pave   NaN      Reg
# ...          ...      ...          ...      ...    ...   ...      ...
# 2804          20       RL        100.0    21370   Pave   NaN      Reg
# 2805          30       RL         55.0     8250   Pave   NaN      Reg
# 2825          20       RL         80.0    12048   Pave   NaN      Reg
# 2892          30  C (all)         69.0    12366   Pave   NaN      Reg
# 2905          20       RL        125.0    31250   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                    ...
# 18           Lvl    AllPub    Inside  ...        0    NaN   NaN        Shed
# 40           Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 91           Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 103          Bnk    AllPub    Inside  ...        0    NaN   NaN         NaN
# 157          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# ...          ...       ...       ...  ...      ...    ...   ...         ...
# 2804         Lvl    AllPub       FR2  ...        0    NaN   NaN        Shed
# 2805         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2825         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2892         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2905         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 18       500     10    2006        WD         Normal      90000
# 40         0      6    2008        WD        AdjLand      82000
# 91         0      7    2006        WD         Normal     109900
# 103        0      6    2009        WD         Alloca     118964
# 157        0      6    2006        WD         Normal     109500
# ...      ...    ...     ...       ...            ...        ...
# 2804     600      6    2006        WD         Normal         -1
# 2805       0      6    2006        WD         Normal         -1
# 2825       0      4    2006        WD         Normal         -1
# 2892       0     10    2006        WD        Abnorml         -1
# 2905       0      5    2006        WD         Normal         -1
#
# [82 rows x 80 columns]

# %%
df[pd.isnull(df['BsmtFinType1'])]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 18            90       RL         72.0    10791   Pave   NaN      Reg
# 40            90       RL         65.0     6040   Pave   NaN      Reg
# 91            20       RL         60.0     7200   Pave   NaN      Reg
# 103           90       RL         64.0     7018   Pave   NaN      Reg
# 157           20       RL         60.0     7200   Pave   NaN      Reg
# ...          ...      ...          ...      ...    ...   ...      ...
# 2804          20       RL        100.0    21370   Pave   NaN      Reg
# 2805          30       RL         55.0     8250   Pave   NaN      Reg
# 2825          20       RL         80.0    12048   Pave   NaN      Reg
# 2892          30  C (all)         69.0    12366   Pave   NaN      Reg
# 2905          20       RL        125.0    31250   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                    ...
# 18           Lvl    AllPub    Inside  ...        0    NaN   NaN        Shed
# 40           Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 91           Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 103          Bnk    AllPub    Inside  ...        0    NaN   NaN         NaN
# 157          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# ...          ...       ...       ...  ...      ...    ...   ...         ...
# 2804         Lvl    AllPub       FR2  ...        0    NaN   NaN        Shed
# 2805         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2825         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2892         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2905         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 18       500     10    2006        WD         Normal      90000
# 40         0      6    2008        WD        AdjLand      82000
# 91         0      7    2006        WD         Normal     109900
# 103        0      6    2009        WD         Alloca     118964
# 157        0      6    2006        WD         Normal     109500
# ...      ...    ...     ...       ...            ...        ...
# 2804     600      6    2006        WD         Normal         -1
# 2805       0      6    2006        WD         Normal         -1
# 2825       0      4    2006        WD         Normal         -1
# 2892       0     10    2006        WD        Abnorml         -1
# 2905       0      5    2006        WD         Normal         -1
#
# [79 rows x 80 columns]

# %%
df[pd.isnull(df['BsmtFinType2'])]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 18            90       RL         72.0    10791   Pave   NaN      Reg
# 40            90       RL         65.0     6040   Pave   NaN      Reg
# 91            20       RL         60.0     7200   Pave   NaN      Reg
# 103           90       RL         64.0     7018   Pave   NaN      Reg
# 157           20       RL         60.0     7200   Pave   NaN      Reg
# ...          ...      ...          ...      ...    ...   ...      ...
# 2804          20       RL        100.0    21370   Pave   NaN      Reg
# 2805          30       RL         55.0     8250   Pave   NaN      Reg
# 2825          20       RL         80.0    12048   Pave   NaN      Reg
# 2892          30  C (all)         69.0    12366   Pave   NaN      Reg
# 2905          20       RL        125.0    31250   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                    ...
# 18           Lvl    AllPub    Inside  ...        0    NaN   NaN        Shed
# 40           Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 91           Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 103          Bnk    AllPub    Inside  ...        0    NaN   NaN         NaN
# 157          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# ...          ...       ...       ...  ...      ...    ...   ...         ...
# 2804         Lvl    AllPub       FR2  ...        0    NaN   NaN        Shed
# 2805         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2825         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2892         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2905         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 18       500     10    2006        WD         Normal      90000
# 40         0      6    2008        WD        AdjLand      82000
# 91         0      7    2006        WD         Normal     109900
# 103        0      6    2009        WD         Alloca     118964
# 157        0      6    2006        WD         Normal     109500
# ...      ...    ...     ...       ...            ...        ...
# 2804     600      6    2006        WD         Normal         -1
# 2805       0      6    2006        WD         Normal         -1
# 2825       0      4    2006        WD         Normal         -1
# 2892       0     10    2006        WD        Abnorml         -1
# 2905       0      5    2006        WD         Normal         -1
#
# [80 rows x 80 columns]

# %% [markdown]
# In all these feature there seems to be about 80 rows each. I will check to see if these are all same houses.

# %%
is_one_basement_missing = pd.isnull(df['BsmtQual']) | pd.isnull(df['BsmtCond']) | pd.isnull(df['BsmtExposure']) | pd.isnull(df['BsmtFinType1']) | pd.isnull(df['BsmtFinType2'])
df[is_one_basement_missing]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 18            90       RL         72.0    10791   Pave   NaN      Reg
# 40            90       RL         65.0     6040   Pave   NaN      Reg
# 91            20       RL         60.0     7200   Pave   NaN      Reg
# 103           90       RL         64.0     7018   Pave   NaN      Reg
# 157           20       RL         60.0     7200   Pave   NaN      Reg
# ...          ...      ...          ...      ...    ...   ...      ...
# 2804          20       RL        100.0    21370   Pave   NaN      Reg
# 2805          30       RL         55.0     8250   Pave   NaN      Reg
# 2825          20       RL         80.0    12048   Pave   NaN      Reg
# 2892          30  C (all)         69.0    12366   Pave   NaN      Reg
# 2905          20       RL        125.0    31250   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                    ...
# 18           Lvl    AllPub    Inside  ...        0    NaN   NaN        Shed
# 40           Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 91           Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 103          Bnk    AllPub    Inside  ...        0    NaN   NaN         NaN
# 157          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# ...          ...       ...       ...  ...      ...    ...   ...         ...
# 2804         Lvl    AllPub       FR2  ...        0    NaN   NaN        Shed
# 2805         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2825         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2892         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2905         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 18       500     10    2006        WD         Normal      90000
# 40         0      6    2008        WD        AdjLand      82000
# 91         0      7    2006        WD         Normal     109900
# 103        0      6    2009        WD         Alloca     118964
# 157        0      6    2006        WD         Normal     109500
# ...      ...    ...     ...       ...            ...        ...
# 2804     600      6    2006        WD         Normal         -1
# 2805       0      6    2006        WD         Normal         -1
# 2825       0      4    2006        WD         Normal         -1
# 2892       0     10    2006        WD        Abnorml         -1
# 2905       0      5    2006        WD         Normal         -1
#
# [88 rows x 80 columns]

# %%
is_all_basement_missing = pd.isnull(df['BsmtQual']) & pd.isnull(df['BsmtCond']) & pd.isnull(df['BsmtExposure']) & pd.isnull(df['BsmtFinType1']) & pd.isnull(df['BsmtFinType2'])
df[is_all_basement_missing]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 18            90       RL         72.0    10791   Pave   NaN      Reg
# 40            90       RL         65.0     6040   Pave   NaN      Reg
# 91            20       RL         60.0     7200   Pave   NaN      Reg
# 103           90       RL         64.0     7018   Pave   NaN      Reg
# 157           20       RL         60.0     7200   Pave   NaN      Reg
# ...          ...      ...          ...      ...    ...   ...      ...
# 2804          20       RL        100.0    21370   Pave   NaN      Reg
# 2805          30       RL         55.0     8250   Pave   NaN      Reg
# 2825          20       RL         80.0    12048   Pave   NaN      Reg
# 2892          30  C (all)         69.0    12366   Pave   NaN      Reg
# 2905          20       RL        125.0    31250   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                    ...
# 18           Lvl    AllPub    Inside  ...        0    NaN   NaN        Shed
# 40           Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 91           Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 103          Bnk    AllPub    Inside  ...        0    NaN   NaN         NaN
# 157          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# ...          ...       ...       ...  ...      ...    ...   ...         ...
# 2804         Lvl    AllPub       FR2  ...        0    NaN   NaN        Shed
# 2805         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2825         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2892         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2905         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 18       500     10    2006        WD         Normal      90000
# 40         0      6    2008        WD        AdjLand      82000
# 91         0      7    2006        WD         Normal     109900
# 103        0      6    2009        WD         Alloca     118964
# 157        0      6    2006        WD         Normal     109500
# ...      ...    ...     ...       ...            ...        ...
# 2804     600      6    2006        WD         Normal         -1
# 2805       0      6    2006        WD         Normal         -1
# 2825       0      4    2006        WD         Normal         -1
# 2892       0     10    2006        WD        Abnorml         -1
# 2905       0      5    2006        WD         Normal         -1
#
# [79 rows x 80 columns]

# %% [markdown]
# There are 79 houses with missing values in all these basement features.

# %%
# Distribution of different entries
for column in ['BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2']:
    print(df[column].value_counts(), "\n")
# Out:
# TA    1283
# Gd    1209
# Ex     258
# Fa      88
# Name: BsmtQual, dtype: int64
#
# TA    2606
# Gd     122
# Fa     104
# Po       5
# Name: BsmtCond, dtype: int64
#
# No    1904
# Av     418
# Gd     276
# Mn     239
# Name: BsmtExposure, dtype: int64
#
# Unf    851
# GLQ    849
# ALQ    429
# Rec    288
# BLQ    269
# LwQ    154
# Name: BsmtFinType1, dtype: int64
#
# Unf    2493
# Rec     105
# LwQ      87
# BLQ      68
# ALQ      52
# GLQ      34
# Name: BsmtFinType2, dtype: int64

# %%
df['BsmtFinSF1'].value_counts()
# Out:
# 0.0       929
# 24.0       27
# 16.0       14
# 300.0       9
# 288.0       8
#          ...
# 1022.0      1
# 939.0       1
# 1124.0      1
# 1619.0      1
# 1106.0      1
# Name: BsmtFinSF1, Length: 991, dtype: int64

# %% [markdown]
# Let me first set all housing having basement area as 0. All the basement features entries of such house should be 'no basement'.

# %%
# Houses with basement area 0 and invalid entries.
df.loc[(df['BsmtFinSF1'] == 0) & is_all_basement_missing, 'BsmtQual':]
# Out:
#      BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  \
# Id
# 18        NaN      NaN          NaN          NaN         0.0          NaN
# 40        NaN      NaN          NaN          NaN         0.0          NaN
# 91        NaN      NaN          NaN          NaN         0.0          NaN
# 103       NaN      NaN          NaN          NaN         0.0          NaN
# 157       NaN      NaN          NaN          NaN         0.0          NaN
# ...       ...      ...          ...          ...         ...          ...
# 2804      NaN      NaN          NaN          NaN         0.0          NaN
# 2805      NaN      NaN          NaN          NaN         0.0          NaN
# 2825      NaN      NaN          NaN          NaN         0.0          NaN
# 2892      NaN      NaN          NaN          NaN         0.0          NaN
# 2905      NaN      NaN          NaN          NaN         0.0          NaN
#
#       BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating  ... PoolArea PoolQC Fence  \
# Id                                                ...
# 18           0.0        0.0          0.0    GasA  ...        0    NaN   NaN
# 40           0.0        0.0          0.0    GasA  ...        0    NaN   NaN
# 91           0.0        0.0          0.0    GasA  ...        0    NaN   NaN
# 103          0.0        0.0          0.0    GasA  ...        0    NaN   NaN
# 157          0.0        0.0          0.0    GasA  ...        0    NaN   NaN
# ...          ...        ...          ...     ...  ...      ...    ...   ...
# 2804         0.0        0.0          0.0    GasA  ...        0    NaN   NaN
# 2805         0.0        0.0          0.0    GasA  ...        0    NaN   NaN
# 2825         0.0        0.0          0.0    GasA  ...        0    NaN   NaN
# 2892         0.0        0.0          0.0    GasA  ...        0    NaN   NaN
# 2905         0.0        0.0          0.0    GasA  ...        0    NaN   NaN
#
#       MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 18           Shed      500      10    2006        WD         Normal      90000
# 40            NaN        0       6    2008        WD        AdjLand      82000
# 91            NaN        0       7    2006        WD         Normal     109900
# 103           NaN        0       6    2009        WD         Alloca     118964
# 157           NaN        0       6    2006        WD         Normal     109500
# ...           ...      ...     ...     ...       ...            ...        ...
# 2804         Shed      600       6    2006        WD         Normal         -1
# 2805          NaN        0       6    2006        WD         Normal         -1
# 2825          NaN        0       4    2006        WD         Normal         -1
# 2892          NaN        0      10    2006        WD        Abnorml         -1
# 2905          NaN        0       5    2006        WD         Normal         -1
#
# [78 rows x 51 columns]

# %%
# Setting all these to NA (no basement)
df.loc[(df['BsmtFinSF1'] == 0) & is_all_basement_missing, ['BsmtQual','BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2']] = 'NA'

# %%
# Checking to see if update was done as expected
df.loc[(df['BsmtFinSF1'] == 0) & is_all_basement_missing, 'BsmtQual':]
# Out:
#      BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  \
# Id
# 18         NA       NA           NA           NA         0.0           NA
# 40         NA       NA           NA           NA         0.0           NA
# 91         NA       NA           NA           NA         0.0           NA
# 103        NA       NA           NA           NA         0.0           NA
# 157        NA       NA           NA           NA         0.0           NA
# ...       ...      ...          ...          ...         ...          ...
# 2804       NA       NA           NA           NA         0.0           NA
# 2805       NA       NA           NA           NA         0.0           NA
# 2825       NA       NA           NA           NA         0.0           NA
# 2892       NA       NA           NA           NA         0.0           NA
# 2905       NA       NA           NA           NA         0.0           NA
#
#       BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating  ... PoolArea PoolQC Fence  \
# Id                                                ...
# 18           0.0        0.0          0.0    GasA  ...        0    NaN   NaN
# 40           0.0        0.0          0.0    GasA  ...        0    NaN   NaN
# 91           0.0        0.0          0.0    GasA  ...        0    NaN   NaN
# 103          0.0        0.0          0.0    GasA  ...        0    NaN   NaN
# 157          0.0        0.0          0.0    GasA  ...        0    NaN   NaN
# ...          ...        ...          ...     ...  ...      ...    ...   ...
# 2804         0.0        0.0          0.0    GasA  ...        0    NaN   NaN
# 2805         0.0        0.0          0.0    GasA  ...        0    NaN   NaN
# 2825         0.0        0.0          0.0    GasA  ...        0    NaN   NaN
# 2892         0.0        0.0          0.0    GasA  ...        0    NaN   NaN
# 2905         0.0        0.0          0.0    GasA  ...        0    NaN   NaN
#
#       MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 18           Shed      500      10    2006        WD         Normal      90000
# 40            NaN        0       6    2008        WD        AdjLand      82000
# 91            NaN        0       7    2006        WD         Normal     109900
# 103           NaN        0       6    2009        WD         Alloca     118964
# 157           NaN        0       6    2006        WD         Normal     109500
# ...           ...      ...     ...     ...       ...            ...        ...
# 2804         Shed      600       6    2006        WD         Normal         -1
# 2805          NaN        0       6    2006        WD         Normal         -1
# 2825          NaN        0       4    2006        WD         Normal         -1
# 2892          NaN        0      10    2006        WD        Abnorml         -1
# 2905          NaN        0       5    2006        WD         Normal         -1
#
# [78 rows x 51 columns]

# %%
# Checking new distribution
for column in ['BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2']:
    print(df[column].value_counts(), "\n")
# Out:
# TA    1283
# Gd    1209
# Ex     258
# Fa      88
# NA      78
# Name: BsmtQual, dtype: int64
#
# TA    2606
# Gd     122
# Fa     104
# NA      78
# Po       5
# Name: BsmtCond, dtype: int64
#
# No    1904
# Av     418
# Gd     276
# Mn     239
# NA      78
# Name: BsmtExposure, dtype: int64
#
# Unf    851
# GLQ    849
# ALQ    429
# Rec    288
# BLQ    269
# LwQ    154
# NA      78
# Name: BsmtFinType1, dtype: int64
#
# Unf    2493
# Rec     105
# LwQ      87
# NA       78
# BLQ      68
# ALQ      52
# GLQ      34
# Name: BsmtFinType2, dtype: int64

# %%
# Update was done as expected 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 1 to 2919
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     2919 non-null   int64
#  1   MSZoning       2919 non-null   object
#  2   LotFrontage    2919 non-null   float64
#  3   LotArea        2919 non-null   int64
#  4   Street         2919 non-null   object
#  5   Alley          198 non-null    object
#  6   LotShape       2919 non-null   object
#  7   LandContour    2919 non-null   object
#  8   Utilities      2919 non-null   object
#  9   LotConfig      2919 non-null   object
#  10  LandSlope      2919 non-null   object
#  11  Neighborhood   2919 non-null   object
#  12  Condition1     2919 non-null   object
#  13  Condition2     2919 non-null   object
#  14  BldgType       2919 non-null   object
#  15  HouseStyle     2919 non-null   object
#  16  OverallQual    2919 non-null   int64
#  17  OverallCond    2919 non-null   int64
#  18  YearBuilt      2919 non-null   int64
#  19  YearRemodAdd   2919 non-null   int64
#  20  RoofStyle      2919 non-null   object
#  21  RoofMatl       2919 non-null   object
#  22  Exterior1st    2919 non-null   object
#  23  Exterior2nd    2919 non-null   object
#  24  MasVnrType     2919 non-null   object
#  25  MasVnrArea     2919 non-null   float64
#  26  ExterQual      2919 non-null   object
#  27  ExterCond      2919 non-null   object
#  28  Foundation     2919 non-null   object
#  29  BsmtQual       2916 non-null   object
#  30  BsmtCond       2915 non-null   object
#  31  BsmtExposure   2915 non-null   object
#  32  BsmtFinType1   2918 non-null   object
#  33  BsmtFinSF1     2918 non-null   float64
#  34  BsmtFinType2   2917 non-null   object
#  35  BsmtFinSF2     2918 non-null   float64
#  36  BsmtUnfSF      2918 non-null   float64
#  37  TotalBsmtSF    2918 non-null   float64
#  38  Heating        2919 non-null   object
#  39  HeatingQC      2919 non-null   object
#  40  CentralAir     2919 non-null   object
#  41  Electrical     2918 non-null   object
#  42  1stFlrSF       2919 non-null   int64
#  43  2ndFlrSF       2919 non-null   int64
#  44  LowQualFinSF   2919 non-null   int64
#  45  GrLivArea      2919 non-null   int64
#  46  BsmtFullBath   2917 non-null   float64
#  47  BsmtHalfBath   2917 non-null   float64
#  48  FullBath       2919 non-null   int64
#  49  HalfBath       2919 non-null   int64
#  50  BedroomAbvGr   2919 non-null   int64
#  51  KitchenAbvGr   2919 non-null   int64
#  52  KitchenQual    2918 non-null   object
#  53  TotRmsAbvGrd   2919 non-null   int64
#  54  Functional     2917 non-null   object
#  55  Fireplaces     2919 non-null   int64
#  56  FireplaceQu    1499 non-null   object
#  57  GarageType     2762 non-null   object
#  58  GarageYrBlt    2760 non-null   float64
#  59  GarageFinish   2760 non-null   object
#  60  GarageCars     2918 non-null   float64
#  61  GarageArea     2918 non-null   float64
#  62  GarageQual     2760 non-null   object
#  63  GarageCond     2760 non-null   object
#  64  PavedDrive     2919 non-null   object
#  65  WoodDeckSF     2919 non-null   int64
#  66  OpenPorchSF    2919 non-null   int64
#  67  EnclosedPorch  2919 non-null   int64
#  68  3SsnPorch      2919 non-null   int64
#  69  ScreenPorch    2919 non-null   int64
#  70  PoolArea       2919 non-null   int64
#  71  PoolQC         10 non-null     object
#  72  Fence          571 non-null    object
#  73  MiscFeature    105 non-null    object
#  74  MiscVal        2919 non-null   int64
#  75  MoSold         2919 non-null   int64
#  76  YrSold         2919 non-null   int64
#  77  SaleType       2918 non-null   object
#  78  SaleCondition  2919 non-null   object
#  79  SalePrice      2919 non-null   int64
# dtypes: float64(11), int64(26), object(43)
# memory usage: 1.8+ MB

# %% [markdown]
# Now I will deal with the remaining few houses.

# %%
# Houses with basement area 0 and invalid entries.
is_one_basement_missing = pd.isnull(df['BsmtQual']) | pd.isnull(df['BsmtCond']) | pd.isnull(df['BsmtExposure']) | pd.isnull(df['BsmtFinType1']) | pd.isnull(df['BsmtFinType2'])
df.loc[(df['BsmtFinSF1'] == 0) & is_one_basement_missing, 'BsmtQual':]
# Out:
#      BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  \
# Id
# 949        Gd       TA          NaN          Unf         0.0          Unf
# 1488       Gd       TA          NaN          Unf         0.0          Unf
# 2218      NaN       Fa           No          Unf         0.0          Unf
# 2219      NaN       TA           No          Unf         0.0          Unf
# 2349       Gd       TA          NaN          Unf         0.0          Unf
#
#       BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating  ... PoolArea PoolQC Fence  \
# Id                                                ...
# 949          0.0      936.0        936.0    GasA  ...        0    NaN   NaN
# 1488         0.0     1595.0       1595.0    GasA  ...        0    NaN   NaN
# 2218         0.0      173.0        173.0    GasA  ...        0    NaN   NaN
# 2219         0.0      356.0        356.0    GasA  ...        0    NaN   NaN
# 2349         0.0      725.0        725.0    GasA  ...        0    NaN   NaN
#
#       MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 949           NaN        0       2    2006        WD         Normal     192500
# 1488          NaN        0       5    2010        WD         Normal         -1
# 2218          NaN        0       7    2008        WD         Normal         -1
# 2219          NaN        0       5    2008        WD         Normal         -1
# 2349          NaN        0       7    2007       New        Partial         -1
#
# [5 rows x 51 columns]

# %%
df.loc[is_one_basement_missing, 'BsmtQual':]
# Out:
#      BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  \
# Id
# 333        Gd       TA           No          GLQ      1124.0          NaN
# 949        Gd       TA          NaN          Unf         0.0          Unf
# 1488       Gd       TA          NaN          Unf         0.0          Unf
# 2041       Gd      NaN           Mn          GLQ      1044.0          Rec
# 2121      NaN      NaN          NaN          NaN         NaN          NaN
# 2186       TA      NaN           No          BLQ      1033.0          Unf
# 2218      NaN       Fa           No          Unf         0.0          Unf
# 2219      NaN       TA           No          Unf         0.0          Unf
# 2349       Gd       TA          NaN          Unf         0.0          Unf
# 2525       TA      NaN           Av          ALQ       755.0          Unf
#
#       BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating  ... PoolArea PoolQC  Fence  \
# Id                                                ...
# 333        479.0     1603.0       3206.0    GasA  ...        0    NaN    NaN
# 949          0.0      936.0        936.0    GasA  ...        0    NaN    NaN
# 1488         0.0     1595.0       1595.0    GasA  ...        0    NaN    NaN
# 2041       382.0        0.0       1426.0    GasA  ...        0    NaN   GdWo
# 2121         NaN        NaN          NaN    GasA  ...        0    NaN  MnPrv
# 2186         0.0       94.0       1127.0    GasA  ...        0    NaN    NaN
# 2218         0.0      173.0        173.0    GasA  ...        0    NaN    NaN
# 2219         0.0      356.0        356.0    GasA  ...        0    NaN    NaN
# 2349         0.0      725.0        725.0    GasA  ...        0    NaN    NaN
# 2525         0.0      240.0        995.0    GasA  ...        0    NaN  MnPrv
#
#       MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 333           NaN        0      10    2009        WD         Normal     284000
# 949           NaN        0       2    2006        WD         Normal     192500
# 1488          NaN        0       5    2010        WD         Normal         -1
# 2041          NaN        0       5    2008        WD         Normal         -1
# 2121          NaN        0       4    2008     ConLD        Abnorml         -1
# 2186          NaN        0       5    2008        WD         Normal         -1
# 2218          NaN        0       7    2008        WD         Normal         -1
# 2219          NaN        0       5    2008        WD         Normal         -1
# 2349          NaN        0       7    2007       New        Partial         -1
# 2525          NaN        0       6    2007        WD         Normal         -1
#
# [10 rows x 51 columns]

# %%
df.loc[(df['BsmtQual'] == 'Gd'), 'BsmtCond'].value_counts()
# Out:
# TA    1133
# Gd      66
# Fa       9
# Name: BsmtCond, dtype: int64

# %%
# Setting housing with Good basement quality to TA
df.loc[(df['BsmtQual'] == 'Gd') & pd.isnull(df['BsmtCond']), 'BsmtCond'] = 'TA'

# %%
is_one_basement_missing = pd.isnull(df['BsmtQual']) | pd.isnull(df['BsmtCond']) | pd.isnull(df['BsmtExposure']) | pd.isnull(df['BsmtFinType1']) | pd.isnull(df['BsmtFinType2'])
df.loc[is_one_basement_missing, 'BsmtQual':]
# Out:
#      BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  \
# Id
# 333        Gd       TA           No          GLQ      1124.0          NaN
# 949        Gd       TA          NaN          Unf         0.0          Unf
# 1488       Gd       TA          NaN          Unf         0.0          Unf
# 2121      NaN      NaN          NaN          NaN         NaN          NaN
# 2186       TA      NaN           No          BLQ      1033.0          Unf
# 2218      NaN       Fa           No          Unf         0.0          Unf
# 2219      NaN       TA           No          Unf         0.0          Unf
# 2349       Gd       TA          NaN          Unf         0.0          Unf
# 2525       TA      NaN           Av          ALQ       755.0          Unf
#
#       BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating  ... PoolArea PoolQC  Fence  \
# Id                                                ...
# 333        479.0     1603.0       3206.0    GasA  ...        0    NaN    NaN
# 949          0.0      936.0        936.0    GasA  ...        0    NaN    NaN
# 1488         0.0     1595.0       1595.0    GasA  ...        0    NaN    NaN
# 2121         NaN        NaN          NaN    GasA  ...        0    NaN  MnPrv
# 2186         0.0       94.0       1127.0    GasA  ...        0    NaN    NaN
# 2218         0.0      173.0        173.0    GasA  ...        0    NaN    NaN
# 2219         0.0      356.0        356.0    GasA  ...        0    NaN    NaN
# 2349         0.0      725.0        725.0    GasA  ...        0    NaN    NaN
# 2525         0.0      240.0        995.0    GasA  ...        0    NaN  MnPrv
#
#       MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 333           NaN        0      10    2009        WD         Normal     284000
# 949           NaN        0       2    2006        WD         Normal     192500
# 1488          NaN        0       5    2010        WD         Normal         -1
# 2121          NaN        0       4    2008     ConLD        Abnorml         -1
# 2186          NaN        0       5    2008        WD         Normal         -1
# 2218          NaN        0       7    2008        WD         Normal         -1
# 2219          NaN        0       5    2008        WD         Normal         -1
# 2349          NaN        0       7    2007       New        Partial         -1
# 2525          NaN        0       6    2007        WD         Normal         -1
#
# [9 rows x 51 columns]

# %%
# Checking houses with good basement height and an avergage condition
df.loc[(df['BsmtQual'] == 'Gd') & (df['BsmtCond'] == 'TA'), 'BsmtExposure'].value_counts()
# Out:
# No    655
# Av    247
# Gd    125
# Mn    104
# Name: BsmtExposure, dtype: int64

# %%
# Setting these missing values to No as that is the entry most houses of this type have
df.loc[(df['BsmtQual'] == 'Gd') & (df['BsmtCond'] == 'TA') & pd.isnull(df['BsmtExposure']), 'BsmtExposure'] = 'No'

# %%
is_one_basement_missing = pd.isnull(df['BsmtQual']) | pd.isnull(df['BsmtCond']) | pd.isnull(df['BsmtExposure']) | pd.isnull(df['BsmtFinType1']) | pd.isnull(df['BsmtFinType2'])
df.loc[is_one_basement_missing, 'BsmtQual':]
# Out:
#      BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  \
# Id
# 333        Gd       TA           No          GLQ      1124.0          NaN
# 2121      NaN      NaN          NaN          NaN         NaN          NaN
# 2186       TA      NaN           No          BLQ      1033.0          Unf
# 2218      NaN       Fa           No          Unf         0.0          Unf
# 2219      NaN       TA           No          Unf         0.0          Unf
# 2525       TA      NaN           Av          ALQ       755.0          Unf
#
#       BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating  ... PoolArea PoolQC  Fence  \
# Id                                                ...
# 333        479.0     1603.0       3206.0    GasA  ...        0    NaN    NaN
# 2121         NaN        NaN          NaN    GasA  ...        0    NaN  MnPrv
# 2186         0.0       94.0       1127.0    GasA  ...        0    NaN    NaN
# 2218         0.0      173.0        173.0    GasA  ...        0    NaN    NaN
# 2219         0.0      356.0        356.0    GasA  ...        0    NaN    NaN
# 2525         0.0      240.0        995.0    GasA  ...        0    NaN  MnPrv
#
#       MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 333           NaN        0      10    2009        WD         Normal     284000
# 2121          NaN        0       4    2008     ConLD        Abnorml         -1
# 2186          NaN        0       5    2008        WD         Normal         -1
# 2218          NaN        0       7    2008        WD         Normal         -1
# 2219          NaN        0       5    2008        WD         Normal         -1
# 2525          NaN        0       6    2007        WD         Normal         -1
#
# [6 rows x 51 columns]

# %%
# Checking out houses with typical basement height
df.loc[(df['BsmtQual'] == 'TA'), 'BsmtCond'].value_counts()
# Out:
# TA    1177
# Fa      72
# Gd      31
# Po       1
# Name: BsmtCond, dtype: int64

# %%
# Setting these missing values to TA as the above distribution shows a clear bias
df.loc[(df['BsmtQual'] == 'TA')  & pd.isnull(df['BsmtCond']), 'BsmtCond'] = 'TA'

# %%
is_one_basement_missing = pd.isnull(df['BsmtQual']) | pd.isnull(df['BsmtCond']) | pd.isnull(df['BsmtExposure']) | pd.isnull(df['BsmtFinType1']) | pd.isnull(df['BsmtFinType2'])
df.loc[is_one_basement_missing, 'BsmtQual':]
# Out:
#      BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  \
# Id
# 333        Gd       TA           No          GLQ      1124.0          NaN
# 2121      NaN      NaN          NaN          NaN         NaN          NaN
# 2218      NaN       Fa           No          Unf         0.0          Unf
# 2219      NaN       TA           No          Unf         0.0          Unf
#
#       BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating  ... PoolArea PoolQC  Fence  \
# Id                                                ...
# 333        479.0     1603.0       3206.0    GasA  ...        0    NaN    NaN
# 2121         NaN        NaN          NaN    GasA  ...        0    NaN  MnPrv
# 2218         0.0      173.0        173.0    GasA  ...        0    NaN    NaN
# 2219         0.0      356.0        356.0    GasA  ...        0    NaN    NaN
#
#       MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 333           NaN        0      10    2009        WD         Normal     284000
# 2121          NaN        0       4    2008     ConLD        Abnorml         -1
# 2218          NaN        0       7    2008        WD         Normal         -1
# 2219          NaN        0       5    2008        WD         Normal         -1
#
# [4 rows x 51 columns]

# %% [markdown]
# There is one house with no entry in any basement feature. I will assume that this house does not have a basement.

# %%
df.loc[pd.isnull(df['TotalBsmtSF']), ['BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2']] = 'NA'

# %%
df.loc[pd.isnull(df['TotalBsmtSF']), 'BsmtQual':]
# Out:
#      BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  \
# Id
# 2121       NA       NA           NA           NA         NaN           NA
#
#       BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating  ... PoolArea PoolQC  Fence  \
# Id                                                ...
# 2121         NaN        NaN          NaN    GasA  ...        0    NaN  MnPrv
#
#       MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 2121          NaN        0       4    2008     ConLD        Abnorml         -1
#
# [1 rows x 51 columns]

# %%
df.loc[pd.isnull(df['TotalBsmtSF']), ['BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'BsmtUnfSF']]
# Out:
#       BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  BsmtUnfSF
# Id
# 2121         NaN         NaN        NaN        NaN

# %%
df.loc[pd.isnull(df['TotalBsmtSF']), ['BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'BsmtUnfSF']] = 0
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 1 to 2919
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     2919 non-null   int64
#  1   MSZoning       2919 non-null   object
#  2   LotFrontage    2919 non-null   float64
#  3   LotArea        2919 non-null   int64
#  4   Street         2919 non-null   object
#  5   Alley          198 non-null    object
#  6   LotShape       2919 non-null   object
#  7   LandContour    2919 non-null   object
#  8   Utilities      2919 non-null   object
#  9   LotConfig      2919 non-null   object
#  10  LandSlope      2919 non-null   object
#  11  Neighborhood   2919 non-null   object
#  12  Condition1     2919 non-null   object
#  13  Condition2     2919 non-null   object
#  14  BldgType       2919 non-null   object
#  15  HouseStyle     2919 non-null   object
#  16  OverallQual    2919 non-null   int64
#  17  OverallCond    2919 non-null   int64
#  18  YearBuilt      2919 non-null   int64
#  19  YearRemodAdd   2919 non-null   int64
#  20  RoofStyle      2919 non-null   object
#  21  RoofMatl       2919 non-null   object
#  22  Exterior1st    2919 non-null   object
#  23  Exterior2nd    2919 non-null   object
#  24  MasVnrType     2919 non-null   object
#  25  MasVnrArea     2919 non-null   float64
#  26  ExterQual      2919 non-null   object
#  27  ExterCond      2919 non-null   object
#  28  Foundation     2919 non-null   object
#  29  BsmtQual       2917 non-null   object
#  30  BsmtCond       2919 non-null   object
#  31  BsmtExposure   2919 non-null   object
#  32  BsmtFinType1   2919 non-null   object
#  33  BsmtFinSF1     2919 non-null   float64
#  34  BsmtFinType2   2918 non-null   object
#  35  BsmtFinSF2     2919 non-null   float64
#  36  BsmtUnfSF      2919 non-null   float64
#  37  TotalBsmtSF    2918 non-null   float64
#  38  Heating        2919 non-null   object
#  39  HeatingQC      2919 non-null   object
#  40  CentralAir     2919 non-null   object
#  41  Electrical     2918 non-null   object
#  42  1stFlrSF       2919 non-null   int64
#  43  2ndFlrSF       2919 non-null   int64
#  44  LowQualFinSF   2919 non-null   int64
#  45  GrLivArea      2919 non-null   int64
#  46  BsmtFullBath   2917 non-null   float64
#  47  BsmtHalfBath   2917 non-null   float64
#  48  FullBath       2919 non-null   int64
#  49  HalfBath       2919 non-null   int64
#  50  BedroomAbvGr   2919 non-null   int64
#  51  KitchenAbvGr   2919 non-null   int64
#  52  KitchenQual    2918 non-null   object
#  53  TotRmsAbvGrd   2919 non-null   int64
#  54  Functional     2917 non-null   object
#  55  Fireplaces     2919 non-null   int64
#  56  FireplaceQu    1499 non-null   object
#  57  GarageType     2762 non-null   object
#  58  GarageYrBlt    2760 non-null   float64
#  59  GarageFinish   2760 non-null   object
#  60  GarageCars     2918 non-null   float64
#  61  GarageArea     2918 non-null   float64
#  62  GarageQual     2760 non-null   object
#  63  GarageCond     2760 non-null   object
#  64  PavedDrive     2919 non-null   object
#  65  WoodDeckSF     2919 non-null   int64
#  66  OpenPorchSF    2919 non-null   int64
#  67  EnclosedPorch  2919 non-null   int64
#  68  3SsnPorch      2919 non-null   int64
#  69  ScreenPorch    2919 non-null   int64
#  70  PoolArea       2919 non-null   int64
#  71  PoolQC         10 non-null     object
#  72  Fence          571 non-null    object
#  73  MiscFeature    105 non-null    object
#  74  MiscVal        2919 non-null   int64
#  75  MoSold         2919 non-null   int64
#  76  YrSold         2919 non-null   int64
#  77  SaleType       2918 non-null   object
#  78  SaleCondition  2919 non-null   object
#  79  SalePrice      2919 non-null   int64
# dtypes: float64(11), int64(26), object(43)
# memory usage: 1.8+ MB

# %%
is_one_basement_missing = pd.isnull(df['BsmtQual']) | pd.isnull(df['BsmtCond']) | pd.isnull(df['BsmtExposure']) | pd.isnull(df['BsmtFinType1']) | pd.isnull(df['BsmtFinType2'])
df.loc[is_one_basement_missing, 'BsmtQual':]
# Out:
#      BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  \
# Id
# 333        Gd       TA           No          GLQ      1124.0          NaN
# 2218      NaN       Fa           No          Unf         0.0          Unf
# 2219      NaN       TA           No          Unf         0.0          Unf
#
#       BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating  ... PoolArea PoolQC Fence  \
# Id                                                ...
# 333        479.0     1603.0       3206.0    GasA  ...        0    NaN   NaN
# 2218         0.0      173.0        173.0    GasA  ...        0    NaN   NaN
# 2219         0.0      356.0        356.0    GasA  ...        0    NaN   NaN
#
#       MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 333           NaN        0      10    2009        WD         Normal     284000
# 2218          NaN        0       7    2008        WD         Normal         -1
# 2219          NaN        0       5    2008        WD         Normal         -1
#
# [3 rows x 51 columns]

# %%
df.loc[df['BsmtCond'] == 'TA', 'BsmtQual'].value_counts()
# Out:
# TA    1179
# Gd    1134
# Ex     234
# Fa      61
# Name: BsmtQual, dtype: int64

# %%
df.loc[(df['BsmtCond'] == 'TA') & (df['BsmtExposure'] == 'No'), 'BsmtQual'].value_counts()
# Out:
# TA    964
# Gd    658
# Ex     70
# Fa     54
# Name: BsmtQual, dtype: int64

# %%
# Setting it to be TA since that seems to be the best choice
df.loc[pd.isnull(df['BsmtQual']) & (df['BsmtCond'] == 'TA'), 'BsmtQual'] = 'TA'

# %%
is_one_basement_missing = pd.isnull(df['BsmtQual']) | pd.isnull(df['BsmtCond']) | pd.isnull(df['BsmtExposure']) | pd.isnull(df['BsmtFinType1']) | pd.isnull(df['BsmtFinType2'])
df.loc[is_one_basement_missing, 'BsmtQual':]
# Out:
#      BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  \
# Id
# 333        Gd       TA           No          GLQ      1124.0          NaN
# 2218      NaN       Fa           No          Unf         0.0          Unf
#
#       BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating  ... PoolArea PoolQC Fence  \
# Id                                                ...
# 333        479.0     1603.0       3206.0    GasA  ...        0    NaN   NaN
# 2218         0.0      173.0        173.0    GasA  ...        0    NaN   NaN
#
#       MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 333           NaN        0      10    2009        WD         Normal     284000
# 2218          NaN        0       7    2008        WD         Normal         -1
#
# [2 rows x 51 columns]

# %%
df.loc[df['BsmtFinType1'] == 'GLQ', 'BsmtFinType2'].value_counts()
# Out:
# Unf    790
# Rec     19
# LwQ     17
# ALQ     15
# BLQ      7
# Name: BsmtFinType2, dtype: int64

# %% [markdown]
# Since there is a finishing surface area, we know it can't be 'Unf'

# %%
types = df['BsmtFinType1'].unique()

for _type in types:
    if _type == 'Unf' or _type == 'NA' or _type == 'TA' or _type is np.nan:
        continue
    plt.hist(df.loc[(df['BsmtFinType1'] == _type), 'BsmtFinSF1'], color = 'c', bins = 50)
    plt.xlabel(f'Surface area of finish type : {_type}')
    plt.ylabel('Frequency')
    plt.title(f'Frquency of Surface areas of type : {_type}')
    plt.tight_layout()
    plt.show()

# %%
types = df['BsmtFinType1'].unique()

for _type in types:
    if _type == 'Unf' or _type == 'NA' or _type == 'TA' or _type is np.nan:
        continue
    plt.hist(df.loc[(df['BsmtFinType1'] == _type) & (df['BsmtFinSF1'] < 600) & (df['BsmtFinSF1'] > 400), 'BsmtFinSF1'], color = 'c', bins = 10)
    plt.xlabel(f'Surface area of finish type : {_type}')
    plt.ylabel('Frequency')
    plt.title(f'Frquency of Surface areas of type : {_type}')
    plt.tight_layout()
    plt.show()

# %%
types = df['BsmtFinType1'].unique()
for _type in types:
    if _type == 'Unf' or _type == 'NA' or _type == 'TA' or _type is np.nan:
        continue
        
    count = df.loc[(df['BsmtFinType1'] == _type) & (df['BsmtFinSF1'] < 600) & (df['BsmtFinSF1'] > 400), 'BsmtFinSF1'].value_counts().sum()
    print(f"{_type} count : {count}")
# Out:
# GLQ count : 120
# ALQ count : 96
# Rec count : 66
# BLQ count : 75
# LwQ count : 27

# %% [markdown]
# Most houses with basement finishing surface areas in the range 400 - 600 are of type GLQ. Howeven its first finish is already set to GLQ. Hence I will set it to ALQ.

# %%
# Setting value to ALQ
df.loc[pd.isnull(df['BsmtFinType2']), 'BsmtFinType2'] = 'ALQ'

# %%
is_one_basement_missing = pd.isnull(df['BsmtQual']) | pd.isnull(df['BsmtCond']) | pd.isnull(df['BsmtExposure']) | pd.isnull(df['BsmtFinType1']) | pd.isnull(df['BsmtFinType2'])
df.loc[is_one_basement_missing, 'BsmtQual':]
# Out:
#      BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  \
# Id
# 2218      NaN       Fa           No          Unf         0.0          Unf
#
#       BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating  ... PoolArea PoolQC Fence  \
# Id                                                ...
# 2218         0.0      173.0        173.0    GasA  ...        0    NaN   NaN
#
#       MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 2218          NaN        0       7    2008        WD         Normal         -1
#
# [1 rows x 51 columns]

# %%
df.loc[df['BsmtCond'] == 'Fa', 'BsmtQual'].value_counts()
# Out:
# TA    72
# Fa    22
# Gd     9
# Name: BsmtQual, dtype: int64

# %%
# Setting it to TA as that is the most common occuring entry
df.loc[(df['BsmtCond'] == 'Fa') & pd.isnull(df['BsmtQual']), 'BsmtQual'] = 'TA'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 1 to 2919
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     2919 non-null   int64
#  1   MSZoning       2919 non-null   object
#  2   LotFrontage    2919 non-null   float64
#  3   LotArea        2919 non-null   int64
#  4   Street         2919 non-null   object
#  5   Alley          198 non-null    object
#  6   LotShape       2919 non-null   object
#  7   LandContour    2919 non-null   object
#  8   Utilities      2919 non-null   object
#  9   LotConfig      2919 non-null   object
#  10  LandSlope      2919 non-null   object
#  11  Neighborhood   2919 non-null   object
#  12  Condition1     2919 non-null   object
#  13  Condition2     2919 non-null   object
#  14  BldgType       2919 non-null   object
#  15  HouseStyle     2919 non-null   object
#  16  OverallQual    2919 non-null   int64
#  17  OverallCond    2919 non-null   int64
#  18  YearBuilt      2919 non-null   int64
#  19  YearRemodAdd   2919 non-null   int64
#  20  RoofStyle      2919 non-null   object
#  21  RoofMatl       2919 non-null   object
#  22  Exterior1st    2919 non-null   object
#  23  Exterior2nd    2919 non-null   object
#  24  MasVnrType     2919 non-null   object
#  25  MasVnrArea     2919 non-null   float64
#  26  ExterQual      2919 non-null   object
#  27  ExterCond      2919 non-null   object
#  28  Foundation     2919 non-null   object
#  29  BsmtQual       2919 non-null   object
#  30  BsmtCond       2919 non-null   object
#  31  BsmtExposure   2919 non-null   object
#  32  BsmtFinType1   2919 non-null   object
#  33  BsmtFinSF1     2919 non-null   float64
#  34  BsmtFinType2   2919 non-null   object
#  35  BsmtFinSF2     2919 non-null   float64
#  36  BsmtUnfSF      2919 non-null   float64
#  37  TotalBsmtSF    2918 non-null   float64
#  38  Heating        2919 non-null   object
#  39  HeatingQC      2919 non-null   object
#  40  CentralAir     2919 non-null   object
#  41  Electrical     2918 non-null   object
#  42  1stFlrSF       2919 non-null   int64
#  43  2ndFlrSF       2919 non-null   int64
#  44  LowQualFinSF   2919 non-null   int64
#  45  GrLivArea      2919 non-null   int64
#  46  BsmtFullBath   2917 non-null   float64
#  47  BsmtHalfBath   2917 non-null   float64
#  48  FullBath       2919 non-null   int64
#  49  HalfBath       2919 non-null   int64
#  50  BedroomAbvGr   2919 non-null   int64
#  51  KitchenAbvGr   2919 non-null   int64
#  52  KitchenQual    2918 non-null   object
#  53  TotRmsAbvGrd   2919 non-null   int64
#  54  Functional     2917 non-null   object
#  55  Fireplaces     2919 non-null   int64
#  56  FireplaceQu    1499 non-null   object
#  57  GarageType     2762 non-null   object
#  58  GarageYrBlt    2760 non-null   float64
#  59  GarageFinish   2760 non-null   object
#  60  GarageCars     2918 non-null   float64
#  61  GarageArea     2918 non-null   float64
#  62  GarageQual     2760 non-null   object
#  63  GarageCond     2760 non-null   object
#  64  PavedDrive     2919 non-null   object
#  65  WoodDeckSF     2919 non-null   int64
#  66  OpenPorchSF    2919 non-null   int64
#  67  EnclosedPorch  2919 non-null   int64
#  68  3SsnPorch      2919 non-null   int64
#  69  ScreenPorch    2919 non-null   int64
#  70  PoolArea       2919 non-null   int64
#  71  PoolQC         10 non-null     object
#  72  Fence          571 non-null    object
#  73  MiscFeature    105 non-null    object
#  74  MiscVal        2919 non-null   int64
#  75  MoSold         2919 non-null   int64
#  76  YrSold         2919 non-null   int64
#  77  SaleType       2918 non-null   object
#  78  SaleCondition  2919 non-null   object
#  79  SalePrice      2919 non-null   int64
# dtypes: float64(11), int64(26), object(43)
# memory usage: 1.8+ MB

# %%
# House with missing TotalBsmtSF value
df.loc[pd.isnull(df['TotalBsmtSF']), 'BsmtQual' :]
# Out:
#      BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  \
# Id
# 2121       NA       NA           NA           NA         0.0           NA
#
#       BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating  ... PoolArea PoolQC  Fence  \
# Id                                                ...
# 2121         0.0        0.0          NaN    GasA  ...        0    NaN  MnPrv
#
#       MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 2121          NaN        0       4    2008     ConLD        Abnorml         -1
#
# [1 rows x 51 columns]

# %%
# Setting it to 0 as there is no basement
df.loc[pd.isnull(df['TotalBsmtSF']), 'TotalBsmtSF'] = 0

# %%
# Checking to make sure nothing is abonormal
df.loc[df['BsmtQual'] == 'NA', 'TotalBsmtSF'].value_counts()
# Out:
# 0.0    79
# Name: TotalBsmtSF, dtype: int64

# %%
# All Basement features are now ready
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 1 to 2919
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     2919 non-null   int64
#  1   MSZoning       2919 non-null   object
#  2   LotFrontage    2919 non-null   float64
#  3   LotArea        2919 non-null   int64
#  4   Street         2919 non-null   object
#  5   Alley          198 non-null    object
#  6   LotShape       2919 non-null   object
#  7   LandContour    2919 non-null   object
#  8   Utilities      2919 non-null   object
#  9   LotConfig      2919 non-null   object
#  10  LandSlope      2919 non-null   object
#  11  Neighborhood   2919 non-null   object
#  12  Condition1     2919 non-null   object
#  13  Condition2     2919 non-null   object
#  14  BldgType       2919 non-null   object
#  15  HouseStyle     2919 non-null   object
#  16  OverallQual    2919 non-null   int64
#  17  OverallCond    2919 non-null   int64
#  18  YearBuilt      2919 non-null   int64
#  19  YearRemodAdd   2919 non-null   int64
#  20  RoofStyle      2919 non-null   object
#  21  RoofMatl       2919 non-null   object
#  22  Exterior1st    2919 non-null   object
#  23  Exterior2nd    2919 non-null   object
#  24  MasVnrType     2919 non-null   object
#  25  MasVnrArea     2919 non-null   float64
#  26  ExterQual      2919 non-null   object
#  27  ExterCond      2919 non-null   object
#  28  Foundation     2919 non-null   object
#  29  BsmtQual       2919 non-null   object
#  30  BsmtCond       2919 non-null   object
#  31  BsmtExposure   2919 non-null   object
#  32  BsmtFinType1   2919 non-null   object
#  33  BsmtFinSF1     2919 non-null   float64
#  34  BsmtFinType2   2919 non-null   object
#  35  BsmtFinSF2     2919 non-null   float64
#  36  BsmtUnfSF      2919 non-null   float64
#  37  TotalBsmtSF    2919 non-null   float64
#  38  Heating        2919 non-null   object
#  39  HeatingQC      2919 non-null   object
#  40  CentralAir     2919 non-null   object
#  41  Electrical     2918 non-null   object
#  42  1stFlrSF       2919 non-null   int64
#  43  2ndFlrSF       2919 non-null   int64
#  44  LowQualFinSF   2919 non-null   int64
#  45  GrLivArea      2919 non-null   int64
#  46  BsmtFullBath   2917 non-null   float64
#  47  BsmtHalfBath   2917 non-null   float64
#  48  FullBath       2919 non-null   int64
#  49  HalfBath       2919 non-null   int64
#  50  BedroomAbvGr   2919 non-null   int64
#  51  KitchenAbvGr   2919 non-null   int64
#  52  KitchenQual    2918 non-null   object
#  53  TotRmsAbvGrd   2919 non-null   int64
#  54  Functional     2917 non-null   object
#  55  Fireplaces     2919 non-null   int64
#  56  FireplaceQu    1499 non-null   object
#  57  GarageType     2762 non-null   object
#  58  GarageYrBlt    2760 non-null   float64
#  59  GarageFinish   2760 non-null   object
#  60  GarageCars     2918 non-null   float64
#  61  GarageArea     2918 non-null   float64
#  62  GarageQual     2760 non-null   object
#  63  GarageCond     2760 non-null   object
#  64  PavedDrive     2919 non-null   object
#  65  WoodDeckSF     2919 non-null   int64
#  66  OpenPorchSF    2919 non-null   int64
#  67  EnclosedPorch  2919 non-null   int64
#  68  3SsnPorch      2919 non-null   int64
#  69  ScreenPorch    2919 non-null   int64
#  70  PoolArea       2919 non-null   int64
#  71  PoolQC         10 non-null     object
#  72  Fence          571 non-null    object
#  73  MiscFeature    105 non-null    object
#  74  MiscVal        2919 non-null   int64
#  75  MoSold         2919 non-null   int64
#  76  YrSold         2919 non-null   int64
#  77  SaleType       2918 non-null   object
#  78  SaleCondition  2919 non-null   object
#  79  SalePrice      2919 non-null   int64
# dtypes: float64(11), int64(26), object(43)
# memory usage: 1.8+ MB

# %% [markdown]
# ## Feature : Electrical

# %%
# House with missing value in electrical feature
df[pd.isnull(df['Electrical'])]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1380          80       RL         73.0     9735   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                    ...
# 1380         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1380       0      5    2008        WD         Normal     167500
#
# [1 rows x 80 columns]

# %%
# Distribution of entries
df['Electrical'].value_counts()
# Out:
# SBrkr    2671
# FuseA     188
# FuseF      50
# FuseP       8
# Mix         1
# Name: Electrical, dtype: int64

# %%
# Setting the value to SBrkr since the house has a relatively high class and also since that is the most common entry
df.loc[pd.isnull(df['Electrical']), 'Electrical'] = 'SBrkr'

# %%
# Checking if update done correctly
df['Electrical'].value_counts()
# Out:
# SBrkr    2672
# FuseA     188
# FuseF      50
# FuseP       8
# Mix         1
# Name: Electrical, dtype: int64

# %%
# Electrical Feature is now complete
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 1 to 2919
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     2919 non-null   int64
#  1   MSZoning       2919 non-null   object
#  2   LotFrontage    2919 non-null   float64
#  3   LotArea        2919 non-null   int64
#  4   Street         2919 non-null   object
#  5   Alley          198 non-null    object
#  6   LotShape       2919 non-null   object
#  7   LandContour    2919 non-null   object
#  8   Utilities      2919 non-null   object
#  9   LotConfig      2919 non-null   object
#  10  LandSlope      2919 non-null   object
#  11  Neighborhood   2919 non-null   object
#  12  Condition1     2919 non-null   object
#  13  Condition2     2919 non-null   object
#  14  BldgType       2919 non-null   object
#  15  HouseStyle     2919 non-null   object
#  16  OverallQual    2919 non-null   int64
#  17  OverallCond    2919 non-null   int64
#  18  YearBuilt      2919 non-null   int64
#  19  YearRemodAdd   2919 non-null   int64
#  20  RoofStyle      2919 non-null   object
#  21  RoofMatl       2919 non-null   object
#  22  Exterior1st    2919 non-null   object
#  23  Exterior2nd    2919 non-null   object
#  24  MasVnrType     2919 non-null   object
#  25  MasVnrArea     2919 non-null   float64
#  26  ExterQual      2919 non-null   object
#  27  ExterCond      2919 non-null   object
#  28  Foundation     2919 non-null   object
#  29  BsmtQual       2919 non-null   object
#  30  BsmtCond       2919 non-null   object
#  31  BsmtExposure   2919 non-null   object
#  32  BsmtFinType1   2919 non-null   object
#  33  BsmtFinSF1     2919 non-null   float64
#  34  BsmtFinType2   2919 non-null   object
#  35  BsmtFinSF2     2919 non-null   float64
#  36  BsmtUnfSF      2919 non-null   float64
#  37  TotalBsmtSF    2919 non-null   float64
#  38  Heating        2919 non-null   object
#  39  HeatingQC      2919 non-null   object
#  40  CentralAir     2919 non-null   object
#  41  Electrical     2919 non-null   object
#  42  1stFlrSF       2919 non-null   int64
#  43  2ndFlrSF       2919 non-null   int64
#  44  LowQualFinSF   2919 non-null   int64
#  45  GrLivArea      2919 non-null   int64
#  46  BsmtFullBath   2917 non-null   float64
#  47  BsmtHalfBath   2917 non-null   float64
#  48  FullBath       2919 non-null   int64
#  49  HalfBath       2919 non-null   int64
#  50  BedroomAbvGr   2919 non-null   int64
#  51  KitchenAbvGr   2919 non-null   int64
#  52  KitchenQual    2918 non-null   object
#  53  TotRmsAbvGrd   2919 non-null   int64
#  54  Functional     2917 non-null   object
#  55  Fireplaces     2919 non-null   int64
#  56  FireplaceQu    1499 non-null   object
#  57  GarageType     2762 non-null   object
#  58  GarageYrBlt    2760 non-null   float64
#  59  GarageFinish   2760 non-null   object
#  60  GarageCars     2918 non-null   float64
#  61  GarageArea     2918 non-null   float64
#  62  GarageQual     2760 non-null   object
#  63  GarageCond     2760 non-null   object
#  64  PavedDrive     2919 non-null   object
#  65  WoodDeckSF     2919 non-null   int64
#  66  OpenPorchSF    2919 non-null   int64
#  67  EnclosedPorch  2919 non-null   int64
#  68  3SsnPorch      2919 non-null   int64
#  69  ScreenPorch    2919 non-null   int64
#  70  PoolArea       2919 non-null   int64
#  71  PoolQC         10 non-null     object
#  72  Fence          571 non-null    object
#  73  MiscFeature    105 non-null    object
#  74  MiscVal        2919 non-null   int64
#  75  MoSold         2919 non-null   int64
#  76  YrSold         2919 non-null   int64
#  77  SaleType       2918 non-null   object
#  78  SaleCondition  2919 non-null   object
#  79  SalePrice      2919 non-null   int64
# dtypes: float64(11), int64(26), object(43)
# memory usage: 1.8+ MB

# %% [markdown]
# ## Feature : Basment bathrooms

# %%
# House with missing basement full bathroom values
df.loc[pd.isnull(df['BsmtFullBath']), 'BsmtQual':]
# Out:
#      BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  \
# Id
# 2121       NA       NA           NA           NA         0.0           NA
# 2189       NA       NA           NA           NA         0.0           NA
#
#       BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating  ... PoolArea PoolQC  Fence  \
# Id                                                ...
# 2121         0.0        0.0          0.0    GasA  ...        0    NaN  MnPrv
# 2189         0.0        0.0          0.0    GasA  ...        0    NaN    NaN
#
#       MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 2121          NaN        0       4    2008     ConLD        Abnorml         -1
# 2189          NaN        0       7    2008        WD         Normal         -1
#
# [2 rows x 51 columns]

# %%
# House with missing basement half bathroom values
df.loc[pd.isnull(df['BsmtHalfBath']), 'BsmtQual':]
# Out:
#      BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  \
# Id
# 2121       NA       NA           NA           NA         0.0           NA
# 2189       NA       NA           NA           NA         0.0           NA
#
#       BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating  ... PoolArea PoolQC  Fence  \
# Id                                                ...
# 2121         0.0        0.0          0.0    GasA  ...        0    NaN  MnPrv
# 2189         0.0        0.0          0.0    GasA  ...        0    NaN    NaN
#
#       MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 2121          NaN        0       4    2008     ConLD        Abnorml         -1
# 2189          NaN        0       7    2008        WD         Normal         -1
#
# [2 rows x 51 columns]

# %% [markdown]
# Since all of these houses do not have basements, I will set the basement bathroom count to be 0.

# %%
# Setting values to 0
df.loc[pd.isnull(df['BsmtFullBath']), 'BsmtFullBath'] = 0
df.loc[pd.isnull(df['BsmtHalfBath']), 'BsmtHalfBath'] = 0

# %%
# Checking to see if there are any houses whose entires are impossible
df.loc[(df['BsmtFullBath'] != 0) & (df['BsmtQual'] == 'NA')]
# Out:
# Empty DataFrame
# Columns: [MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []
#
# [0 rows x 80 columns]

# %% [markdown]
# There aren't any such houses.

# %%
# Basement Bathroom count feature is now complete
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 1 to 2919
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     2919 non-null   int64
#  1   MSZoning       2919 non-null   object
#  2   LotFrontage    2919 non-null   float64
#  3   LotArea        2919 non-null   int64
#  4   Street         2919 non-null   object
#  5   Alley          198 non-null    object
#  6   LotShape       2919 non-null   object
#  7   LandContour    2919 non-null   object
#  8   Utilities      2919 non-null   object
#  9   LotConfig      2919 non-null   object
#  10  LandSlope      2919 non-null   object
#  11  Neighborhood   2919 non-null   object
#  12  Condition1     2919 non-null   object
#  13  Condition2     2919 non-null   object
#  14  BldgType       2919 non-null   object
#  15  HouseStyle     2919 non-null   object
#  16  OverallQual    2919 non-null   int64
#  17  OverallCond    2919 non-null   int64
#  18  YearBuilt      2919 non-null   int64
#  19  YearRemodAdd   2919 non-null   int64
#  20  RoofStyle      2919 non-null   object
#  21  RoofMatl       2919 non-null   object
#  22  Exterior1st    2919 non-null   object
#  23  Exterior2nd    2919 non-null   object
#  24  MasVnrType     2919 non-null   object
#  25  MasVnrArea     2919 non-null   float64
#  26  ExterQual      2919 non-null   object
#  27  ExterCond      2919 non-null   object
#  28  Foundation     2919 non-null   object
#  29  BsmtQual       2919 non-null   object
#  30  BsmtCond       2919 non-null   object
#  31  BsmtExposure   2919 non-null   object
#  32  BsmtFinType1   2919 non-null   object
#  33  BsmtFinSF1     2919 non-null   float64
#  34  BsmtFinType2   2919 non-null   object
#  35  BsmtFinSF2     2919 non-null   float64
#  36  BsmtUnfSF      2919 non-null   float64
#  37  TotalBsmtSF    2919 non-null   float64
#  38  Heating        2919 non-null   object
#  39  HeatingQC      2919 non-null   object
#  40  CentralAir     2919 non-null   object
#  41  Electrical     2919 non-null   object
#  42  1stFlrSF       2919 non-null   int64
#  43  2ndFlrSF       2919 non-null   int64
#  44  LowQualFinSF   2919 non-null   int64
#  45  GrLivArea      2919 non-null   int64
#  46  BsmtFullBath   2919 non-null   float64
#  47  BsmtHalfBath   2919 non-null   float64
#  48  FullBath       2919 non-null   int64
#  49  HalfBath       2919 non-null   int64
#  50  BedroomAbvGr   2919 non-null   int64
#  51  KitchenAbvGr   2919 non-null   int64
#  52  KitchenQual    2918 non-null   object
#  53  TotRmsAbvGrd   2919 non-null   int64
#  54  Functional     2917 non-null   object
#  55  Fireplaces     2919 non-null   int64
#  56  FireplaceQu    1499 non-null   object
#  57  GarageType     2762 non-null   object
#  58  GarageYrBlt    2760 non-null   float64
#  59  GarageFinish   2760 non-null   object
#  60  GarageCars     2918 non-null   float64
#  61  GarageArea     2918 non-null   float64
#  62  GarageQual     2760 non-null   object
#  63  GarageCond     2760 non-null   object
#  64  PavedDrive     2919 non-null   object
#  65  WoodDeckSF     2919 non-null   int64
#  66  OpenPorchSF    2919 non-null   int64
#  67  EnclosedPorch  2919 non-null   int64
#  68  3SsnPorch      2919 non-null   int64
#  69  ScreenPorch    2919 non-null   int64
#  70  PoolArea       2919 non-null   int64
#  71  PoolQC         10 non-null     object
#  72  Fence          571 non-null    object
#  73  MiscFeature    105 non-null    object
#  74  MiscVal        2919 non-null   int64
#  75  MoSold         2919 non-null   int64
#  76  YrSold         2919 non-null   int64
#  77  SaleType       2918 non-null   object
#  78  SaleCondition  2919 non-null   object
#  79  SalePrice      2919 non-null   int64
# dtypes: float64(11), int64(26), object(43)
# memory usage: 1.8+ MB

# %% [markdown]
# ## Feature : Kitchen

# %%
# Houses with ivalid entry in KitchenQual feature
df.loc[pd.isnull(df['KitchenQual']), 'KitchenAbvGr':]
# Out:
#       KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces  \
# Id
# 1556             1         NaN             6        Mod           0
#
#      FireplaceQu GarageType  GarageYrBlt GarageFinish  GarageCars  ...  \
# Id                                                                 ...
# 1556         NaN     Detchd       1917.0          Unf         1.0  ...
#
#       PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  SaleType  \
# Id
# 1556         0    NaN   NaN         NaN        0       1    2010       COD
#
#       SaleCondition  SalePrice
# Id
# 1556         Normal         -1
#
# [1 rows x 29 columns]

# %%
# Houses with ivalid entry in KitchenQual feature
df.loc[pd.isnull(df['KitchenQual'])]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1556          50       RL         72.0    10632   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                    ...
# 1556         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1556       0      1    2010       COD         Normal         -1
#
# [1 rows x 80 columns]

# %%
# Distribution of KitchenQual
df['KitchenQual'].value_counts()
# Out:
# TA    1492
# Gd    1151
# Ex     205
# Fa      70
# Name: KitchenQual, dtype: int64

# %%
# Distribution of KitchenAbvGr
df['KitchenAbvGr'].value_counts()
# Out:
# 1    2785
# 2     129
# 0       3
# 3       2
# Name: KitchenAbvGr, dtype: int64

# %%
# KitchenQual of houses with Kitchen above grade 1
df.loc[df['KitchenAbvGr'] == 1, 'KitchenQual'].value_counts()
# Out:
# TA    1372
# Gd    1146
# Ex     205
# Fa      61
# Name: KitchenQual, dtype: int64

# %%
# KitchenQual of houses with Kitchen above grade 1 and class is 50
df.loc[(df['KitchenAbvGr'] == 1) & (df['MSSubClass'] == 50), 'KitchenQual'].value_counts()
# Out:
# TA    206
# Gd     57
# Fa     16
# Ex      4
# Name: KitchenQual, dtype: int64

# %% [markdown]
# TA (Typical / Average) seems to be the best entry from the above distribution.

# %%
# Houses with ivalid entry in KitchenQual feature
df.loc[pd.isnull(df['KitchenQual']), 'KitchenQual'] = 'TA'

# %%
# Checking to see update done correctly
df['KitchenQual'].value_counts()
# Out:
# TA    1493
# Gd    1151
# Ex     205
# Fa      70
# Name: KitchenQual, dtype: int64

# %%
# Kitchen features are now complete
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 1 to 2919
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     2919 non-null   int64
#  1   MSZoning       2919 non-null   object
#  2   LotFrontage    2919 non-null   float64
#  3   LotArea        2919 non-null   int64
#  4   Street         2919 non-null   object
#  5   Alley          198 non-null    object
#  6   LotShape       2919 non-null   object
#  7   LandContour    2919 non-null   object
#  8   Utilities      2919 non-null   object
#  9   LotConfig      2919 non-null   object
#  10  LandSlope      2919 non-null   object
#  11  Neighborhood   2919 non-null   object
#  12  Condition1     2919 non-null   object
#  13  Condition2     2919 non-null   object
#  14  BldgType       2919 non-null   object
#  15  HouseStyle     2919 non-null   object
#  16  OverallQual    2919 non-null   int64
#  17  OverallCond    2919 non-null   int64
#  18  YearBuilt      2919 non-null   int64
#  19  YearRemodAdd   2919 non-null   int64
#  20  RoofStyle      2919 non-null   object
#  21  RoofMatl       2919 non-null   object
#  22  Exterior1st    2919 non-null   object
#  23  Exterior2nd    2919 non-null   object
#  24  MasVnrType     2919 non-null   object
#  25  MasVnrArea     2919 non-null   float64
#  26  ExterQual      2919 non-null   object
#  27  ExterCond      2919 non-null   object
#  28  Foundation     2919 non-null   object
#  29  BsmtQual       2919 non-null   object
#  30  BsmtCond       2919 non-null   object
#  31  BsmtExposure   2919 non-null   object
#  32  BsmtFinType1   2919 non-null   object
#  33  BsmtFinSF1     2919 non-null   float64
#  34  BsmtFinType2   2919 non-null   object
#  35  BsmtFinSF2     2919 non-null   float64
#  36  BsmtUnfSF      2919 non-null   float64
#  37  TotalBsmtSF    2919 non-null   float64
#  38  Heating        2919 non-null   object
#  39  HeatingQC      2919 non-null   object
#  40  CentralAir     2919 non-null   object
#  41  Electrical     2919 non-null   object
#  42  1stFlrSF       2919 non-null   int64
#  43  2ndFlrSF       2919 non-null   int64
#  44  LowQualFinSF   2919 non-null   int64
#  45  GrLivArea      2919 non-null   int64
#  46  BsmtFullBath   2919 non-null   float64
#  47  BsmtHalfBath   2919 non-null   float64
#  48  FullBath       2919 non-null   int64
#  49  HalfBath       2919 non-null   int64
#  50  BedroomAbvGr   2919 non-null   int64
#  51  KitchenAbvGr   2919 non-null   int64
#  52  KitchenQual    2919 non-null   object
#  53  TotRmsAbvGrd   2919 non-null   int64
#  54  Functional     2917 non-null   object
#  55  Fireplaces     2919 non-null   int64
#  56  FireplaceQu    1499 non-null   object
#  57  GarageType     2762 non-null   object
#  58  GarageYrBlt    2760 non-null   float64
#  59  GarageFinish   2760 non-null   object
#  60  GarageCars     2918 non-null   float64
#  61  GarageArea     2918 non-null   float64
#  62  GarageQual     2760 non-null   object
#  63  GarageCond     2760 non-null   object
#  64  PavedDrive     2919 non-null   object
#  65  WoodDeckSF     2919 non-null   int64
#  66  OpenPorchSF    2919 non-null   int64
#  67  EnclosedPorch  2919 non-null   int64
#  68  3SsnPorch      2919 non-null   int64
#  69  ScreenPorch    2919 non-null   int64
#  70  PoolArea       2919 non-null   int64
#  71  PoolQC         10 non-null     object
#  72  Fence          571 non-null    object
#  73  MiscFeature    105 non-null    object
#  74  MiscVal        2919 non-null   int64
#  75  MoSold         2919 non-null   int64
#  76  YrSold         2919 non-null   int64
#  77  SaleType       2918 non-null   object
#  78  SaleCondition  2919 non-null   object
#  79  SalePrice      2919 non-null   int64
# dtypes: float64(11), int64(26), object(43)
# memory usage: 1.8+ MB

# %% [markdown]
# ## Feature : Fuctional

# %%
# Houses with invalid entry in Functional feature
df[pd.isnull(df['Functional'])]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 2217          20       RL         80.0    14584   Pave   NaN      Reg
# 2474          50       RM         60.0    10320   Pave  Grvl      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                    ...
# 2217         Low    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2474         Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 2217       0      2    2008        WD        Abnorml         -1
# 2474       0      9    2007       COD        Abnorml         -1
#
# [2 rows x 80 columns]

# %%
# Distribution of this feature
df['Functional'].value_counts()
# Out:
# Typ     2717
# Min2      70
# Min1      65
# Mod       35
# Maj1      19
# Maj2       9
# Sev        2
# Name: Functional, dtype: int64

# %%
# Setting missing values to typical by default
df.loc[pd.isnull(df['Functional']), 'Functional'] = 'Typ'

# %%
# Checkig if update done as expected
df['Functional'].value_counts()
# Out:
# Typ     2719
# Min2      70
# Min1      65
# Mod       35
# Maj1      19
# Maj2       9
# Sev        2
# Name: Functional, dtype: int64

# %%
# Functional Feature is now complete
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 1 to 2919
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     2919 non-null   int64
#  1   MSZoning       2919 non-null   object
#  2   LotFrontage    2919 non-null   float64
#  3   LotArea        2919 non-null   int64
#  4   Street         2919 non-null   object
#  5   Alley          198 non-null    object
#  6   LotShape       2919 non-null   object
#  7   LandContour    2919 non-null   object
#  8   Utilities      2919 non-null   object
#  9   LotConfig      2919 non-null   object
#  10  LandSlope      2919 non-null   object
#  11  Neighborhood   2919 non-null   object
#  12  Condition1     2919 non-null   object
#  13  Condition2     2919 non-null   object
#  14  BldgType       2919 non-null   object
#  15  HouseStyle     2919 non-null   object
#  16  OverallQual    2919 non-null   int64
#  17  OverallCond    2919 non-null   int64
#  18  YearBuilt      2919 non-null   int64
#  19  YearRemodAdd   2919 non-null   int64
#  20  RoofStyle      2919 non-null   object
#  21  RoofMatl       2919 non-null   object
#  22  Exterior1st    2919 non-null   object
#  23  Exterior2nd    2919 non-null   object
#  24  MasVnrType     2919 non-null   object
#  25  MasVnrArea     2919 non-null   float64
#  26  ExterQual      2919 non-null   object
#  27  ExterCond      2919 non-null   object
#  28  Foundation     2919 non-null   object
#  29  BsmtQual       2919 non-null   object
#  30  BsmtCond       2919 non-null   object
#  31  BsmtExposure   2919 non-null   object
#  32  BsmtFinType1   2919 non-null   object
#  33  BsmtFinSF1     2919 non-null   float64
#  34  BsmtFinType2   2919 non-null   object
#  35  BsmtFinSF2     2919 non-null   float64
#  36  BsmtUnfSF      2919 non-null   float64
#  37  TotalBsmtSF    2919 non-null   float64
#  38  Heating        2919 non-null   object
#  39  HeatingQC      2919 non-null   object
#  40  CentralAir     2919 non-null   object
#  41  Electrical     2919 non-null   object
#  42  1stFlrSF       2919 non-null   int64
#  43  2ndFlrSF       2919 non-null   int64
#  44  LowQualFinSF   2919 non-null   int64
#  45  GrLivArea      2919 non-null   int64
#  46  BsmtFullBath   2919 non-null   float64
#  47  BsmtHalfBath   2919 non-null   float64
#  48  FullBath       2919 non-null   int64
#  49  HalfBath       2919 non-null   int64
#  50  BedroomAbvGr   2919 non-null   int64
#  51  KitchenAbvGr   2919 non-null   int64
#  52  KitchenQual    2919 non-null   object
#  53  TotRmsAbvGrd   2919 non-null   int64
#  54  Functional     2919 non-null   object
#  55  Fireplaces     2919 non-null   int64
#  56  FireplaceQu    1499 non-null   object
#  57  GarageType     2762 non-null   object
#  58  GarageYrBlt    2760 non-null   float64
#  59  GarageFinish   2760 non-null   object
#  60  GarageCars     2918 non-null   float64
#  61  GarageArea     2918 non-null   float64
#  62  GarageQual     2760 non-null   object
#  63  GarageCond     2760 non-null   object
#  64  PavedDrive     2919 non-null   object
#  65  WoodDeckSF     2919 non-null   int64
#  66  OpenPorchSF    2919 non-null   int64
#  67  EnclosedPorch  2919 non-null   int64
#  68  3SsnPorch      2919 non-null   int64
#  69  ScreenPorch    2919 non-null   int64
#  70  PoolArea       2919 non-null   int64
#  71  PoolQC         10 non-null     object
#  72  Fence          571 non-null    object
#  73  MiscFeature    105 non-null    object
#  74  MiscVal        2919 non-null   int64
#  75  MoSold         2919 non-null   int64
#  76  YrSold         2919 non-null   int64
#  77  SaleType       2918 non-null   object
#  78  SaleCondition  2919 non-null   object
#  79  SalePrice      2919 non-null   int64
# dtypes: float64(11), int64(26), object(43)
# memory usage: 1.8+ MB

# %% [markdown]
# ## Feature : Fireplace

# %%
# Houses with missing values in the FireplaceQu feature
df[pd.isnull(df['FireplaceQu'])]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL    65.000000     8450   Pave   NaN      Reg
# 6             50       RL    85.000000    14115   Pave   NaN      IR1
# 11            20       RL    70.000000    11200   Pave   NaN      Reg
# 13            20       RL    83.650517    12968   Pave   NaN      IR2
# 16            45       RM    51.000000     6120   Pave   NaN      Reg
# ...          ...      ...          ...      ...    ...   ...      ...
# 2913         160       RM    21.000000     1533   Pave   NaN      Reg
# 2914         160       RM    21.000000     1526   Pave   NaN      Reg
# 2915         160       RM    21.000000     1936   Pave   NaN      Reg
# 2916         160       RM    21.000000     1894   Pave   NaN      Reg
# 2918          85       RL    62.000000    10441   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# 1            Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 6            Lvl    AllPub    Inside  ...        0    NaN  MnPrv        Shed
# 11           Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 13           Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 16           Lvl    AllPub    Corner  ...        0    NaN  GdPrv         NaN
# ...          ...       ...       ...  ...      ...    ...    ...         ...
# 2913         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 2914         Lvl    AllPub    Inside  ...        0    NaN  GdPrv         NaN
# 2915         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 2916         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 2918         Lvl    AllPub    Inside  ...        0    NaN  MnPrv        Shed
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1          0      2    2008        WD         Normal     208500
# 6        700     10    2009        WD         Normal     143000
# 11         0      2    2008        WD         Normal     129500
# 13         0      9    2008        WD         Normal     144000
# 16         0      7    2007        WD         Normal     132000
# ...      ...    ...     ...       ...            ...        ...
# 2913       0     12    2006        WD        Abnorml         -1
# 2914       0      6    2006        WD         Normal         -1
# 2915       0      6    2006        WD         Normal         -1
# 2916       0      4    2006        WD        Abnorml         -1
# 2918     700      7    2006        WD         Normal         -1
#
# [1420 rows x 80 columns]

# %%
df.loc[pd.isnull(df['FireplaceQu']), 'Fireplaces':]
# Out:
#       Fireplaces FireplaceQu GarageType  GarageYrBlt GarageFinish  GarageCars  \
# Id
# 1              0         NaN     Attchd       2003.0          RFn         2.0
# 6              0         NaN     Attchd       1993.0          Unf         2.0
# 11             0         NaN     Detchd       1965.0          Unf         1.0
# 13             0         NaN     Detchd       1962.0          Unf         1.0
# 16             0         NaN     Detchd       1991.0          Unf         2.0
# ...          ...         ...        ...          ...          ...         ...
# 2913           0         NaN    CarPort       1970.0          Unf         1.0
# 2914           0         NaN        NaN          NaN          NaN         0.0
# 2915           0         NaN        NaN          NaN          NaN         0.0
# 2916           0         NaN    CarPort       1970.0          Unf         1.0
# 2918           0         NaN        NaN          NaN          NaN         0.0
#
#       GarageArea GarageQual GarageCond PavedDrive  ...  PoolArea  PoolQC  \
# Id                                                 ...
# 1          548.0         TA         TA          Y  ...         0     NaN
# 6          480.0         TA         TA          Y  ...         0     NaN
# 11         384.0         TA         TA          Y  ...         0     NaN
# 13         352.0         TA         TA          Y  ...         0     NaN
# 16         576.0         TA         TA          Y  ...         0     NaN
# ...          ...        ...        ...        ...  ...       ...     ...
# 2913       286.0         TA         TA          Y  ...         0     NaN
# 2914         0.0        NaN        NaN          Y  ...         0     NaN
# 2915         0.0        NaN        NaN          Y  ...         0     NaN
# 2916       286.0         TA         TA          Y  ...         0     NaN
# 2918         0.0        NaN        NaN          Y  ...         0     NaN
#
#       Fence  MiscFeature  MiscVal  MoSold YrSold SaleType SaleCondition  \
# Id
# 1       NaN          NaN        0       2   2008       WD        Normal
# 6     MnPrv         Shed      700      10   2009       WD        Normal
# 11      NaN          NaN        0       2   2008       WD        Normal
# 13      NaN          NaN        0       9   2008       WD        Normal
# 16    GdPrv          NaN        0       7   2007       WD        Normal
# ...     ...          ...      ...     ...    ...      ...           ...
# 2913    NaN          NaN        0      12   2006       WD       Abnorml
# 2914  GdPrv          NaN        0       6   2006       WD        Normal
# 2915    NaN          NaN        0       6   2006       WD        Normal
# 2916    NaN          NaN        0       4   2006       WD       Abnorml
# 2918  MnPrv         Shed      700       7   2006       WD        Normal
#
#       SalePrice
# Id
# 1        208500
# 6        143000
# 11       129500
# 13       144000
# 16       132000
# ...         ...
# 2913         -1
# 2914         -1
# 2915         -1
# 2916         -1
# 2918         -1
#
# [1420 rows x 25 columns]

# %%
# Distribution of entries in FireplaceQu feature
df['FireplaceQu'].value_counts()
# Out:
# Gd    744
# TA    592
# Fa     74
# Po     46
# Ex     43
# Name: FireplaceQu, dtype: int64

# %%
# Distrubtion of number of fireplaces for houses with missing FireplaceQu values
df.loc[pd.isnull(df['FireplaceQu']), 'Fireplaces'].value_counts()
# Out:
# 0    1420
# Name: Fireplaces, dtype: int64

# %% [markdown]
# All of these houses, do not contain fireplaces. Hence I will set the missing values to 'NA' (No fireplace).

# %%
# Setting missing values to 'NA'
df.loc[pd.isnull(df['FireplaceQu']), 'FireplaceQu'] = 'NA'

# %%
# Checking if update done correclty
df['FireplaceQu'].value_counts()
# Out:
# NA    1420
# Gd     744
# TA     592
# Fa      74
# Po      46
# Ex      43
# Name: FireplaceQu, dtype: int64

# %%
# FireplaceQu Feature now complete
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 1 to 2919
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     2919 non-null   int64
#  1   MSZoning       2919 non-null   object
#  2   LotFrontage    2919 non-null   float64
#  3   LotArea        2919 non-null   int64
#  4   Street         2919 non-null   object
#  5   Alley          198 non-null    object
#  6   LotShape       2919 non-null   object
#  7   LandContour    2919 non-null   object
#  8   Utilities      2919 non-null   object
#  9   LotConfig      2919 non-null   object
#  10  LandSlope      2919 non-null   object
#  11  Neighborhood   2919 non-null   object
#  12  Condition1     2919 non-null   object
#  13  Condition2     2919 non-null   object
#  14  BldgType       2919 non-null   object
#  15  HouseStyle     2919 non-null   object
#  16  OverallQual    2919 non-null   int64
#  17  OverallCond    2919 non-null   int64
#  18  YearBuilt      2919 non-null   int64
#  19  YearRemodAdd   2919 non-null   int64
#  20  RoofStyle      2919 non-null   object
#  21  RoofMatl       2919 non-null   object
#  22  Exterior1st    2919 non-null   object
#  23  Exterior2nd    2919 non-null   object
#  24  MasVnrType     2919 non-null   object
#  25  MasVnrArea     2919 non-null   float64
#  26  ExterQual      2919 non-null   object
#  27  ExterCond      2919 non-null   object
#  28  Foundation     2919 non-null   object
#  29  BsmtQual       2919 non-null   object
#  30  BsmtCond       2919 non-null   object
#  31  BsmtExposure   2919 non-null   object
#  32  BsmtFinType1   2919 non-null   object
#  33  BsmtFinSF1     2919 non-null   float64
#  34  BsmtFinType2   2919 non-null   object
#  35  BsmtFinSF2     2919 non-null   float64
#  36  BsmtUnfSF      2919 non-null   float64
#  37  TotalBsmtSF    2919 non-null   float64
#  38  Heating        2919 non-null   object
#  39  HeatingQC      2919 non-null   object
#  40  CentralAir     2919 non-null   object
#  41  Electrical     2919 non-null   object
#  42  1stFlrSF       2919 non-null   int64
#  43  2ndFlrSF       2919 non-null   int64
#  44  LowQualFinSF   2919 non-null   int64
#  45  GrLivArea      2919 non-null   int64
#  46  BsmtFullBath   2919 non-null   float64
#  47  BsmtHalfBath   2919 non-null   float64
#  48  FullBath       2919 non-null   int64
#  49  HalfBath       2919 non-null   int64
#  50  BedroomAbvGr   2919 non-null   int64
#  51  KitchenAbvGr   2919 non-null   int64
#  52  KitchenQual    2919 non-null   object
#  53  TotRmsAbvGrd   2919 non-null   int64
#  54  Functional     2919 non-null   object
#  55  Fireplaces     2919 non-null   int64
#  56  FireplaceQu    2919 non-null   object
#  57  GarageType     2762 non-null   object
#  58  GarageYrBlt    2760 non-null   float64
#  59  GarageFinish   2760 non-null   object
#  60  GarageCars     2918 non-null   float64
#  61  GarageArea     2918 non-null   float64
#  62  GarageQual     2760 non-null   object
#  63  GarageCond     2760 non-null   object
#  64  PavedDrive     2919 non-null   object
#  65  WoodDeckSF     2919 non-null   int64
#  66  OpenPorchSF    2919 non-null   int64
#  67  EnclosedPorch  2919 non-null   int64
#  68  3SsnPorch      2919 non-null   int64
#  69  ScreenPorch    2919 non-null   int64
#  70  PoolArea       2919 non-null   int64
#  71  PoolQC         10 non-null     object
#  72  Fence          571 non-null    object
#  73  MiscFeature    105 non-null    object
#  74  MiscVal        2919 non-null   int64
#  75  MoSold         2919 non-null   int64
#  76  YrSold         2919 non-null   int64
#  77  SaleType       2918 non-null   object
#  78  SaleCondition  2919 non-null   object
#  79  SalePrice      2919 non-null   int64
# dtypes: float64(11), int64(26), object(43)
# memory usage: 1.8+ MB

# %% [markdown]
# ## Feature : Garage

# %%
# Checking houses with garage area 0
df[df['GarageArea'] == 0]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 40            90       RL         65.0     6040   Pave   NaN      Reg
# 49           190       RM         33.0     4456   Pave   NaN      Reg
# 79            90       RL         72.0    10778   Pave   NaN      Reg
# 89            50  C (all)        105.0     8470   Pave   NaN      IR1
# 90            20       RL         60.0     8070   Pave   NaN      Reg
# ...          ...      ...          ...      ...    ...   ...      ...
# 2894          50  C (all)         60.0     8520   Grvl   NaN      Reg
# 2910         180       RM         21.0     1470   Pave   NaN      Reg
# 2914         160       RM         21.0     1526   Pave   NaN      Reg
# 2915         160       RM         21.0     1936   Pave   NaN      Reg
# 2918          85       RL         62.0    10441   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# 40           Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 49           Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 79           Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 89           Lvl    AllPub    Corner  ...        0    NaN  MnPrv         NaN
# 90           Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# ...          ...       ...       ...  ...      ...    ...    ...         ...
# 2894         Bnk    AllPub    Inside  ...        0    NaN    NaN         NaN
# 2910         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 2914         Lvl    AllPub    Inside  ...        0    NaN  GdPrv         NaN
# 2915         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 2918         Lvl    AllPub    Inside  ...        0    NaN  MnPrv        Shed
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 40         0      6    2008        WD        AdjLand      82000
# 49         0      6    2009       New        Partial     113000
# 79         0      4    2010        WD         Normal     136500
# 89         0     10    2009     ConLD        Abnorml      85000
# 90         0      8    2007        WD         Normal     123600
# ...      ...    ...     ...       ...            ...        ...
# 2894       0      4    2006        WD         Normal         -1
# 2910       0      4    2006        WD         Normal         -1
# 2914       0      6    2006        WD         Normal         -1
# 2915       0      6    2006        WD         Normal         -1
# 2918     700      7    2006        WD         Normal         -1
#
# [157 rows x 80 columns]

# %%
# Checking houses with garage area 0
df.loc[df['GarageArea'] == 0, "GarageType" :]
# Out:
#      GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# Id
# 40          NaN          NaN          NaN         0.0         0.0        NaN
# 49          NaN          NaN          NaN         0.0         0.0        NaN
# 79          NaN          NaN          NaN         0.0         0.0        NaN
# 89          NaN          NaN          NaN         0.0         0.0        NaN
# 90          NaN          NaN          NaN         0.0         0.0        NaN
# ...         ...          ...          ...         ...         ...        ...
# 2894        NaN          NaN          NaN         0.0         0.0        NaN
# 2910        NaN          NaN          NaN         0.0         0.0        NaN
# 2914        NaN          NaN          NaN         0.0         0.0        NaN
# 2915        NaN          NaN          NaN         0.0         0.0        NaN
# 2918        NaN          NaN          NaN         0.0         0.0        NaN
#
#      GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  ...  PoolArea  PoolQC  \
# Id                                                   ...
# 40          NaN          N           0            0  ...         0     NaN
# 49          NaN          N           0            0  ...         0     NaN
# 79          NaN          Y           0            0  ...         0     NaN
# 89          NaN          N           0            0  ...         0     NaN
# 90          NaN          Y           0            0  ...         0     NaN
# ...         ...        ...         ...          ...  ...       ...     ...
# 2894        NaN          N           0            0  ...         0     NaN
# 2910        NaN          Y           0            0  ...         0     NaN
# 2914        NaN          Y           0           34  ...         0     NaN
# 2915        NaN          Y           0            0  ...         0     NaN
# 2918        NaN          Y          80           32  ...         0     NaN
#
#       Fence  MiscFeature MiscVal MoSold YrSold  SaleType  SaleCondition  \
# Id
# 40      NaN          NaN       0      6   2008        WD        AdjLand
# 49      NaN          NaN       0      6   2009       New        Partial
# 79      NaN          NaN       0      4   2010        WD         Normal
# 89    MnPrv          NaN       0     10   2009     ConLD        Abnorml
# 90      NaN          NaN       0      8   2007        WD         Normal
# ...     ...          ...     ...    ...    ...       ...            ...
# 2894    NaN          NaN       0      4   2006        WD         Normal
# 2910    NaN          NaN       0      4   2006        WD         Normal
# 2914  GdPrv          NaN       0      6   2006        WD         Normal
# 2915    NaN          NaN       0      6   2006        WD         Normal
# 2918  MnPrv         Shed     700      7   2006        WD         Normal
#
#       SalePrice
# Id
# 40        82000
# 49       113000
# 79       136500
# 89        85000
# 90       123600
# ...         ...
# 2894         -1
# 2910         -1
# 2914         -1
# 2915         -1
# 2918         -1
#
# [157 rows x 23 columns]

# %% [markdown]
# If a house has a garage area 0, I will sent all other features related to garage as NA (no garage).

# %%
# Checking distrbution of entries in garage features for houses with garage area 0
garage_features = ['GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageQual', 'GarageCond']

for feature in garage_features:
    print("Uniques in :" , df.loc[(df['GarageArea'] == 0) , feature].unique(), "\n")
# Out:
# Uniques in : [nan]
#
# Uniques in : [nan]
#
# Uniques in : [nan]
#
# Uniques in : [nan]
#
# Uniques in : [nan]

# %%
# Checking distrubutions before update

for feature in garage_features:
    print(df[feature].value_counts(), "\n")
# Out:
# Attchd     1723
# Detchd      779
# BuiltIn     186
# Basment      36
# 2Types       23
# CarPort      15
# Name: GarageType, dtype: int64
#
# 2005.0    142
# 2006.0    115
# 2007.0    115
# 2004.0     99
# 2003.0     92
#          ...
# 1933.0      1
# 1943.0      1
# 1906.0      1
# 1919.0      1
# 1896.0      1
# Name: GarageYrBlt, Length: 103, dtype: int64
#
# Unf    1230
# RFn     811
# Fin     719
# Name: GarageFinish, dtype: int64
#
# TA    2604
# Fa     124
# Gd      24
# Po       5
# Ex       3
# Name: GarageQual, dtype: int64
#
# TA    2654
# Fa      74
# Gd      15
# Po      14
# Ex       3
# Name: GarageCond, dtype: int64

# %%
# Setting all garage related features of houses with garage area 0 to NA except for year built
# I will set year built feature to 0 since it was never built

for feature in garage_features:
    if feature != 'GarageYrBlt':
        df.loc[(df['GarageArea'] == 0) , feature] = 'NA'
    else :
        df.loc[(df['GarageArea'] == 0) , feature] = 0

# %%
# Checking if update done correctly
for feature in garage_features:
    print("Uniques in :" , df.loc[(df['GarageArea'] == 0) , feature].unique(), "\n")
    
for feature in garage_features:
    print(df[feature].value_counts(), "\n")
# Out:
# Uniques in : ['NA']
#
# Uniques in : [0.]
#
# Uniques in : ['NA']
#
# Uniques in : ['NA']
#
# Uniques in : ['NA']
#
# Attchd     1723
# Detchd      779
# BuiltIn     186
# NA          157
# Basment      36
# 2Types       23
# CarPort      15
# Name: GarageType, dtype: int64
#
# 0.0       157
# 2005.0    142
# 2006.0    115
# 2007.0    115
# 2004.0     99
#          ...
# 1933.0      1
# 1919.0      1
# 1896.0      1
# 2207.0      1
# 1906.0      1
# Name: GarageYrBlt, Length: 104, dtype: int64
#
# Unf    1230
# RFn     811
# Fin     719
# NA      157
# Name: GarageFinish, dtype: int64
#
# TA    2604
# NA     157
# Fa     124
# Gd      24
# Po       5
# Ex       3
# Name: GarageQual, dtype: int64
#
# TA    2654
# NA     157
# Fa      74
# Gd      15
# Po      14
# Ex       3
# Name: GarageCond, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 1 to 2919
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     2919 non-null   int64
#  1   MSZoning       2919 non-null   object
#  2   LotFrontage    2919 non-null   float64
#  3   LotArea        2919 non-null   int64
#  4   Street         2919 non-null   object
#  5   Alley          198 non-null    object
#  6   LotShape       2919 non-null   object
#  7   LandContour    2919 non-null   object
#  8   Utilities      2919 non-null   object
#  9   LotConfig      2919 non-null   object
#  10  LandSlope      2919 non-null   object
#  11  Neighborhood   2919 non-null   object
#  12  Condition1     2919 non-null   object
#  13  Condition2     2919 non-null   object
#  14  BldgType       2919 non-null   object
#  15  HouseStyle     2919 non-null   object
#  16  OverallQual    2919 non-null   int64
#  17  OverallCond    2919 non-null   int64
#  18  YearBuilt      2919 non-null   int64
#  19  YearRemodAdd   2919 non-null   int64
#  20  RoofStyle      2919 non-null   object
#  21  RoofMatl       2919 non-null   object
#  22  Exterior1st    2919 non-null   object
#  23  Exterior2nd    2919 non-null   object
#  24  MasVnrType     2919 non-null   object
#  25  MasVnrArea     2919 non-null   float64
#  26  ExterQual      2919 non-null   object
#  27  ExterCond      2919 non-null   object
#  28  Foundation     2919 non-null   object
#  29  BsmtQual       2919 non-null   object
#  30  BsmtCond       2919 non-null   object
#  31  BsmtExposure   2919 non-null   object
#  32  BsmtFinType1   2919 non-null   object
#  33  BsmtFinSF1     2919 non-null   float64
#  34  BsmtFinType2   2919 non-null   object
#  35  BsmtFinSF2     2919 non-null   float64
#  36  BsmtUnfSF      2919 non-null   float64
#  37  TotalBsmtSF    2919 non-null   float64
#  38  Heating        2919 non-null   object
#  39  HeatingQC      2919 non-null   object
#  40  CentralAir     2919 non-null   object
#  41  Electrical     2919 non-null   object
#  42  1stFlrSF       2919 non-null   int64
#  43  2ndFlrSF       2919 non-null   int64
#  44  LowQualFinSF   2919 non-null   int64
#  45  GrLivArea      2919 non-null   int64
#  46  BsmtFullBath   2919 non-null   float64
#  47  BsmtHalfBath   2919 non-null   float64
#  48  FullBath       2919 non-null   int64
#  49  HalfBath       2919 non-null   int64
#  50  BedroomAbvGr   2919 non-null   int64
#  51  KitchenAbvGr   2919 non-null   int64
#  52  KitchenQual    2919 non-null   object
#  53  TotRmsAbvGrd   2919 non-null   int64
#  54  Functional     2919 non-null   object
#  55  Fireplaces     2919 non-null   int64
#  56  FireplaceQu    2919 non-null   object
#  57  GarageType     2919 non-null   object
#  58  GarageYrBlt    2917 non-null   float64
#  59  GarageFinish   2917 non-null   object
#  60  GarageCars     2918 non-null   float64
#  61  GarageArea     2918 non-null   float64
#  62  GarageQual     2917 non-null   object
#  63  GarageCond     2917 non-null   object
#  64  PavedDrive     2919 non-null   object
#  65  WoodDeckSF     2919 non-null   int64
#  66  OpenPorchSF    2919 non-null   int64
#  67  EnclosedPorch  2919 non-null   int64
#  68  3SsnPorch      2919 non-null   int64
#  69  ScreenPorch    2919 non-null   int64
#  70  PoolArea       2919 non-null   int64
#  71  PoolQC         10 non-null     object
#  72  Fence          571 non-null    object
#  73  MiscFeature    105 non-null    object
#  74  MiscVal        2919 non-null   int64
#  75  MoSold         2919 non-null   int64
#  76  YrSold         2919 non-null   int64
#  77  SaleType       2918 non-null   object
#  78  SaleCondition  2919 non-null   object
#  79  SalePrice      2919 non-null   int64
# dtypes: float64(11), int64(26), object(43)
# memory usage: 1.8+ MB

# %%
# Checking out remaining houses
df.loc[pd.isnull(df['GarageYrBlt']), 'GarageType':]
# Out:
#      GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# Id
# 2127     Detchd          NaN          NaN         1.0       360.0        NaN
# 2577     Detchd          NaN          NaN         NaN         NaN        NaN
#
#      GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  ...  PoolArea  PoolQC  \
# Id                                                   ...
# 2127        NaN          Y          64            0  ...         0     NaN
# 2577        NaN          Y         174            0  ...         0     NaN
#
#       Fence  MiscFeature MiscVal MoSold YrSold  SaleType  SaleCondition  \
# Id
# 2127  MnPrv         Shed    1000      9   2008        WD         Normal
# 2577  MnPrv          NaN       0      3   2007        WD         Alloca
#
#       SalePrice
# Id
# 2127         -1
# 2577         -1
#
# [2 rows x 23 columns]

# %%
# Checking out distribution of years in which detached garages were built
df.loc[df['GarageType'] == 'Detchd', 'GarageYrBlt'].value_counts(sort = True)
# Out:
# 1950.0    29
# 1920.0    27
# 1930.0    24
# 1939.0    18
# 1940.0    18
#           ..
# 1984.0     1
# 1929.0     1
# 1908.0     1
# 1917.0     1
# 1943.0     1
# Name: GarageYrBlt, Length: 101, dtype: int64

# %%
# Checking the frequency of years in which detached garages were built
plt.hist(df.loc[pd.notnull(df['GarageYrBlt']) & (df['GarageType'] == 'Detchd'), 'GarageYrBlt'], color = 'c', bins = 30);

# %% [markdown]
# Since it seems to be evenly distibuted I will set it to the median value.

# %%
median_year = df.loc[pd.notnull(df['GarageYrBlt']), 'GarageYrBlt'].median()

# %%
# Setting value to median
df.loc[pd.isnull(df['GarageYrBlt']), 'GarageYrBlt'] = median_year

# %%
# Checking if update done correctly
df.loc[pd.isnull(df['GarageYrBlt']), 'GarageType':]
# Out:
# Empty DataFrame
# Columns: [GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []
#
# [0 rows x 23 columns]

# %%
# Houses with missing GarageFinishes
df.loc[pd.isnull(df['GarageFinish']), 'GarageType':]
# Out:
#      GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# Id
# 2127     Detchd       1977.0          NaN         1.0       360.0        NaN
# 2577     Detchd       1977.0          NaN         NaN         NaN        NaN
#
#      GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  ...  PoolArea  PoolQC  \
# Id                                                   ...
# 2127        NaN          Y          64            0  ...         0     NaN
# 2577        NaN          Y         174            0  ...         0     NaN
#
#       Fence  MiscFeature MiscVal MoSold YrSold  SaleType  SaleCondition  \
# Id
# 2127  MnPrv         Shed    1000      9   2008        WD         Normal
# 2577  MnPrv          NaN       0      3   2007        WD         Alloca
#
#       SalePrice
# Id
# 2127         -1
# 2577         -1
#
# [2 rows x 23 columns]

# %%
df.loc[df['GarageType'] == 'Detchd', 'GarageFinish'].value_counts()
# Out:
# Unf    719
# RFn     34
# Fin     24
# Name: GarageFinish, dtype: int64

# %%
# Setting finishing to Unfinished as that is the most common entry
df.loc[pd.isnull(df['GarageFinish']), 'GarageFinish'] = 'Unf'

# %%
# Checking if the update was done correctly
df.loc[df['GarageType'] == 'Detchd', 'GarageFinish'].value_counts()
# Out:
# Unf    721
# RFn     34
# Fin     24
# Name: GarageFinish, dtype: int64

# %%
# Houses with missing GarageFinishes
df.loc[pd.isnull(df['GarageCars']), 'GarageType' : ]
# Out:
#      GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# Id
# 2577     Detchd       1977.0          Unf         NaN         NaN        NaN
#
#      GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  ...  PoolArea  PoolQC  \
# Id                                                   ...
# 2577        NaN          Y         174            0  ...         0     NaN
#
#       Fence  MiscFeature MiscVal MoSold YrSold  SaleType  SaleCondition  \
# Id
# 2577  MnPrv          NaN       0      3   2007        WD         Alloca
#
#       SalePrice
# Id
# 2577         -1
#
# [1 rows x 23 columns]

# %%
# Distribution of GarageCars entries
df['GarageCars'].value_counts()
# Out:
# 2.0    1594
# 1.0     776
# 3.0     374
# 0.0     157
# 4.0      16
# 5.0       1
# Name: GarageCars, dtype: int64

# %%
# Distribution of GarageCars entries among detached garages
df.loc[df['GarageType'] == 'Detchd','GarageCars'].value_counts()
# Out:
# 2.0    384
# 1.0    376
# 3.0     13
# 4.0      4
# 5.0      1
# Name: GarageCars, dtype: int64

# %%
# Distribution of GarageCars entries among detached garages built before 1985
df.loc[(df['GarageType'] == 'Detchd') & (df['GarageYrBlt'] < 1985),'GarageCars'].value_counts()
# Out:
# 1.0    346
# 2.0    235
# 3.0      8
# 4.0      4
# 5.0      1
# Name: GarageCars, dtype: int64

# %% [markdown]
# From the above analysis car capacity of 1 is the best entry, taking into consideration the type of garage and the year in which it was built.

# %%
# Setting car capicity to 1
df.loc[pd.isnull(df['GarageCars']), 'GarageCars'] = 1

# %%
# Checking if update done as expected
df['GarageCars'].value_counts()
# Out:
# 2.0    1594
# 1.0     777
# 3.0     374
# 0.0     157
# 4.0      16
# 5.0       1
# Name: GarageCars, dtype: int64

# %%
# Houses with missing Garage Area values
df.loc[pd.isnull(df['GarageArea']), 'GarageType' : ]
# Out:
#      GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# Id
# 2577     Detchd       1977.0          Unf         1.0         NaN        NaN
#
#      GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  ...  PoolArea  PoolQC  \
# Id                                                   ...
# 2577        NaN          Y         174            0  ...         0     NaN
#
#       Fence  MiscFeature MiscVal MoSold YrSold  SaleType  SaleCondition  \
# Id
# 2577  MnPrv          NaN       0      3   2007        WD         Alloca
#
#       SalePrice
# Id
# 2577         -1
#
# [1 rows x 23 columns]

# %% [markdown]
# I will set this value to the median garage area value of detached garages with capacity 1 built before 1985.

# %%
median_garage_size = df.loc[(df['GarageType'] == 'Detchd') & (df['GarageYrBlt'] < 1985) & (df['GarageCars'] == 1), 'GarageArea'].median()
print(f"Median garage size : {median_garage_size}")
# Out:
# Median garage size : 264.0

# %%
# Setting missing value to this median value
df.loc[pd.isnull(df['GarageArea']), 'GarageArea'] = median_garage_size

# %%
# Houses with missing Garage Qual values
df.loc[pd.isnull(df['GarageQual']), 'GarageType' :]
# Out:
#      GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# Id
# 2127     Detchd       1977.0          Unf         1.0       360.0        NaN
# 2577     Detchd       1977.0          Unf         1.0       264.0        NaN
#
#      GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  ...  PoolArea  PoolQC  \
# Id                                                   ...
# 2127        NaN          Y          64            0  ...         0     NaN
# 2577        NaN          Y         174            0  ...         0     NaN
#
#       Fence  MiscFeature MiscVal MoSold YrSold  SaleType  SaleCondition  \
# Id
# 2127  MnPrv         Shed    1000      9   2008        WD         Normal
# 2577  MnPrv          NaN       0      3   2007        WD         Alloca
#
#       SalePrice
# Id
# 2127         -1
# 2577         -1
#
# [2 rows x 23 columns]

# %%
# Checking distribution of quality of garages of houses having garage of similar type
df.loc[(df['GarageType'] == 'Detchd') & (df['GarageYrBlt'] < 1985) & (df['GarageCars'] == 1), 'GarageQual'].value_counts()
# Out:
# TA    270
# Fa     69
# Po      5
# Ex      1
# Name: GarageQual, dtype: int64

# %%
# Setting quality to 'TA' as suggested by the distribution
df.loc[pd.isnull(df['GarageQual']), 'GarageQual'] = 'TA'

# %%
# Checking distribution of condition of garages of houses having garage of similar type
df.loc[(df['GarageType'] == 'Detchd') & (df['GarageYrBlt'] < 1985) & (df['GarageCars'] == 1), 'GarageCond'].value_counts()
# Out:
# TA    291
# Fa     44
# Po      9
# Ex      1
# Name: GarageCond, dtype: int64

# %%
# Setting Condition to 'TA' as suggested by the distribution
df.loc[pd.isnull(df['GarageCond']), 'GarageCond'] = 'TA|'

# %%
# All garage features are now complete
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 1 to 2919
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     2919 non-null   int64
#  1   MSZoning       2919 non-null   object
#  2   LotFrontage    2919 non-null   float64
#  3   LotArea        2919 non-null   int64
#  4   Street         2919 non-null   object
#  5   Alley          198 non-null    object
#  6   LotShape       2919 non-null   object
#  7   LandContour    2919 non-null   object
#  8   Utilities      2919 non-null   object
#  9   LotConfig      2919 non-null   object
#  10  LandSlope      2919 non-null   object
#  11  Neighborhood   2919 non-null   object
#  12  Condition1     2919 non-null   object
#  13  Condition2     2919 non-null   object
#  14  BldgType       2919 non-null   object
#  15  HouseStyle     2919 non-null   object
#  16  OverallQual    2919 non-null   int64
#  17  OverallCond    2919 non-null   int64
#  18  YearBuilt      2919 non-null   int64
#  19  YearRemodAdd   2919 non-null   int64
#  20  RoofStyle      2919 non-null   object
#  21  RoofMatl       2919 non-null   object
#  22  Exterior1st    2919 non-null   object
#  23  Exterior2nd    2919 non-null   object
#  24  MasVnrType     2919 non-null   object
#  25  MasVnrArea     2919 non-null   float64
#  26  ExterQual      2919 non-null   object
#  27  ExterCond      2919 non-null   object
#  28  Foundation     2919 non-null   object
#  29  BsmtQual       2919 non-null   object
#  30  BsmtCond       2919 non-null   object
#  31  BsmtExposure   2919 non-null   object
#  32  BsmtFinType1   2919 non-null   object
#  33  BsmtFinSF1     2919 non-null   float64
#  34  BsmtFinType2   2919 non-null   object
#  35  BsmtFinSF2     2919 non-null   float64
#  36  BsmtUnfSF      2919 non-null   float64
#  37  TotalBsmtSF    2919 non-null   float64
#  38  Heating        2919 non-null   object
#  39  HeatingQC      2919 non-null   object
#  40  CentralAir     2919 non-null   object
#  41  Electrical     2919 non-null   object
#  42  1stFlrSF       2919 non-null   int64
#  43  2ndFlrSF       2919 non-null   int64
#  44  LowQualFinSF   2919 non-null   int64
#  45  GrLivArea      2919 non-null   int64
#  46  BsmtFullBath   2919 non-null   float64
#  47  BsmtHalfBath   2919 non-null   float64
#  48  FullBath       2919 non-null   int64
#  49  HalfBath       2919 non-null   int64
#  50  BedroomAbvGr   2919 non-null   int64
#  51  KitchenAbvGr   2919 non-null   int64
#  52  KitchenQual    2919 non-null   object
#  53  TotRmsAbvGrd   2919 non-null   int64
#  54  Functional     2919 non-null   object
#  55  Fireplaces     2919 non-null   int64
#  56  FireplaceQu    2919 non-null   object
#  57  GarageType     2919 non-null   object
#  58  GarageYrBlt    2919 non-null   float64
#  59  GarageFinish   2919 non-null   object
#  60  GarageCars     2919 non-null   float64
#  61  GarageArea     2919 non-null   float64
#  62  GarageQual     2919 non-null   object
#  63  GarageCond     2919 non-null   object
#  64  PavedDrive     2919 non-null   object
#  65  WoodDeckSF     2919 non-null   int64
#  66  OpenPorchSF    2919 non-null   int64
#  67  EnclosedPorch  2919 non-null   int64
#  68  3SsnPorch      2919 non-null   int64
#  69  ScreenPorch    2919 non-null   int64
#  70  PoolArea       2919 non-null   int64
#  71  PoolQC         10 non-null     object
#  72  Fence          571 non-null    object
#  73  MiscFeature    105 non-null    object
#  74  MiscVal        2919 non-null   int64
#  75  MoSold         2919 non-null   int64
#  76  YrSold         2919 non-null   int64
#  77  SaleType       2918 non-null   object
#  78  SaleCondition  2919 non-null   object
#  79  SalePrice      2919 non-null   int64
# dtypes: float64(11), int64(26), object(43)
# memory usage: 1.8+ MB

# %% [markdown]
# ## Feature : Pool

# %%
# Housing with missing values in this feature
df.loc[pd.isnull(df['PoolQC']), 'PoolArea':]
# Out:
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# Id
# 1            0    NaN    NaN         NaN        0       2    2008       WD
# 2            0    NaN    NaN         NaN        0       5    2007       WD
# 3            0    NaN    NaN         NaN        0       9    2008       WD
# 4            0    NaN    NaN         NaN        0       2    2006       WD
# 5            0    NaN    NaN         NaN        0      12    2008       WD
# ...        ...    ...    ...         ...      ...     ...     ...      ...
# 2915         0    NaN    NaN         NaN        0       6    2006       WD
# 2916         0    NaN    NaN         NaN        0       4    2006       WD
# 2917         0    NaN    NaN         NaN        0       9    2006       WD
# 2918         0    NaN  MnPrv        Shed      700       7    2006       WD
# 2919         0    NaN    NaN         NaN        0      11    2006       WD
#
#      SaleCondition  SalePrice
# Id
# 1           Normal     208500
# 2           Normal     181500
# 3           Normal     223500
# 4          Abnorml     140000
# 5           Normal     250000
# ...            ...        ...
# 2915        Normal         -1
# 2916       Abnorml         -1
# 2917       Abnorml         -1
# 2918        Normal         -1
# 2919        Normal         -1
#
# [2909 rows x 10 columns]

# %% [markdown]
# I will set the pool quality value to NA (No pool) for houses with pool area 0.

# %%
df.loc[(pd.isnull(df['PoolQC'])) & (df['PoolArea'] == 0), 'PoolArea':]
# Out:
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# Id
# 1            0    NaN    NaN         NaN        0       2    2008       WD
# 2            0    NaN    NaN         NaN        0       5    2007       WD
# 3            0    NaN    NaN         NaN        0       9    2008       WD
# 4            0    NaN    NaN         NaN        0       2    2006       WD
# 5            0    NaN    NaN         NaN        0      12    2008       WD
# ...        ...    ...    ...         ...      ...     ...     ...      ...
# 2915         0    NaN    NaN         NaN        0       6    2006       WD
# 2916         0    NaN    NaN         NaN        0       4    2006       WD
# 2917         0    NaN    NaN         NaN        0       9    2006       WD
# 2918         0    NaN  MnPrv        Shed      700       7    2006       WD
# 2919         0    NaN    NaN         NaN        0      11    2006       WD
#
#      SaleCondition  SalePrice
# Id
# 1           Normal     208500
# 2           Normal     181500
# 3           Normal     223500
# 4          Abnorml     140000
# 5           Normal     250000
# ...            ...        ...
# 2915        Normal         -1
# 2916       Abnorml         -1
# 2917       Abnorml         -1
# 2918        Normal         -1
# 2919        Normal         -1
#
# [2906 rows x 10 columns]

# %%
# Setting value to NA
df.loc[(pd.isnull(df['PoolQC'])) & (df['PoolArea'] == 0), 'PoolQC'] = 'NA'

# %%
# Remainnig Houses
df.loc[pd.isnull(df['PoolQC']), 'PoolArea':]
# Out:
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# Id
# 2421       368    NaN  GdPrv         NaN        0       2    2007       WD
# 2504       444    NaN    NaN         NaN        0       4    2007       WD
# 2600       561    NaN  GdPrv         NaN        0       6    2007       WD
#
#      SaleCondition  SalePrice
# Id
# 2421        Normal         -1
# 2504        Normal         -1
# 2600        Normal         -1

# %%
#All houses having pools
df.loc[df['PoolArea'] != 0, 'PoolArea':]
# Out:
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# Id
# 198        512     Ex  GdPrv         NaN        0       3    2006       WD
# 811        648     Fa  GdPrv         NaN        0       1    2006       WD
# 1171       576     Gd  GdPrv         NaN        0       7    2008       WD
# 1183       555     Ex  MnPrv         NaN        0       7    2007       WD
# 1299       480     Gd    NaN         NaN        0       1    2008      New
# 1387       519     Fa  MnPrv        TenC     2000       7    2006       WD
# 1424       738     Gd  GdPrv         NaN        0       8    2006       WD
# 1975       144     Ex    NaN         NaN        0       2    2008       WD
# 2421       368    NaN  GdPrv         NaN        0       2    2007       WD
# 2504       444    NaN    NaN         NaN        0       4    2007       WD
# 2574       228     Ex    NaN         NaN        0       8    2007       WD
# 2600       561    NaN  GdPrv         NaN        0       6    2007       WD
# 2711       800     Gd  GdPrv         NaN        0       1    2006       WD
#
#      SaleCondition  SalePrice
# Id
# 198        Abnorml     235000
# 811         Normal     181000
# 1171        Normal     171000
# 1183       Abnorml     745000
# 1299       Partial     160000
# 1387        Normal     250000
# 1424        Alloca     274970
# 1975        Normal         -1
# 2421        Normal         -1
# 2504        Normal         -1
# 2574        Normal         -1
# 2600        Normal         -1
# 2711        Normal         -1

# %%
df.loc[df['PoolArea'] != 0, 'PoolQC'].value_counts()
# Out:
# Ex    4
# Gd    4
# Fa    2
# Name: PoolQC, dtype: int64

# %% [markdown]
# I will set it by default to good.

# %%
# Setting default pool quality to be good
df.loc[pd.isnull(df['PoolQC']), 'PoolQC'] = 'Gd'

# %%
# Pool feature is now complete
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 1 to 2919
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     2919 non-null   int64
#  1   MSZoning       2919 non-null   object
#  2   LotFrontage    2919 non-null   float64
#  3   LotArea        2919 non-null   int64
#  4   Street         2919 non-null   object
#  5   Alley          198 non-null    object
#  6   LotShape       2919 non-null   object
#  7   LandContour    2919 non-null   object
#  8   Utilities      2919 non-null   object
#  9   LotConfig      2919 non-null   object
#  10  LandSlope      2919 non-null   object
#  11  Neighborhood   2919 non-null   object
#  12  Condition1     2919 non-null   object
#  13  Condition2     2919 non-null   object
#  14  BldgType       2919 non-null   object
#  15  HouseStyle     2919 non-null   object
#  16  OverallQual    2919 non-null   int64
#  17  OverallCond    2919 non-null   int64
#  18  YearBuilt      2919 non-null   int64
#  19  YearRemodAdd   2919 non-null   int64
#  20  RoofStyle      2919 non-null   object
#  21  RoofMatl       2919 non-null   object
#  22  Exterior1st    2919 non-null   object
#  23  Exterior2nd    2919 non-null   object
#  24  MasVnrType     2919 non-null   object
#  25  MasVnrArea     2919 non-null   float64
#  26  ExterQual      2919 non-null   object
#  27  ExterCond      2919 non-null   object
#  28  Foundation     2919 non-null   object
#  29  BsmtQual       2919 non-null   object
#  30  BsmtCond       2919 non-null   object
#  31  BsmtExposure   2919 non-null   object
#  32  BsmtFinType1   2919 non-null   object
#  33  BsmtFinSF1     2919 non-null   float64
#  34  BsmtFinType2   2919 non-null   object
#  35  BsmtFinSF2     2919 non-null   float64
#  36  BsmtUnfSF      2919 non-null   float64
#  37  TotalBsmtSF    2919 non-null   float64
#  38  Heating        2919 non-null   object
#  39  HeatingQC      2919 non-null   object
#  40  CentralAir     2919 non-null   object
#  41  Electrical     2919 non-null   object
#  42  1stFlrSF       2919 non-null   int64
#  43  2ndFlrSF       2919 non-null   int64
#  44  LowQualFinSF   2919 non-null   int64
#  45  GrLivArea      2919 non-null   int64
#  46  BsmtFullBath   2919 non-null   float64
#  47  BsmtHalfBath   2919 non-null   float64
#  48  FullBath       2919 non-null   int64
#  49  HalfBath       2919 non-null   int64
#  50  BedroomAbvGr   2919 non-null   int64
#  51  KitchenAbvGr   2919 non-null   int64
#  52  KitchenQual    2919 non-null   object
#  53  TotRmsAbvGrd   2919 non-null   int64
#  54  Functional     2919 non-null   object
#  55  Fireplaces     2919 non-null   int64
#  56  FireplaceQu    2919 non-null   object
#  57  GarageType     2919 non-null   object
#  58  GarageYrBlt    2919 non-null   float64
#  59  GarageFinish   2919 non-null   object
#  60  GarageCars     2919 non-null   float64
#  61  GarageArea     2919 non-null   float64
#  62  GarageQual     2919 non-null   object
#  63  GarageCond     2919 non-null   object
#  64  PavedDrive     2919 non-null   object
#  65  WoodDeckSF     2919 non-null   int64
#  66  OpenPorchSF    2919 non-null   int64
#  67  EnclosedPorch  2919 non-null   int64
#  68  3SsnPorch      2919 non-null   int64
#  69  ScreenPorch    2919 non-null   int64
#  70  PoolArea       2919 non-null   int64
#  71  PoolQC         2919 non-null   object
#  72  Fence          571 non-null    object
#  73  MiscFeature    105 non-null    object
#  74  MiscVal        2919 non-null   int64
#  75  MoSold         2919 non-null   int64
#  76  YrSold         2919 non-null   int64
#  77  SaleType       2918 non-null   object
#  78  SaleCondition  2919 non-null   object
#  79  SalePrice      2919 non-null   int64
# dtypes: float64(11), int64(26), object(43)
# memory usage: 1.8+ MB

# %% [markdown]
# ## Feature : Fence

# %%
# Houses with missing values in fence feature
df.loc[pd.isnull(df['Fence']), 'PoolArea':]
# Out:
#       PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# Id
# 1            0     NA   NaN         NaN        0       2    2008       WD
# 2            0     NA   NaN         NaN        0       5    2007       WD
# 3            0     NA   NaN         NaN        0       9    2008       WD
# 4            0     NA   NaN         NaN        0       2    2006       WD
# 5            0     NA   NaN         NaN        0      12    2008       WD
# ...        ...    ...   ...         ...      ...     ...     ...      ...
# 2913         0     NA   NaN         NaN        0      12    2006       WD
# 2915         0     NA   NaN         NaN        0       6    2006       WD
# 2916         0     NA   NaN         NaN        0       4    2006       WD
# 2917         0     NA   NaN         NaN        0       9    2006       WD
# 2919         0     NA   NaN         NaN        0      11    2006       WD
#
#      SaleCondition  SalePrice
# Id
# 1           Normal     208500
# 2           Normal     181500
# 3           Normal     223500
# 4          Abnorml     140000
# 5           Normal     250000
# ...            ...        ...
# 2913       Abnorml         -1
# 2915        Normal         -1
# 2916       Abnorml         -1
# 2917       Abnorml         -1
# 2919        Normal         -1
#
# [2348 rows x 10 columns]

# %%
# Distribution of entries in fence feature
df['Fence'].value_counts()
# Out:
# MnPrv    329
# GdPrv    118
# GdWo     112
# MnWw      12
# Name: Fence, dtype: int64

# %% [markdown]
# This data set represents housing prices of houses from the state of Iowa in the United States of America. Most houses in th US do not have any kind of fencing (from my experience there). Hence I will set the default value in this feature to NA (No fence).

# %%
# Setting default value to NA
df.loc[pd.isnull(df['Fence']), 'Fence'] = 'NA'

# %%
# Checking if update done as expected
df['Fence'].value_counts()
# Out:
# NA       2348
# MnPrv     329
# GdPrv     118
# GdWo      112
# MnWw       12
# Name: Fence, dtype: int64

# %%
# Fence feature is now complete
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 1 to 2919
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     2919 non-null   int64
#  1   MSZoning       2919 non-null   object
#  2   LotFrontage    2919 non-null   float64
#  3   LotArea        2919 non-null   int64
#  4   Street         2919 non-null   object
#  5   Alley          198 non-null    object
#  6   LotShape       2919 non-null   object
#  7   LandContour    2919 non-null   object
#  8   Utilities      2919 non-null   object
#  9   LotConfig      2919 non-null   object
#  10  LandSlope      2919 non-null   object
#  11  Neighborhood   2919 non-null   object
#  12  Condition1     2919 non-null   object
#  13  Condition2     2919 non-null   object
#  14  BldgType       2919 non-null   object
#  15  HouseStyle     2919 non-null   object
#  16  OverallQual    2919 non-null   int64
#  17  OverallCond    2919 non-null   int64
#  18  YearBuilt      2919 non-null   int64
#  19  YearRemodAdd   2919 non-null   int64
#  20  RoofStyle      2919 non-null   object
#  21  RoofMatl       2919 non-null   object
#  22  Exterior1st    2919 non-null   object
#  23  Exterior2nd    2919 non-null   object
#  24  MasVnrType     2919 non-null   object
#  25  MasVnrArea     2919 non-null   float64
#  26  ExterQual      2919 non-null   object
#  27  ExterCond      2919 non-null   object
#  28  Foundation     2919 non-null   object
#  29  BsmtQual       2919 non-null   object
#  30  BsmtCond       2919 non-null   object
#  31  BsmtExposure   2919 non-null   object
#  32  BsmtFinType1   2919 non-null   object
#  33  BsmtFinSF1     2919 non-null   float64
#  34  BsmtFinType2   2919 non-null   object
#  35  BsmtFinSF2     2919 non-null   float64
#  36  BsmtUnfSF      2919 non-null   float64
#  37  TotalBsmtSF    2919 non-null   float64
#  38  Heating        2919 non-null   object
#  39  HeatingQC      2919 non-null   object
#  40  CentralAir     2919 non-null   object
#  41  Electrical     2919 non-null   object
#  42  1stFlrSF       2919 non-null   int64
#  43  2ndFlrSF       2919 non-null   int64
#  44  LowQualFinSF   2919 non-null   int64
#  45  GrLivArea      2919 non-null   int64
#  46  BsmtFullBath   2919 non-null   float64
#  47  BsmtHalfBath   2919 non-null   float64
#  48  FullBath       2919 non-null   int64
#  49  HalfBath       2919 non-null   int64
#  50  BedroomAbvGr   2919 non-null   int64
#  51  KitchenAbvGr   2919 non-null   int64
#  52  KitchenQual    2919 non-null   object
#  53  TotRmsAbvGrd   2919 non-null   int64
#  54  Functional     2919 non-null   object
#  55  Fireplaces     2919 non-null   int64
#  56  FireplaceQu    2919 non-null   object
#  57  GarageType     2919 non-null   object
#  58  GarageYrBlt    2919 non-null   float64
#  59  GarageFinish   2919 non-null   object
#  60  GarageCars     2919 non-null   float64
#  61  GarageArea     2919 non-null   float64
#  62  GarageQual     2919 non-null   object
#  63  GarageCond     2919 non-null   object
#  64  PavedDrive     2919 non-null   object
#  65  WoodDeckSF     2919 non-null   int64
#  66  OpenPorchSF    2919 non-null   int64
#  67  EnclosedPorch  2919 non-null   int64
#  68  3SsnPorch      2919 non-null   int64
#  69  ScreenPorch    2919 non-null   int64
#  70  PoolArea       2919 non-null   int64
#  71  PoolQC         2919 non-null   object
#  72  Fence          2919 non-null   object
#  73  MiscFeature    105 non-null    object
#  74  MiscVal        2919 non-null   int64
#  75  MoSold         2919 non-null   int64
#  76  YrSold         2919 non-null   int64
#  77  SaleType       2918 non-null   object
#  78  SaleCondition  2919 non-null   object
#  79  SalePrice      2919 non-null   int64
# dtypes: float64(11), int64(26), object(43)
# memory usage: 1.8+ MB

# %% [markdown]
# ## Feature : Miscellaneous features

# %%
# Houses with missing values in this feature
df.loc[pd.isnull(df['MiscFeature'])]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 2914         160       RM         21.0     1526   Pave   NaN      Reg
# 2915         160       RM         21.0     1936   Pave   NaN      Reg
# 2916         160       RM         21.0     1894   Pave   NaN      Reg
# 2917          20       RL        160.0    20000   Pave   NaN      Reg
# 2919          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# 1            Lvl    AllPub    Inside  ...        0     NA     NA         NaN
# 2            Lvl    AllPub       FR2  ...        0     NA     NA         NaN
# 3            Lvl    AllPub    Inside  ...        0     NA     NA         NaN
# 4            Lvl    AllPub    Corner  ...        0     NA     NA         NaN
# 5            Lvl    AllPub       FR2  ...        0     NA     NA         NaN
# ...          ...       ...       ...  ...      ...    ...    ...         ...
# 2914         Lvl    AllPub    Inside  ...        0     NA  GdPrv         NaN
# 2915         Lvl    AllPub    Inside  ...        0     NA     NA         NaN
# 2916         Lvl    AllPub    Inside  ...        0     NA     NA         NaN
# 2917         Lvl    AllPub    Inside  ...        0     NA     NA         NaN
# 2919         Lvl    AllPub    Inside  ...        0     NA     NA         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1          0      2    2008        WD         Normal     208500
# 2          0      5    2007        WD         Normal     181500
# 3          0      9    2008        WD         Normal     223500
# 4          0      2    2006        WD        Abnorml     140000
# 5          0     12    2008        WD         Normal     250000
# ...      ...    ...     ...       ...            ...        ...
# 2914       0      6    2006        WD         Normal         -1
# 2915       0      6    2006        WD         Normal         -1
# 2916       0      4    2006        WD        Abnorml         -1
# 2917       0      9    2006        WD        Abnorml         -1
# 2919       0     11    2006        WD         Normal         -1
#
# [2814 rows x 80 columns]

# %%
# Distribution of entries
df['MiscFeature'].value_counts()
# Out:
# Shed    95
# Gar2     5
# Othr     4
# TenC     1
# Name: MiscFeature, dtype: int64

# %%
# Setting default value to NA
df.loc[pd.isnull(df['MiscFeature']), 'MiscFeature'] = 'NA'

# %%
# Checking if update done as expected
df['MiscFeature'].value_counts()
# Out:
# NA      2814
# Shed      95
# Gar2       5
# Othr       4
# TenC       1
# Name: MiscFeature, dtype: int64

# %%
# This feature is now complete
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 1 to 2919
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     2919 non-null   int64
#  1   MSZoning       2919 non-null   object
#  2   LotFrontage    2919 non-null   float64
#  3   LotArea        2919 non-null   int64
#  4   Street         2919 non-null   object
#  5   Alley          198 non-null    object
#  6   LotShape       2919 non-null   object
#  7   LandContour    2919 non-null   object
#  8   Utilities      2919 non-null   object
#  9   LotConfig      2919 non-null   object
#  10  LandSlope      2919 non-null   object
#  11  Neighborhood   2919 non-null   object
#  12  Condition1     2919 non-null   object
#  13  Condition2     2919 non-null   object
#  14  BldgType       2919 non-null   object
#  15  HouseStyle     2919 non-null   object
#  16  OverallQual    2919 non-null   int64
#  17  OverallCond    2919 non-null   int64
#  18  YearBuilt      2919 non-null   int64
#  19  YearRemodAdd   2919 non-null   int64
#  20  RoofStyle      2919 non-null   object
#  21  RoofMatl       2919 non-null   object
#  22  Exterior1st    2919 non-null   object
#  23  Exterior2nd    2919 non-null   object
#  24  MasVnrType     2919 non-null   object
#  25  MasVnrArea     2919 non-null   float64
#  26  ExterQual      2919 non-null   object
#  27  ExterCond      2919 non-null   object
#  28  Foundation     2919 non-null   object
#  29  BsmtQual       2919 non-null   object
#  30  BsmtCond       2919 non-null   object
#  31  BsmtExposure   2919 non-null   object
#  32  BsmtFinType1   2919 non-null   object
#  33  BsmtFinSF1     2919 non-null   float64
#  34  BsmtFinType2   2919 non-null   object
#  35  BsmtFinSF2     2919 non-null   float64
#  36  BsmtUnfSF      2919 non-null   float64
#  37  TotalBsmtSF    2919 non-null   float64
#  38  Heating        2919 non-null   object
#  39  HeatingQC      2919 non-null   object
#  40  CentralAir     2919 non-null   object
#  41  Electrical     2919 non-null   object
#  42  1stFlrSF       2919 non-null   int64
#  43  2ndFlrSF       2919 non-null   int64
#  44  LowQualFinSF   2919 non-null   int64
#  45  GrLivArea      2919 non-null   int64
#  46  BsmtFullBath   2919 non-null   float64
#  47  BsmtHalfBath   2919 non-null   float64
#  48  FullBath       2919 non-null   int64
#  49  HalfBath       2919 non-null   int64
#  50  BedroomAbvGr   2919 non-null   int64
#  51  KitchenAbvGr   2919 non-null   int64
#  52  KitchenQual    2919 non-null   object
#  53  TotRmsAbvGrd   2919 non-null   int64
#  54  Functional     2919 non-null   object
#  55  Fireplaces     2919 non-null   int64
#  56  FireplaceQu    2919 non-null   object
#  57  GarageType     2919 non-null   object
#  58  GarageYrBlt    2919 non-null   float64
#  59  GarageFinish   2919 non-null   object
#  60  GarageCars     2919 non-null   float64
#  61  GarageArea     2919 non-null   float64
#  62  GarageQual     2919 non-null   object
#  63  GarageCond     2919 non-null   object
#  64  PavedDrive     2919 non-null   object
#  65  WoodDeckSF     2919 non-null   int64
#  66  OpenPorchSF    2919 non-null   int64
#  67  EnclosedPorch  2919 non-null   int64
#  68  3SsnPorch      2919 non-null   int64
#  69  ScreenPorch    2919 non-null   int64
#  70  PoolArea       2919 non-null   int64
#  71  PoolQC         2919 non-null   object
#  72  Fence          2919 non-null   object
#  73  MiscFeature    2919 non-null   object
#  74  MiscVal        2919 non-null   int64
#  75  MoSold         2919 non-null   int64
#  76  YrSold         2919 non-null   int64
#  77  SaleType       2918 non-null   object
#  78  SaleCondition  2919 non-null   object
#  79  SalePrice      2919 non-null   int64
# dtypes: float64(11), int64(26), object(43)
# memory usage: 1.8+ MB

# %% [markdown]
# ## Feature : SaleType

# %%
# House with missing value in the feature
df[pd.isnull(df['SaleType'])]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 2490          20       RL         85.0    13770   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                    ...
# 2490         Lvl    AllPub    Corner  ...        0     NA    NA          NA
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 2490       0     10    2007       NaN         Normal         -1
#
# [1 rows x 80 columns]

# %%
df.loc[pd.isnull(df['SaleType']), 'GarageType':]
# Out:
#      GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# Id
# 2490     Attchd       1958.0          Unf         1.0       303.0         TA
#
#      GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  ...  PoolArea  PoolQC  \
# Id                                                   ...
# 2490         TA          Y           0            0  ...         0      NA
#
#       Fence  MiscFeature MiscVal MoSold YrSold  SaleType  SaleCondition  \
# Id
# 2490     NA           NA       0     10   2007       NaN         Normal
#
#       SalePrice
# Id
# 2490         -1
#
# [1 rows x 23 columns]

# %%
# Distrubtion of entries
df['SaleType'].value_counts()
# Out:
# WD       2525
# New       239
# COD        87
# ConLD      26
# CWD        12
# ConLI       9
# ConLw       8
# Oth         7
# Con         5
# Name: SaleType, dtype: int64

# %%
# Distrbution of entries of house solve after 2000
df.loc[df['YrSold'] == 2007, 'SaleType'].value_counts()
# Out:
# WD       568
# New       89
# COD       18
# CWD       11
# ConLw      2
# Oth        2
# Con        1
# Name: SaleType, dtype: int64

# %%
# Setting value to 'WD' since that is the most common entry
df.loc[pd.isnull(df['SaleType']), 'SaleType'] = 'WD'

# %%
# Checking to see that the update is done correctly
df['SaleType'].value_counts()
# Out:
# WD       2526
# New       239
# COD        87
# ConLD      26
# CWD        12
# ConLI       9
# ConLw       8
# Oth         7
# Con         5
# Name: SaleType, dtype: int64

# %%
# This features is now complete
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 1 to 2919
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     2919 non-null   int64
#  1   MSZoning       2919 non-null   object
#  2   LotFrontage    2919 non-null   float64
#  3   LotArea        2919 non-null   int64
#  4   Street         2919 non-null   object
#  5   Alley          198 non-null    object
#  6   LotShape       2919 non-null   object
#  7   LandContour    2919 non-null   object
#  8   Utilities      2919 non-null   object
#  9   LotConfig      2919 non-null   object
#  10  LandSlope      2919 non-null   object
#  11  Neighborhood   2919 non-null   object
#  12  Condition1     2919 non-null   object
#  13  Condition2     2919 non-null   object
#  14  BldgType       2919 non-null   object
#  15  HouseStyle     2919 non-null   object
#  16  OverallQual    2919 non-null   int64
#  17  OverallCond    2919 non-null   int64
#  18  YearBuilt      2919 non-null   int64
#  19  YearRemodAdd   2919 non-null   int64
#  20  RoofStyle      2919 non-null   object
#  21  RoofMatl       2919 non-null   object
#  22  Exterior1st    2919 non-null   object
#  23  Exterior2nd    2919 non-null   object
#  24  MasVnrType     2919 non-null   object
#  25  MasVnrArea     2919 non-null   float64
#  26  ExterQual      2919 non-null   object
#  27  ExterCond      2919 non-null   object
#  28  Foundation     2919 non-null   object
#  29  BsmtQual       2919 non-null   object
#  30  BsmtCond       2919 non-null   object
#  31  BsmtExposure   2919 non-null   object
#  32  BsmtFinType1   2919 non-null   object
#  33  BsmtFinSF1     2919 non-null   float64
#  34  BsmtFinType2   2919 non-null   object
#  35  BsmtFinSF2     2919 non-null   float64
#  36  BsmtUnfSF      2919 non-null   float64
#  37  TotalBsmtSF    2919 non-null   float64
#  38  Heating        2919 non-null   object
#  39  HeatingQC      2919 non-null   object
#  40  CentralAir     2919 non-null   object
#  41  Electrical     2919 non-null   object
#  42  1stFlrSF       2919 non-null   int64
#  43  2ndFlrSF       2919 non-null   int64
#  44  LowQualFinSF   2919 non-null   int64
#  45  GrLivArea      2919 non-null   int64
#  46  BsmtFullBath   2919 non-null   float64
#  47  BsmtHalfBath   2919 non-null   float64
#  48  FullBath       2919 non-null   int64
#  49  HalfBath       2919 non-null   int64
#  50  BedroomAbvGr   2919 non-null   int64
#  51  KitchenAbvGr   2919 non-null   int64
#  52  KitchenQual    2919 non-null   object
#  53  TotRmsAbvGrd   2919 non-null   int64
#  54  Functional     2919 non-null   object
#  55  Fireplaces     2919 non-null   int64
#  56  FireplaceQu    2919 non-null   object
#  57  GarageType     2919 non-null   object
#  58  GarageYrBlt    2919 non-null   float64
#  59  GarageFinish   2919 non-null   object
#  60  GarageCars     2919 non-null   float64
#  61  GarageArea     2919 non-null   float64
#  62  GarageQual     2919 non-null   object
#  63  GarageCond     2919 non-null   object
#  64  PavedDrive     2919 non-null   object
#  65  WoodDeckSF     2919 non-null   int64
#  66  OpenPorchSF    2919 non-null   int64
#  67  EnclosedPorch  2919 non-null   int64
#  68  3SsnPorch      2919 non-null   int64
#  69  ScreenPorch    2919 non-null   int64
#  70  PoolArea       2919 non-null   int64
#  71  PoolQC         2919 non-null   object
#  72  Fence          2919 non-null   object
#  73  MiscFeature    2919 non-null   object
#  74  MiscVal        2919 non-null   int64
#  75  MoSold         2919 non-null   int64
#  76  YrSold         2919 non-null   int64
#  77  SaleType       2919 non-null   object
#  78  SaleCondition  2919 non-null   object
#  79  SalePrice      2919 non-null   int64
# dtypes: float64(11), int64(26), object(43)
# memory usage: 1.8+ MB

# %% [markdown]
# ### All missing data has been filled in.
