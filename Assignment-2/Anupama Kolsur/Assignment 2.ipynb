# %%
import pandas as pd
import numpy as np

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %%
pd.options.display.max_rows
pd.set_option("display.max_rows",None)
df_train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 5        6          50       RL         85.0    14115   Pave   NaN      IR1
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# 8        9          50       RM         51.0     6120   Pave   NaN      Reg
# 9       10         190       RL         50.0     7420   Pave   NaN      Reg
# 10      11          20       RL         70.0    11200   Pave   NaN      Reg
# ...

# %%
df_train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
import matplotlib.pyplot as plt

# %%
# Checking the skewness of sale price
print ("Skew: ", df_train.SalePrice.skew())
plt.hist(df_train.SalePrice)
plt.show()
# Out:
# Skew:  1.8828757597682129

# %%
target = np.log(df_train.SalePrice)
print ("Skew is:", target.skew())
plt.hist(target, color='red')
plt.show()
# Out:
# Skew is: 0.12133506220520406

# %%
# displaying all the columns in the train dataset
df_train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
# displaying the correlation matrix between columns 
import seaborn as sns
corrmat=df_train.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);

# %%
# unique values in OverallQual column
df_train.OverallQual.unique()
# Out:
# array([ 7,  6,  8,  5,  9,  4, 10,  3,  1,  2], dtype=int64)

# %%
#median values of SalePrice corresponding to the OverallQual column
quality_pivot = df_train.pivot_table(index='OverallQual',values='SalePrice', aggfunc=np.median)
quality_pivot
# Out:
#              SalePrice
# OverallQual
# 1                50150
# 2                60000
# 3                86250
# 4               108000
# 5               133000
# 6               160000
# 7               200141
# 8               269750
# 9               345000
# 10              432390

# %%
# bar graph of sale price against OverallQual
quality_pivot.plot(kind='bar')
plt.xticks(rotation=0).show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-90-e82ced029317> in <module>
#       1 # bar graph of sale price against OverallQual
#       2 quality_pivot.plot(kind='bar')
# ----> 3 plt.xticks(rotation=0).show()
#
# AttributeError: 'tuple' object has no attribute 'show'

# %%
# scatter plot of GrLivArea against SalePrice
plt.scatter(x=df_train['GrLivArea'], y=target, color='orange')
plt.ylabel('Sale Price')
plt.xlabel('Above grade (ground) living area square feet')
plt.show()

# %%
# scatter plot of GarageArea against SalePrice
plt.scatter(x=df_train['GarageArea'], y=target)
plt.ylabel('Sale Price')
plt.xlabel('Garage Area')
plt.show()

# %%
#creating new dataset with outliers removed
df_train = df_train[df_train['GarageArea'] < 1200]

# %%
plt.scatter(x=df_train['GarageArea'], y=np.log(df_train.SalePrice))
plt.xlim(-200,1600)
plt.ylabel('Sale Price')
plt.xlabel('Garage Area')
plt.show()

# %%
#cheking count of null values in each column
df_train.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       258
# LotArea             0
# Street              0
# Alley            1364
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# ...

# %%
categoricals = df_train.select_dtypes(exclude=[np.number])
categoricals.describe()
# Out:
#        MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# count      1455   1455    91     1455        1455      1455      1455
# unique        5      2     2        4           4         2         5
# top          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside
# freq       1147   1450    50      921        1309      1454      1048
#
#        LandSlope Neighborhood Condition1  ... GarageType GarageFinish  \
# count       1455         1455       1455  ...       1374         1374
# unique         3           25          9  ...          6            3
# top          Gtl        NAmes       Norm  ...     Attchd          Unf
# freq        1378          225       1257  ...        867          605
#
#        GarageQual GarageCond PavedDrive PoolQC  Fence MiscFeature SaleType  \
# count        1374       1374       1455      6    281          53     1455
# unique          5          5          3      3      4           4        9
# ...

# %%
#count of each unique street types
df_train.Street.value_counts()
# Out:
# Pave    1450
# Grvl       5
# Name: Street, dtype: int64

# %%
#performing one hot encoding on the street types and transforming the data into boolean values
df_train['enc_street'] = pd.get_dummies(df_train.Street, drop_first=True)
df_test['enc_street'] = pd.get_dummies(df_train.Street, drop_first=True)
df_train.enc_street.value_counts()
# Out:
# C:\Users\anupa\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 1    1450
# 0       5
# Name: enc_street, dtype: int64

# %%
#bar graph of median sale price against sale condition
condition_pivot = df_train.pivot_table(index='SaleCondition', values='SalePrice', aggfunc=np.median)
condition_pivot.plot(kind='bar', color='blue')
plt.xlabel('Sale Condition')
plt.ylabel('Median Sale Price')
plt.xticks(rotation=0)
plt.show()

# %%
#
def encode(x):
 return 1 if x == 'Partial' else 0
df_train['enc_condition'] = df_train.SaleCondition.apply(encode)
df_test['enc_condition'] = df_test.SaleCondition.apply(encode)
# Out:
# C:\Users\anupa\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
condition_pivot = df_train.pivot_table(index='enc_condition', values='SalePrice', aggfunc=np.median)
condition_pivot.plot(kind='bar', color='blue')
plt.xlabel('Encoded Sale Condition')
plt.ylabel('Median Sale Price')
plt.xticks(rotation=0)
plt.show()

# %%
data = df_train.select_dtypes(include=[np.number]).interpolate().dropna()
sum(data.isnull().sum() != 0)
# Out:
# 0

# %%
#building a linear model
y = np.log(df_train.SalePrice)
X = data.drop(['SalePrice', 'Id'], axis=1)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=.33)

# %%
#creating a linear regression model
from sklearn import linear_model
lr = linear_model.LinearRegression()
model = lr.fit(X_train, y_train)

# %%
print("R^2 is : ")
model.score(X_test, y_test)
# Out:
# R^2 is :
# 0.888247770926253

# %%
predictions = model.predict(X_test)

# %%
#printing the root mean square error
from sklearn.metrics import mean_squared_error
print ('RMSE is: ')
mean_squared_error(y_test, predictions)
# Out:
# RMSE is:
# 0.017841794519567973

# %%
actual_values = y_test
plt.scatter(predictions, actual_values, alpha=.7,color='b')
plt.xlabel('Predicted Price')
plt.ylabel('Actual Price')
plt.title('Linear Regression Model')
plt.show()

# %%
#improving the model
for i in range (-2, 3):
    alpha = 10**i
    rm = linear_model.Ridge(alpha=alpha)
    ridge_model = rm.fit(X_train, y_train)
    preds_ridge = ridge_model.predict(X_test)

    plt.scatter(preds_ridge, actual_values, alpha=.75, color='b')
    plt.xlabel('Predicted Price')
    plt.ylabel('Actual Price')
    plt.title('Ridge Regularization with alpha = {}'.format(alpha))
    overlay = 'R^2 is: {}\nRMSE is: {}'.format(
                    ridge_model.score(X_test, y_test),
                    mean_squared_error(y_test, preds_ridge))
    plt.annotate(s=overlay,xy=(12.1,10.6),size='x-large')
    plt.show()

# %%
#making a submission
submission = pd.DataFrame()
submission['Id'] = df_test.Id
feats = df_test.select_dtypes(include=[np.number]).drop(['Id'], axis=1).interpolate()

# %%
predictions = model.predict(feats)
final_predictions = np.exp(predictions)

# %%
submission['SalePrice'] = final_predictions
submission
# Out:
#         Id     SalePrice
# 0     1461  1.289595e+05
# 1     1462  1.229207e+05
# 2     1463  1.757048e+05
# 3     1464  2.000508e+05
# 4     1465  1.820755e+05
# 5     1466  1.723183e+05
# 6     1467  1.910646e+05
# 7     1468  1.654886e+05
# 8     1469  1.931590e+05
# 9     1470  1.162140e+05
# 10    1471  1.975173e+05
# 11    1472  1.104969e+05
# 12    1473  1.046280e+05
# 13    1474  1.600486e+05
# 14    1475  1.219503e+05
# 15    1476  3.465103e+05
# 16    1477  2.471722e+05
# 17    1478  2.686596e+05
# 18    1479  2.585578e+05
# 19    1480  4.802821e+05
# 20    1481  2.977381e+05
# 21    1482  1.994470e+05
# 22    1483  1.679170e+05
# 23    1484  1.619809e+05
# 24    1485  1.840495e+05
# 25    1486  1.975576e+05
# 26    1487  3.142562e+05
# 27    1488  2.443817e+05
# 28    1489  1.846486e+05
# 29    1490  2.241714e+05
# 30    1491  1.907149e+05
# 31    1492  9.698201e+04
# 32    1493  2.108023e+05
# 33    1494  2.874320e+05
# 34    1495  2.851916e+05
# 35    1496  2.165161e+05
# ...

# %%
#displaying the predicted SalePrice
submission.to_csv('submission1.csv', index=False)
submission
# Out:
#         Id     SalePrice
# 0     1461  1.289595e+05
# 1     1462  1.229207e+05
# 2     1463  1.757048e+05
# 3     1464  2.000508e+05
# 4     1465  1.820755e+05
# 5     1466  1.723183e+05
# 6     1467  1.910646e+05
# 7     1468  1.654886e+05
# 8     1469  1.931590e+05
# 9     1470  1.162140e+05
# 10    1471  1.975173e+05
# 11    1472  1.104969e+05
# 12    1473  1.046280e+05
# 13    1474  1.600486e+05
# 14    1475  1.219503e+05
# 15    1476  3.465103e+05
# 16    1477  2.471722e+05
# 17    1478  2.686596e+05
# 18    1479  2.585578e+05
# 19    1480  4.802821e+05
# 20    1481  2.977381e+05
# 21    1482  1.994470e+05
# 22    1483  1.679170e+05
# 23    1484  1.619809e+05
# 24    1485  1.840495e+05
# 25    1486  1.975576e+05
# 26    1487  3.142562e+05
# 27    1488  2.443817e+05
# 28    1489  1.846486e+05
# 29    1490  2.241714e+05
# 30    1491  1.907149e+05
# 31    1492  9.698201e+04
# 32    1493  2.108023e+05
# 33    1494  2.874320e+05
# 34    1495  2.851916e+05
# 35    1496  2.165161e+05
# ...
