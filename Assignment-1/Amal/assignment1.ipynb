# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-472b9564-1e51-4356-910a-b7f26b6c5fec" name="files[]" multiple disabled />
#      <output id="result-472b9564-1e51-4356-910a-b7f26b6c5fec">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dataset1.csv to dataset1.csv

# %%
import pandas as pd
import io
data = pd.read_csv(io.StringIO(uploaded['dataset1.csv'].decode('utf-8')))

# %%
df=pd.DataFrame(data)

# %%
df.dropna(subset = ["CT-1 (Marks: 20)"], inplace=True)

# %%
df = df.dropna()
print(df)

# %%
data = data.dropna()

# %%
df['Class Test (Total of best 3, Marks: 60)'] = pd.to_numeric(df['Class Test (Total of best 3, Marks: 60)'], downcast="float")
df['Mark total 300'] = pd.to_numeric(df['Mark total 300'], downcast="float")
df['Total (Marks: 90)'] = pd.to_numeric(df['Total (Marks: 90)'], downcast="float")

# %%
df=pd.DataFrame(data)
print(df)

# %%
data.head(5)

# %%
df['Class Test (Total of best 3, Marks: 60)'].min()

# %%
df.columns

# %%
df.plot.scatter(x='Mark total 300',y='Attendance (Marks: 15)',color='c');

# %%
df.plot.scatter(x='Attendance (Marks: 15)',y='Class Test (Total of best 3, Marks: 60)',color='c');

# %%
df.pivot_table(index='Attendance (Marks: 15)',columns='Roll',values='Mark total 300')

# %%
df[['Attendance (Marks: 15)','Mark total 300','Class Test (Total of best 3, Marks: 60)','Total (Marks: 90)']]

# %%
pd.crosstab(df['Attendance (Marks: 15)'],df['Class Test (Total of best 3, Marks: 60)'])

# %%
df.groupby(['Attendance (Marks: 15)'])['Class Test (Total of best 3, Marks: 60)','Mark total 300','Total (Marks: 90)'].mean().plot(kind='bar',rot=0,title='Attendance VS Marks')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
data.head()
# Out:
#    Roll CT-1 (Marks: 20)  ... Exam Mark (105).1 Mark total 300
# 0   2.0             12.5  ...              46.5          167.0
# 1   3.0                9  ...              44.0          138.5
# 2   4.0               10  ...              43.0          136.0
# 3   5.0               14  ...              44.0          166.0
# 4   6.0             14.5  ...              74.5          176.5
#
# [5 rows x 12 columns]

# %%
df.groupby(['Attendance (Marks: 15)'])['Exam Mark (105)','Exam Mark (105).1','Total (Marks: 90)'].mean().plot(kind='bar',rot=0,title='Attendance VS Marks(Mean)')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
df.groupby(['Attendance (Marks: 15)'])['Exam Mark (105)','Exam Mark (105).1','Total (Marks: 90)'].median().plot(kind='bar',rot=0,title='Attendance VS Marks(Median)')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
df.groupby(['Attendance (Marks: 15)'])['Exam Mark (105)','Exam Mark (105).1','Total (Marks: 90)'].std().plot(kind='bar',rot=0,title='Attendance VS Marks(Standard Deviation)')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
